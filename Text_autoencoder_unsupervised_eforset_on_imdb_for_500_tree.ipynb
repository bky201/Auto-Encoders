# %% [markdown]
# # **TEXT AUTO ENCODER USING UNSUPERVISED EFOREST ON IMDB TEXT DATASET WITH 500 TREE**

# %%
from keras.datasets import imdb
import numpy as np

# %%
max_features= 100 # NUMBER OF WORD OR VOCABULARY SIZE
(X_tr, y_tr), (X_te, y_te) =  imdb.load_data(num_words=max_features)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
X_train = X_tr[:500]
y_train = y_tr[:500]
X_test = X_te[:500]
y_test = y_te[:500]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
print("Categories:", np.unique(y_train))
print("Number of unique words:", len(np.unique(np.hstack(X_train))))
# Out:
# Categories: [0 1]
# Number of unique words: 98

# %%
length = [len(i) for i in X_train]
print("Average Review length:", np.mean(length))
print("Standard Deviation:", round(np.std(length)))
# Out:
# Average Review length: 257.8
# Standard Deviation: 196

# %%
print("Label:", y_train[0])
print(X_train[0])
# Out:
# Label: 1
# [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 2, 36, 2, 5, 25, 2, 43, 2, 2, 50, 2, 2, 9, 35, 2, 2, 5, 2, 4, 2, 2, 2, 2, 2, 2, 39, 4, 2, 2, 2, 17, 2, 38, 13, 2, 4, 2, 50, 16, 6, 2, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 2, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 2, 12, 16, 38, 2, 5, 25, 2, 51, 36, 2, 48, 25, 2, 33, 6, 22, 12, 2, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 2, 2, 2, 15, 2, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 2, 88, 4, 2, 15, 2, 98, 32, 2, 56, 26, 2, 6, 2, 2, 18, 4, 2, 22, 21, 2, 2, 26, 2, 5, 2, 30, 2, 18, 51, 36, 28, 2, 92, 25, 2, 4, 2, 65, 16, 38, 2, 88, 12, 16, 2, 5, 16, 2, 2, 2, 32, 15, 16, 2, 19, 2, 32]

# %% [markdown]
# ##**Pre-processing**

# %%
# Used for pre-processing data
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import pandas as pd
from nltk import pos_tag
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocessing(text):
    #splits the word and checks each character to see if it contains any standard punctuations, 
    #if so it will be replaced with a blank or else it just don’t replace with blank
    text2 = " ".join("".join([" " if ch in string.punctuation else ch for ch in text]).split())
    
    #tokenizes the sentences into words based on whitespaces and puts them together as a list for applying further steps
    tokens = [word for sent in nltk.sent_tokenize(text2) for word in nltk.word_tokenize(sent)]
    
    #Converting all the cases (upper, lower and proper) into lower case reduces duplicates in corpus
    tokens = [word.lower() for word in tokens]
    
    #Stop words are the words that do not carry much of weight in understanding the sentence; 
    #they are used for connecting words and so on. We have removed them with the following line of code
    stopwds = stopwords.words('english')
    tokens = [token for token in tokens if token not in stopwds]
    
    #Stemming applied on the words using Porter stemmer which stems the extra suffixes from the words
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    
    #POS tagging is a prerequisite for lemmatization, based on whether the word 
    #is noun or verb or and so on. it will reduce it to the root word
    tagged_corpus = pos_tag(tokens)

    Noun_tags = ['NN','NNP','NNPS','NNS']
    Verb_tags = ['VB','VBD','VBG','VBN','VBP','VBZ']
    lemmatizer = WordNetLemmatizer()

    #  If the tag for any word falls under the respective noun or verb tags category, 
    #  n or v will be applied accordingly in lemmatize function
    def prat_lemmatize(token,tag):
        if tag in Noun_tags:
            return lemmatizer.lemmatize(token,'n')

        elif tag in Verb_tags:
            return lemmatizer.lemmatize(token,'v')
        else:
            return lemmatizer.lemmatize(token,'n')
    
    #we need to join it back to form stings and the following function performs the same
    pre_proc_text =   " ".join([prat_lemmatize(token,tag) for token,tag in tagged_corpus])

    return pre_proc_text

# %% [markdown]
# ###**PREPROCESSING ON TRAIN AND TEST DATA**

# %%
# A dictionary mapping words to an integer index
vocabulary = imdb.get_word_index()

index = dict([(value, key) for (key, value) in vocabulary.items()])

# %%
'''converts encoded text to human readable form.
    each integer in the text is looked up in the index, and 
    replaced by the corresponding word.
'''
X_train = [' '.join([index.get(i, '?') for i in x]) for x in X_train]
X_test = [' '.join([index.get(i, '?') for i in x]) for x in X_test]

# %%
X_train_preprocessed = []
for i in X_train:
    X_train_preprocessed.append(preprocessing(i))

X_test_preprocessed = []
for i in X_test:
    X_test_preprocessed.append(preprocessing(i))

# %%
X_train_preprocessed[0]
# Out:
# 'movi film get movi movi stori one br br one film'

# %%
X_test_preprocessed[0]
# Out:
# 'br one'

# %% [markdown]
# ### **BUILDING TF-IDF vectorizer**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# from keras.preprocessing.sequence import pad_sequences



vectorizer = TfidfVectorizer(max_features= max_features)

vectorizer.fit(X_train_preprocessed) 

X_train_2 = vectorizer.transform(X_train_preprocessed).todense()

X_test_2 = vectorizer.transform(X_test_preprocessed).todense()

# %%
np.set_printoptions(threshold=np.inf) # to prevent truncation out output resut
print(X_train_2[0][:20])
# Out:
# [[0.         0.         0.30788979 0.         0.         0.40583095
#   0.         0.31603217 0.         0.         0.         0.
#   0.         0.57512642 0.         0.46078001 0.         0.
#   0.         0.31231423 0.         0.         0.         0.        ]]

# %% [markdown]
# ### **DEFINE NODE RULE**

# %%
import copy
import numpy as np

# %%
class NodeRule:

    LT = 0 # 'less than'
    LE = 1 # 'less or equal to'

    def __init__(self, attribute, threshold, op):
        # [lower_bound] [op_left] value [op_right] [upper_bound]
        assert(op in ['gt', 'le'])
        self.attribute = attribute
        if op == 'le':
            self.lower_bound = -np.inf
            self.upper_bound = threshold
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LE
        else:
            self.lower_bound = threshold
            self.upper_bound = np.inf
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LT
    
    def __and__(self, other):
        new_rule = copy.copy(self)
        if self.lower_bound > other.lower_bound:
            new_rule.lower_bound = self.lower_bound
            new_rule.op_left = self.op_left
        elif self.lower_bound < other.lower_bound:
            new_rule.lower_bound = other.lower_bound
            new_rule.op_left = other.op_left
        else:
            new_rule.lower_bound = self.lower_bound
            if NodeRule.LT in [self.op_left, other.op_left]:
                new_rule.op_left = NodeRule.LT
            else:
                new_rule.op_left = NodeRule.LE
        if self.upper_bound < other.upper_bound:
            new_rule.upper_bound = self.upper_bound
            new_rule.op_right = self.op_right
        elif self.upper_bound > other.upper_bound:
            new_rule.upper_bound = other.upper_bound
            new_rule.op_right = other.op_right
        else:
            new_rule.upper_bound = self.upper_bound
            if NodeRule.LT in [self.op_right, other.op_right]:
                new_rule.op_right = NodeRule.LT
            else:
                new_rule.op_right = NodeRule.LE
        return new_rule

    def __str__(self):
        s = str(self.lower_bound) + ' '
        s += '<=' if self.op_left == NodeRule.LE else '<'
        s += ' x_%i ' % self.attribute
        s += '<=' if self.op_right == NodeRule.LE else '<'
        s += ' ' + str(self.upper_bound)
        return s
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ### **DEFINE PATH RULE**

# %%
class PathRule:
    
    def __init__(self, n_attributes):
        self.n_attributes = n_attributes
        self.node_rules = [NodeRule(i, -np.inf, 'gt') for i in range(n_attributes)]
    
    def set_global_bounds(self, lower_bounds, upper_bounds):
        for i in range(self.n_attributes):
            node_rule = NodeRule(i, -np.inf, 'gt')
            node_rule.op_left = NodeRule.LE
            node_rule.op_right = NodeRule.LE
            node_rule.lower_bound = lower_bounds[i]
            node_rule.upper_bound = upper_bounds[i]
            self.add(node_rule)
    
    def add(self, node_rule):
        assert(isinstance(node_rule, NodeRule))
        j = node_rule.attribute
        self.node_rules[j] = self.node_rules[j].__and__(node_rule)
    
    def sample(self, sampling='mean'):
        sample = np.empty(self.n_attributes)
        for i, rule in enumerate(self):
            if sampling == 'mean':
                sample[i] = (rule.lower_bound + rule.upper_bound) / 2.
            else:
                sample[i] = np.random.uniform(rule.lower_bound, rule.upper_bound)
        return sample
    
    def compute_volume(self):
        log_volume = 1
        for i in range(self.n_attributes):
            node_rule = self.node_rules[i]
            log_volume += (node_rule.upper_bound - node_rule.lower_bound)
            assert(node_rule.upper_bound >= node_rule.lower_bound)
        return log_volume
    
    def __len__(self):
        return len(self.node_rules)
    
    def __iter__(self):
        self.current_attribute = 0
        return self
    
    def __next__(self):
        self.current_attribute += 1
        try:
            result = self.node_rules[self.current_attribute-1]
        except IndexError:
            raise StopIteration
        return result
    
    def __str__(self):
        return str(self.node_rules)
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## **RANDOME TREE MODEL**

# %%
from sklearn.ensemble import RandomTreesEmbedding
from sklearn.tree import ExtraTreeRegressor

# %%
class CompletelyRandomTree:

    def __init__(self, sklearn_extra_tree, n_attributes):
        self.n_attributes = n_attributes
        self.tree = sklearn_extra_tree
        self.n_nodes = self.tree.tree_.node_count
        self.parent_ids = np.full(self.n_nodes, -1, dtype=np.int)
        self.operators = [None] * self.n_nodes
        tree = self.tree.tree_
        for i in range(self.n_nodes):
            parent_from_left = np.where(tree.children_left == i)[0]
            parent_from_right = np.where(tree.children_right == i)[0]
            if len(parent_from_left) == 1:
                self.parent_ids[i] = parent_from_left[0]
                self.operators[i] = 'le'
            elif len(parent_from_right) == 1:
                self.parent_ids[i] = parent_from_right[0]
                self.operators[i] = 'gt'
        self.leaf_to_node = np.where(tree.feature == -2)[0]
        self.node_to_leaf = {node_id: leaf_id for leaf_id, node_id in enumerate(self.leaf_to_node)}
        self.n_leafs = len(self.leaf_to_node)
    
    def encode(self, X):
        node_ids = self.tree.apply(X)
        return [self.node_to_leaf[node_id] for node_id in node_ids]
    
    def get_path_rule(self, default_path_rule, leaf_id):
        path_rule = copy.deepcopy(default_path_rule)
        tree = self.tree.tree_
        current_id = self.leaf_to_node[leaf_id]
        while current_id != 0:
            attribute = tree.feature[self.parent_ids[current_id]]
            bound = tree.threshold[self.parent_ids[current_id]]
            op = self.operators[current_id]
            path_rule.add(NodeRule(attribute, bound, op))
            current_id = self.parent_ids[current_id]
        return path_rule

# %% [markdown]
# ## **DEFINE ENCODER FOREST**

# %%
class EncoderForest:

    def __init__(self, n_components):
        self.trees = list()
        self.n_attributes = 0
        self.in_size = 0
        self.out_size = n_components
        self.global_lower_bounds = None
        self.global_upper_bounds = None
        self.default_path_rule = None
        self.unsupervised = True
    
    def fit(self, X, y=None, max_depth=10):
        self.unsupervised = (y is None)
        self.n_attributes = X.shape[1]
        self.in_size = X.shape[0]
        if y is None:
            forest = RandomTreesEmbedding(self.out_size, max_depth=max_depth)
            forest.fit(X)
        else:
            forest = RandomForestClassifier(n_estimators=self.out_size, max_depth=max_depth)
            forest.fit(X, y)
        for i in range(self.out_size):
            self.trees.append(CompletelyRandomTree(forest.estimators_[i], self.n_attributes))
        
        self.global_lower_bounds = np.min(X, axis=0).astype(np.double)
        self.global_upper_bounds = np.max(X, axis=0).astype(np.double)

        self.default_path_rule = PathRule(self.n_attributes)
        self.default_path_rule.set_global_bounds(self.global_lower_bounds, self.global_upper_bounds)
    
    def encode(self, X):
        n_samples = X.shape[0]
        out_dim = len(self.trees)
        encoded = np.empty((n_samples, out_dim), dtype=np.int)
        for i in range(out_dim):
            encoded[:, i] = self.trees[i].encode(X)
        return encoded

    def compute_rule_list(self, x):
        out_dim = len(self.trees)
        rule_list = list()
        for i in range(out_dim):
            path_rule = self.trees[i].get_path_rule(self.default_path_rule, x[i])
            rule_list.append(path_rule)
        return rule_list
    
    def decode(self, x):
        rule_list = self.compute_rule_list(x)
        MCR = self.calculate_MCR(rule_list)
        return MCR.sample(sampling='mean')

    def calculate_MCR(self, path_rule_list):
        MCR = copy.deepcopy(self.default_path_rule)
        n_attributes = len(MCR)
        n_trees = len(path_rule_list)

        for i in range(len(path_rule_list)):
            path_rule = path_rule_list[i]
            print("Volume of path rule %i: %f" % (i, path_rule.compute_volume()))
            for node_rule in path_rule.node_rules:
                MCR.add(node_rule)
        print("Volume of MCR: %f" % MCR.compute_volume())
        return MCR

# %%
X_train = np.array(X_train_2)
X_test = np.array(X_test_2)
y_train = np.array(y_train)
y_test = np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))
y_train = y_train.reshape((y_train.shape[0], -1))
y_test = y_test.reshape((y_test.shape[0], -1))
print("[IMDB] x_train.shape={}, y_train.shape={}".format(X_train.shape, y_train.shape))
print("[IMDB] x_test.shape={}, y_test.shape={}".format(X_test.shape, y_test.shape))
# Out:
# [IMDB] x_train.shape=(500, 24), y_train.shape=(500, 1)
# [IMDB] x_test.shape=(500, 24), y_test.shape=(500, 1)

# %%
print("Start Autoencoder using unsupervised model")
#eforest = RandomTreesEmbedding(n_estimators=n_trees, max_depth=None, n_jobs=-1, random_state=0)
encoder = EncoderForest(500)
encoder.fit(X_train, max_depth=5)
print("end fit on unsupervised model")
# Out:
# Start Autoencoder using unsupervised model
# end fit on unsupervised model

# %% [markdown]
# ### **MODEL EVALUATION**

# %%
X_encode = encoder.encode(X_test)

# %%
#X_encode = np.array(X_encode)

# %%
X_encode.shape
# Out:
# (500, 500)

# %%
results = []
# for i in range(500):
for j in range(len(X_encode)):
    results.append(encoder.decode(X_encode[j]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Volume of path rule 10: 18.115691
# Volume of path rule 11: 16.925417
# Volume of path rule 12: 18.045469
# Volume of path rule 13: 18.791730
# Volume of path rule 14: 18.631585
# Volume of path rule 15: 18.530213
# Volume of path rule 16: 18.439272
# Volume of path rule 17: 18.381276
# Volume of path rule 18: 19.199791
# Volume of path rule 19: 19.020026
# Volume of path rule 20: 18.557223
# Volume of path rule 21: 18.326172
# Volume of path rule 22: 18.708125
# Volume of path rule 23: 18.568514
# Volume of path rule 24: 18.383945
# Volume of path rule 25: 18.953538
# Volume of path rule 26: 18.473715
# Volume of path rule 27: 19.004119
# Volume of path rule 28: 18.040880
# Volume of path rule 29: 18.728744
# Volume of path rule 30: 18.390439
# Volume of path rule 31: 17.493618
# Volume of path rule 32: 17.746777
# Volume of path rule 33: 18.288994
# Volume of path rule 34: 18.366847
# Volume of path rule 35: 18.879626
# Volume of path rule 36: 17.941039
# Volume of path rule 37: 18.414578
# Volume of path rule 38: 19.317131
# Volume of path rule 39: 19.028165
# Volume of path rule 40: 18.401454
# Volume of path rule 41: 17.827897
# Volume of path rule 42: 18.468106
# Volume of path rule 43: 18.948914
# Volume of path rule 44: 19.222856
# Volume of path rule 45: 19.157532
# Volume of path rule 46: 17.354770
# Volume of path rule 47: 17.959225
# Volume of path rule 48: 18.410437
# Volume of path rule 49: 18.600081
# Volume of path rule 50: 17.460033
# Volume of path rule 51: 18.358363
# Volume of path rule 52: 18.333800
# Volume of path rule 53: 18.653920
# Volume of path rule 54: 18.073720
# Volume of path rule 55: 18.806727
# Volume of path rule 56: 19.410347
# Volume of path rule 57: 17.807117
# Volume of path rule 58: 18.767028
# Volume of path rule 59: 17.753021
# Volume of path rule 60: 19.137489
# Volume of path rule 61: 17.671456
# Volume of path rule 62: 18.579213
# Volume of path rule 63: 18.180092
# Volume of path rule 64: 18.858840
# Volume of path rule 65: 17.800488
# Volume of path rule 66: 19.451622
# Volume of path rule 67: 18.792426
# Volume of path rule 68: 18.046942
# Volume of path rule 69: 18.531074
# Volume of path rule 70: 17.904865
# Volume of path rule 71: 18.156662
# Volume of path rule 72: 19.348276
# Volume of path rule 73: 18.455802
# Volume of path rule 74: 18.488411
# Volume of path rule 75: 18.127973
# Volume of path rule 76: 18.540707
# Volume of path rule 77: 18.936359
# Volume of path rule 78: 18.152059
# Volume of path rule 79: 19.376752
# Volume of path rule 80: 18.630440
# Volume of path rule 81: 18.026775
# Volume of path rule 82: 19.101783
# Volume of path rule 83: 18.767179
# Volume of path rule 84: 18.642815
# Volume of path rule 85: 19.000746
# Volume of path rule 86: 18.596576
# Volume of path rule 87: 17.727524
# Volume of path rule 88: 18.055690
# Volume of path rule 89: 17.867442
# Volume of path rule 90: 17.250897
# Volume of path rule 91: 17.733398
# Volume of path rule 92: 18.030902
# Volume of path rule 93: 18.529374
# Volume of path rule 94: 18.682997
# Volume of path rule 95: 18.883796
# Volume of path rule 96: 18.040111
# Volume of path rule 97: 16.966599
# Volume of path rule 98: 18.556919
# Volume of path rule 99: 18.447498
# Volume of path rule 100: 18.144248
# Volume of path rule 101: 17.965295
# Volume of path rule 102: 18.152154
# Volume of path rule 103: 19.464918
# Volume of path rule 104: 18.077580
# Volume of path rule 105: 18.882910
# Volume of path rule 106: 18.636017
# Volume of path rule 107: 18.678000
# Volume of path rule 108: 17.503918
# Volume of path rule 109: 18.635752
# Volume of path rule 110: 18.097635
# Volume of path rule 111: 19.072672
# Volume of path rule 112: 17.968056
# Volume of path rule 113: 17.437241
# Volume of path rule 114: 18.663570
# Volume of path rule 115: 17.981645
# Volume of path rule 116: 17.868361
# Volume of path rule 117: 18.485576
# Volume of path rule 118: 17.953167
# Volume of path rule 119: 18.088784
# Volume of path rule 120: 18.944423
# Volume of path rule 121: 18.042250
# Volume of path rule 122: 18.449368
# Volume of path rule 123: 17.120630
# Volume of path rule 124: 17.477863
# Volume of path rule 125: 17.897550
# Volume of path rule 126: 18.528801
# Volume of path rule 127: 18.130302
# Volume of path rule 128: 18.218937
# Volume of path rule 129: 18.674849
# Volume of path rule 130: 18.507347
# Volume of path rule 131: 18.627198
# Volume of path rule 132: 17.794831
# Volume of path rule 133: 18.242038
# Volume of path rule 134: 18.281089
# Volume of path rule 135: 18.247593
# Volume of path rule 136: 18.332789
# Volume of path rule 137: 17.494226
# Volume of path rule 138: 16.561896
# Volume of path rule 139: 17.846862
# Volume of path rule 140: 18.894411
# Volume of path rule 141: 18.805690
# Volume of path rule 142: 18.819233
# Volume of path rule 143: 18.221972
# Volume of path rule 144: 18.827150
# Volume of path rule 145: 18.406983
# Volume of path rule 146: 18.199752
# Volume of path rule 147: 18.685428
# Volume of path rule 148: 17.608802
# Volume of path rule 149: 17.331444
# Volume of path rule 150: 17.617225
# Volume of path rule 151: 18.574301
# Volume of path rule 152: 18.727992
# Volume of path rule 153: 18.960367
# Volume of path rule 154: 17.633462
# Volume of path rule 155: 17.029224
# Volume of path rule 156: 18.750470
# Volume of path rule 157: 16.847460
# Volume of path rule 158: 18.560199
# Volume of path rule 159: 19.165447
# Volume of path rule 160: 18.567510
# Volume of path rule 161: 17.605534
# Volume of path rule 162: 18.662550
# Volume of path rule 163: 19.153037
# Volume of path rule 164: 18.798787
# Volume of path rule 165: 18.748906
# Volume of path rule 166: 18.019887
# Volume of path rule 167: 19.735860
# Volume of path rule 168: 19.506953
# Volume of path rule 169: 18.465765
# Volume of path rule 170: 19.167484
# Volume of path rule 171: 18.205516
# Volume of path rule 172: 18.143032
# Volume of path rule 173: 18.774254
# Volume of path rule 174: 18.909593
# Volume of path rule 175: 18.895138
# Volume of path rule 176: 18.375285
# Volume of path rule 177: 19.087935
# Volume of path rule 178: 18.492093
# Volume of path rule 179: 19.294031
# Volume of path rule 180: 18.707055
# Volume of path rule 181: 18.125804
# Volume of path rule 182: 19.150960
# Volume of path rule 183: 18.106013
# Volume of path rule 184: 18.507532
# Volume of path rule 185: 17.947869
# Volume of path rule 186: 17.803046
# Volume of path rule 187: 18.065388
# Volume of path rule 188: 18.310476
# Volume of path rule 189: 18.644134
# Volume of path rule 190: 18.961401
# Volume of path rule 191: 17.869383
# Volume of path rule 192: 18.312641
# Volume of path rule 193: 18.881541
# Volume of path rule 194: 18.713693
# Volume of path rule 195: 18.566181
# Volume of path rule 196: 18.564855
# Volume of path rule 197: 18.674325
# Volume of path rule 198: 17.869239
# Volume of path rule 199: 16.755810
# Volume of path rule 200: 17.783693
# Volume of path rule 201: 18.221055
# Volume of path rule 202: 19.021528
# Volume of path rule 203: 18.786100
# Volume of path rule 204: 19.556173
# Volume of path rule 205: 18.836614
# Volume of path rule 206: 18.431537
# Volume of path rule 207: 18.915470
# Volume of path rule 208: 18.802577
# Volume of path rule 209: 18.919924
# Volume of path rule 210: 18.815542
# Volume of path rule 211: 17.549769
# Volume of path rule 212: 17.997970
# Volume of path rule 213: 18.545838
# Volume of path rule 214: 18.808402
# Volume of path rule 215: 19.545390
# Volume of path rule 216: 18.409557
# Volume of path rule 217: 18.276284
# Volume of path rule 218: 17.948185
# Volume of path rule 219: 18.304052
# Volume of path rule 220: 19.128367
# Volume of path rule 221: 18.900458
# Volume of path rule 222: 18.095270
# Volume of path rule 223: 19.008114
# Volume of path rule 224: 18.347347
# Volume of path rule 225: 17.856518
# Volume of path rule 226: 19.004967
# Volume of path rule 227: 18.872309
# Volume of path rule 228: 16.837539
# Volume of path rule 229: 18.255280
# Volume of path rule 230: 19.426392
# Volume of path rule 231: 17.509094
# Volume of path rule 232: 18.573470
# Volume of path rule 233: 18.278314
# Volume of path rule 234: 18.981416
# Volume of path rule 235: 18.723039
# Volume of path rule 236: 18.297371
# Volume of path rule 237: 17.888064
# Volume of path rule 238: 18.894385
# Volume of path rule 239: 19.369826
# Volume of path rule 240: 19.509438
# Volume of path rule 241: 19.203725
# Volume of path rule 242: 19.199879
# Volume of path rule 243: 18.560643
# Volume of path rule 244: 18.918489
# Volume of path rule 245: 17.894921
# Volume of path rule 246: 18.814922
# Volume of path rule 247: 19.023905
# Volume of path rule 248: 19.731941
# Volume of path rule 249: 18.595079
# Volume of path rule 250: 18.614237
# Volume of path rule 251: 19.354354
# Volume of path rule 252: 18.918922
# Volume of path rule 253: 18.684703
# Volume of path rule 254: 17.648796
# Volume of path rule 255: 18.591426
# Volume of path rule 256: 18.314825
# Volume of path rule 257: 17.875118
# Volume of path rule 258: 18.381185
# Volume of path rule 259: 17.054749
# Volume of path rule 260: 18.264122
# Volume of path rule 261: 17.432752
# Volume of path rule 262: 18.387380
# Volume of path rule 263: 18.497440
# Volume of path rule 264: 19.634204
# Volume of path rule 265: 17.804079
# Volume of path rule 266: 18.703748
# Volume of path rule 267: 17.957438
# Volume of path rule 268: 17.755614
# Volume of path rule 269: 18.359856
# Volume of path rule 270: 18.592005
# Volume of path rule 271: 17.877510
# Volume of path rule 272: 17.909620
# Volume of path rule 273: 19.080443
# Volume of path rule 274: 18.534409
# Volume of path rule 275: 18.469232
# Volume of path rule 276: 17.596532
# Volume of path rule 277: 19.197593
# Volume of path rule 278: 18.100147
# Volume of path rule 279: 18.573010
# Volume of path rule 280: 18.350840
# Volume of path rule 281: 18.143035
# Volume of path rule 282: 18.123163
# Volume of path rule 283: 19.030361
# Volume of path rule 284: 17.627541
# Volume of path rule 285: 17.969929
# Volume of path rule 286: 17.957008
# Volume of path rule 287: 17.523223
# Volume of path rule 288: 18.497695
# Volume of path rule 289: 19.475016
# Volume of path rule 290: 17.206128
# Volume of path rule 291: 17.648068
# Volume of path rule 292: 18.370115
# Volume of path rule 293: 18.646368
# Volume of path rule 294: 18.437941
# Volume of path rule 295: 19.493582
# Volume of path rule 296: 18.281276
# Volume of path rule 297: 18.623564
# Volume of path rule 298: 19.072964
# Volume of path rule 299: 17.817273
# Volume of path rule 300: 18.075769
# Volume of path rule 301: 19.050172
# Volume of path rule 302: 18.036334
# Volume of path rule 303: 19.025805
# Volume of path rule 304: 18.732986
# Volume of path rule 305: 18.489842
# Volume of path rule 306: 18.055813
# Volume of path rule 307: 19.261863
# Volume of path rule 308: 18.869084
# Volume of path rule 309: 17.705035
# Volume of path rule 310: 17.055781
# Volume of path rule 311: 18.384291
# Volume of path rule 312: 18.883096
# Volume of path rule 313: 19.285736
# Volume of path rule 314: 18.221199
# Volume of path rule 315: 16.989987
# Volume of path rule 316: 18.244262
# Volume of path rule 317: 18.605724
# Volume of path rule 318: 18.147175
# Volume of path rule 319: 18.141999
# Volume of path rule 320: 18.827150
# Volume of path rule 321: 17.585399
# Volume of path rule 322: 18.436922
# Volume of path rule 323: 19.521268
# Volume of path rule 324: 17.943152
# Volume of path rule 325: 17.592269
# Volume of path rule 326: 19.212230
# Volume of path rule 327: 17.705307
# Volume of path rule 328: 18.021852
# Volume of path rule 329: 18.189337
# Volume of path rule 330: 18.659889
# Volume of path rule 331: 19.137342
# Volume of path rule 332: 18.944853
# Volume of path rule 333: 18.045425
# Volume of path rule 334: 18.598464
# Volume of path rule 335: 19.428759
# Volume of path rule 336: 17.184667
# Volume of path rule 337: 17.563058
# Volume of path rule 338: 18.865454
# Volume of path rule 339: 17.410276
# Volume of path rule 340: 17.870060
# Volume of path rule 341: 19.081049
# Volume of path rule 342: 17.968859
# Volume of path rule 343: 17.890403
# Volume of path rule 344: 18.548599
# Volume of path rule 345: 18.426515
# Volume of path rule 346: 18.265007
# Volume of path rule 347: 18.044029
# Volume of path rule 348: 18.452629
# Volume of path rule 349: 17.936735
# Volume of path rule 350: 18.599989
# Volume of path rule 351: 18.175030
# Volume of path rule 352: 18.226303
# Volume of path rule 353: 18.316976
# Volume of path rule 354: 17.832478
# Volume of path rule 355: 18.991243
# Volume of path rule 356: 17.811127
# Volume of path rule 357: 18.342804
# Volume of path rule 358: 17.839847
# Volume of path rule 359: 18.334737
# Volume of path rule 360: 18.418440
# Volume of path rule 361: 19.805300
# Volume of path rule 362: 17.969551
# Volume of path rule 363: 19.164929
# Volume of path rule 364: 18.361363
# Volume of path rule 365: 18.033080
# Volume of path rule 366: 18.875696
# Volume of path rule 367: 17.850146
# Volume of path rule 368: 18.205579
# Volume of path rule 369: 18.361102
# Volume of path rule 370: 18.091117
# Volume of path rule 371: 18.419331
# Volume of path rule 372: 18.480749
# Volume of path rule 373: 17.402435
# Volume of path rule 374: 17.359896
# Volume of path rule 375: 18.762899
# Volume of path rule 376: 17.244744
# Volume of path rule 377: 18.430966
# Volume of path rule 378: 17.964591
# Volume of path rule 379: 18.902414
# Volume of path rule 380: 18.254789
# Volume of path rule 381: 17.612973
# Volume of path rule 382: 17.173893
# Volume of path rule 383: 18.044476
# Volume of path rule 384: 17.120790
# Volume of path rule 385: 19.304442
# Volume of path rule 386: 18.311664
# Volume of path rule 387: 18.982796
# Volume of path rule 388: 18.556837
# Volume of path rule 389: 18.146756
# Volume of path rule 390: 18.693395
# Volume of path rule 391: 18.085740
# Volume of path rule 392: 19.638049
# Volume of path rule 393: 18.695349
# Volume of path rule 394: 17.626078
# Volume of path rule 395: 18.071998
# Volume of path rule 396: 18.250564
# Volume of path rule 397: 17.918916
# Volume of path rule 398: 19.158764
# Volume of path rule 399: 18.758120
# Volume of path rule 400: 17.956248
# Volume of path rule 401: 17.663690
# Volume of path rule 402: 18.602416
# Volume of path rule 403: 17.695337
# Volume of path rule 404: 18.044354
# Volume of path rule 405: 18.136048
# Volume of path rule 406: 18.439590
# Volume of path rule 407: 17.118305
# Volume of path rule 408: 18.413320
# Volume of path rule 409: 17.260021
# Volume of path rule 410: 18.833999
# Volume of path rule 411: 18.556533
# Volume of path rule 412: 19.175002
# Volume of path rule 413: 17.958946
# Volume of path rule 414: 17.740366
# Volume of path rule 415: 17.661230
# Volume of path rule 416: 18.543846
# Volume of path rule 417: 17.197432
# Volume of path rule 418: 18.052008
# Volume of path rule 419: 18.225478
# Volume of path rule 420: 16.990642
# Volume of path rule 421: 17.843233
# Volume of path rule 422: 17.409258
# Volume of path rule 423: 19.222051
# Volume of path rule 424: 18.903372
# Volume of path rule 425: 17.995611
# Volume of path rule 426: 17.952993
# Volume of path rule 427: 18.377252
# Volume of path rule 428: 17.767876
# Volume of path rule 429: 18.294325
# Volume of path rule 430: 18.107685
# Volume of path rule 431: 18.325011
# Volume of path rule 432: 18.080303
# Volume of path rule 433: 18.495262
# Volume of path rule 434: 19.429867
# Volume of path rule 435: 18.959228
# Volume of path rule 436: 17.400188
# Volume of path rule 437: 17.712778
# Volume of path rule 438: 17.359655
# Volume of path rule 439: 18.595397
# Volume of path rule 440: 17.520581
# Volume of path rule 441: 18.387502
# Volume of path rule 442: 18.758499
# Volume of path rule 443: 19.123459
# Volume of path rule 444: 18.846476
# Volume of path rule 445: 18.664163
# Volume of path rule 446: 17.817695
# Volume of path rule 447: 18.738870
# Volume of path rule 448: 19.167871
# Volume of path rule 449: 17.858514
# Volume of path rule 450: 18.919974
# Volume of path rule 451: 18.784486
# Volume of path rule 452: 18.652006
# Volume of path rule 453: 18.635691
# Volume of path rule 454: 18.825526
# Volume of path rule 455: 17.595088
# Volume of path rule 456: 18.274883
# Volume of path rule 457: 17.097318
# Volume of path rule 458: 18.348853
# Volume of path rule 459: 18.392988
# Volume of path rule 460: 17.208531
# Volume of path rule 461: 19.106857
# Volume of path rule 462: 18.838851
# Volume of path rule 463: 17.533607
# Volume of path rule 464: 19.258117
# Volume of path rule 465: 18.825324
# Volume of path rule 466: 17.267117
# Volume of path rule 467: 18.291552
# Volume of path rule 468: 17.933903
# Volume of path rule 469: 18.848365
# Volume of path rule 470: 18.710229
# Volume of path rule 471: 18.143102
# Volume of path rule 472: 19.196166
# Volume of path rule 473: 18.688810
# Volume of path rule 474: 18.082289
# Volume of path rule 475: 18.326305
# Volume of path rule 476: 17.413488
# Volume of path rule 477: 18.338781
# Volume of path rule 478: 19.104514
# Volume of path rule 479: 17.682386
# Volume of path rule 480: 18.738284
# Volume of path rule 481: 19.219992
# Volume of path rule 482: 17.804327
# Volume of path rule 483: 18.272043
# Volume of path rule 484: 18.743542
# Volume of path rule 485: 18.405391
# Volume of path rule 486: 18.262225
# Volume of path rule 487: 19.183057
# Volume of path rule 488: 18.681431
# Volume of path rule 489: 17.280375
# Volume of path rule 490: 17.991194
# Volume of path rule 491: 19.126092
# Volume of path rule 492: 18.114745
# Volume of path rule 493: 18.249002
# Volume of path rule 494: 18.062001
# Volume of path rule 495: 18.724358
# Volume of path rule 496: 18.969231
# Volume of path rule 497: 18.079246
# Volume of path rule 498: 18.374603
# Volume of path rule 499: 18.023870
# Volume of MCR: 1.181529
# Volume of path rule 0: 18.133808
# Volume of path rule 1: 18.611171
# Volume of path rule 2: 18.410086
# Volume of path rule 3: 18.834472
# Volume of path rule 4: 18.044231
# Volume of path rule 5: 18.270530
# Volume of path rule 6: 17.956668
# Volume of path rule 7: 18.128923
# Volume of path rule 8: 17.834832
# Volume of path rule 9: 17.961082
# Volume of path rule 10: 18.115691
# Volume of path rule 11: 17.380029
# Volume of path rule 12: 18.015851
# Volume of path rule 13: 18.791730
# Volume of path rule 14: 18.973538
# Volume of path rule 15: 17.700550
# Volume of path rule 16: 18.567537
# Volume of path rule 17: 18.584783
# Volume of path rule 18: 19.199791
# Volume of path rule 19: 19.024731
# Volume of path rule 20: 18.557223
# Volume of path rule 21: 17.891142
# Volume of path rule 22: 18.772462
# Volume of path rule 23: 19.777739
# Volume of path rule 24: 18.383945
# Volume of path rule 25: 18.953538
# Volume of path rule 26: 17.935291
# Volume of path rule 27: 19.397061
# Volume of path rule 28: 18.559317
# Volume of path rule 29: 18.728744
# Volume of path rule 30: 17.810864
# Volume of path rule 31: 17.661850
# Volume of path rule 32: 19.349522
# Volume of path rule 33: 18.288994
# Volume of path rule 34: 17.837929
# Volume of path rule 35: 18.879626
# Volume of path rule 36: 18.078189
# Volume of path rule 37: 18.414578
# Volume of path rule 38: 18.449822
# Volume of path rule 39: 18.954027
# Volume of path rule 40: 18.310453
# Volume of path rule 41: 17.681039
# Volume of path rule 42: 18.943564
# Volume of path rule 43: 18.948914
# Volume of path rule 44: 19.222856
# Volume of path rule 45: 18.384798
# Volume of path rule 46: 18.818139
# Volume of path rule 47: 18.973740
# Volume of path rule 48: 18.658636
# Volume of path rule 49: 18.344170
# Volume of path rule 50: 19.008230
# Volume of path rule 51: 18.358363
# Volume of path rule 52: 18.333800
# Volume of path rule 53: 18.653920
# Volume of path rule 54: 19.051469
# Volume of path rule 55: 18.806727
# Volume of path rule 56: 19.302178
# Volume of path rule 57: 17.874452
# Volume of path rule 58: 18.283519
# Volume of path rule 59: 18.397070
# Volume of path rule 60: 19.137489
# Volume of path rule 61: 18.529822
# Volume of path rule 62: 17.868702
# Volume of path rule 63: 18.446499
# Volume of path rule 64: 18.852040
# Volume of path rule 65: 17.805700
# Volume of path rule 66: 19.451622
# Volume of path rule 67: 18.638349
# Volume of path rule 68: 18.712966
# Volume of path rule 69: 18.531074
# Volume of path rule 70: 18.424476
# Volume of path rule 71: 18.156662
# Volume of path rule 72: 18.662581
# Volume of path rule 73: 18.622943
# Volume of path rule 74: 17.893929
# Volume of path rule 75: 18.296670
# Volume of path rule 76: 17.887715
# Volume of path rule 77: 18.293502
# Volume of path rule 78: 18.077029
# Volume of path rule 79: 17.555467
# Volume of path rule 80: 18.184612
# Volume of path rule 81: 18.026775
# Volume of path rule 82: 18.098987
# Volume of path rule 83: 18.209057
# Volume of path rule 84: 19.197408
# Volume of path rule 85: 18.853948
# Volume of path rule 86: 18.597331
# Volume of path rule 87: 18.062277
# Volume of path rule 88: 18.143452
# Volume of path rule 89: 17.669578
# Volume of path rule 90: 17.250897
# Volume of path rule 91: 17.733398
# Volume of path rule 92: 18.030902
# Volume of path rule 93: 18.529374
# Volume of path rule 94: 18.682997
# Volume of path rule 95: 18.503809
# Volume of path rule 96: 18.358275
# Volume of path rule 97: 19.243189
# Volume of path rule 98: 17.711894
# Volume of path rule 99: 18.447498
# Volume of path rule 100: 18.369297
# Volume of path rule 101: 18.176768
# Volume of path rule 102: 19.029916
# Volume of path rule 103: 19.464918
# Volume of path rule 104: 18.876667
# Volume of path rule 105: 18.882910
# Volume of path rule 106: 18.115258
# Volume of path rule 107: 17.971593
# Volume of path rule 108: 18.087784
# Volume of path rule 109: 18.635752
# Volume of path rule 110: 18.097635
# Volume of path rule 111: 19.072672
# Volume of path rule 112: 17.968056
# Volume of path rule 113: 17.859789
# Volume of path rule 114: 18.663570
# Volume of path rule 115: 17.981645
# Volume of path rule 116: 18.494395
# Volume of path rule 117: 17.916248
# Volume of path rule 118: 17.953167
# Volume of path rule 119: 18.530999
# Volume of path rule 120: 18.357383
# Volume of path rule 121: 17.496811
# Volume of path rule 122: 18.024613
# Volume of path rule 123: 18.099973
# Volume of path rule 124: 18.193311
# Volume of path rule 125: 17.897550
# Volume of path rule 126: 17.830562
# Volume of path rule 127: 19.055849
# Volume of path rule 128: 18.859156
# Volume of path rule 129: 18.674849
# Volume of path rule 130: 18.507347
# Volume of path rule 131: 18.627198
# Volume of path rule 132: 18.441006
# Volume of path rule 133: 18.242038
# Volume of path rule 134: 18.671173
# Volume of path rule 135: 17.991154
# Volume of path rule 136: 19.002672
# Volume of path rule 137: 18.787452
# Volume of path rule 138: 17.886304
# Volume of path rule 139: 18.554635
# Volume of path rule 140: 18.894411
# Volume of path rule 141: 18.805690
# Volume of path rule 142: 19.319702
# Volume of path rule 143: 18.221972
# Volume of path rule 144: 18.132329
# Volume of path rule 145: 18.324487
# Volume of path rule 146: 18.028131
# Volume of path rule 147: 18.685428
# Volume of path rule 148: 18.155185
# Volume of path rule 149: 17.620716
# Volume of path rule 150: 17.759000
# Volume of path rule 151: 19.226747
# Volume of path rule 152: 18.727992
# Volume of path rule 153: 18.363986
# Volume of path rule 154: 18.848422
# Volume of path rule 155: 18.132411
# Volume of path rule 156: 17.868426
# Volume of path rule 157: 18.982826
# Volume of path rule 158: 16.986288
# Volume of path rule 159: 19.165447
# Volume of path rule 160: 18.567510
# Volume of path rule 161: 17.605534
# Volume of path rule 162: 18.662550
# Volume of path rule 163: 19.192053
# Volume of path rule 164: 18.798787
# Volume of path rule 165: 19.057305
# Volume of path rule 166: 18.225875
# Volume of path rule 167: 19.700393
# Volume of path rule 168: 18.714705
# Volume of path rule 169: 18.465765
# Volume of path rule 170: 19.167484
# Volume of path rule 171: 18.391282
# Volume of path rule 172: 17.645575
# Volume of path rule 173: 18.267160
# Volume of path rule 174: 18.909593
# Volume of path rule 175: 18.895138
# Volume of path rule 176: 18.768886
# Volume of path rule 177: 18.655378
# Volume of path rule 178: 18.492093
# Volume of path rule 179: 19.294031
# Volume of path rule 180: 18.765536
# Volume of path rule 181: 18.125804
# Volume of path rule 182: 18.738517
# Volume of path rule 183: 18.106013
# Volume of path rule 184: 18.224190
# Volume of path rule 185: 18.856240
# Volume of path rule 186: 17.803046
# Volume of path rule 187: 17.155043
# Volume of path rule 188: 17.916029
# Volume of path rule 189: 18.220132
# Volume of path rule 190: 18.961401
# Volume of path rule 191: 17.869383
# Volume of path rule 192: 18.729961
# Volume of path rule 193: 19.062128
# Volume of path rule 194: 18.713693
# Volume of path rule 195: 18.566181
# Volume of path rule 196: 18.451072
# Volume of path rule 197: 18.030295
# Volume of path rule 198: 18.818974
# Volume of path rule 199: 17.674573
# Volume of path rule 200: 17.926933
# Volume of path rule 201: 18.221055
# Volume of path rule 202: 18.188037
# Volume of path rule 203: 18.786100
# Volume of path rule 204: 19.556173
# Volume of path rule 205: 18.430202
# Volume of path rule 206: 18.431537
# Volume of path rule 207: 18.207377
# Volume of path rule 208: 18.555119
# Volume of path rule 209: 18.310233
# Volume of path rule 210: 17.393489
# Volume of path rule 211: 17.727841
# Volume of path rule 212: 19.027251
# Volume of path rule 213: 17.391023
# Volume of path rule 214: 18.808402
# Volume of path rule 215: 19.545390
# Volume of path rule 216: 18.409557
# Volume of path rule 217: 18.276284
# Volume of path rule 218: 17.948185
# Volume of path rule 219: 18.005594
# Volume of path rule 220: 19.128367
# Volume of path rule 221: 17.908772
# Volume of path rule 222: 18.222114
# Volume of path rule 223: 17.805717
# Volume of path rule 224: 17.692376
# Volume of path rule 225: 18.678909
# Volume of path rule 226: 19.004967
# Volume of path rule 227: 19.585550
# Volume of path rule 228: 17.846951
# Volume of path rule 229: 18.255280
# Volume of path rule 230: 17.904987
# Volume of path rule 231: 17.509094
# Volume of path rule 232: 18.562952
# Volume of path rule 233: 18.278314
# Volume of path rule 234: 18.981416
# Volume of path rule 235: 18.723039
# Volume of path rule 236: 18.297371
# Volume of path rule 237: 18.653643
# Volume of path rule 238: 17.925178
# Volume of path rule 239: 18.973045
# Volume of path rule 240: 19.291772
# Volume of path rule 241: 18.568199
# Volume of path rule 242: 19.438118
# Volume of path rule 243: 18.560643
# Volume of path rule 244: 18.973356
# Volume of path rule 245: 19.147664
# Volume of path rule 246: 18.814922
# Volume of path rule 247: 19.023905
# Volume of path rule 248: 19.099267
# Volume of path rule 249: 17.819708
# Volume of path rule 250: 18.866518
# Volume of path rule 251: 18.234844
# Volume of path rule 252: 18.514103
# Volume of path rule 253: 18.684703
# Volume of path rule 254: 17.648796
# Volume of path rule 255: 18.561571
# Volume of path rule 256: 18.968690
# Volume of path rule 257: 17.875118
# Volume of path rule 258: 18.381185
# Volume of path rule 259: 17.727203
# Volume of path rule 260: 18.505391
# Volume of path rule 261: 17.432752
# Volume of path rule 262: 17.648046
# Volume of path rule 263: 18.497440
# Volume of path rule 264: 18.832783
# Volume of path rule 265: 18.755086
# Volume of path rule 266: 18.703748
# Volume of path rule 267: 18.151636
# Volume of path rule 268: 17.755614
# Volume of path rule 269: 18.575500
# Volume of path rule 270: 17.792045
# Volume of path rule 271: 18.669708
# Volume of path rule 272: 18.697385
# Volume of path rule 273: 18.759406
# Volume of path rule 274: 17.649222
# Volume of path rule 275: 17.603475
# Volume of path rule 276: 17.790916
# Volume of path rule 277: 18.291571
# Volume of path rule 278: 18.100147
# Volume of path rule 279: 18.573010
# Volume of path rule 280: 18.103677
# Volume of path rule 281: 18.469935
# Volume of path rule 282: 17.502163
# Volume of path rule 283: 19.030361
# Volume of path rule 284: 17.653129
# Volume of path rule 285: 18.646164
# Volume of path rule 286: 17.957008
# Volume of path rule 287: 18.466133
# Volume of path rule 288: 18.309951
# Volume of path rule 289: 18.948572
# Volume of path rule 290: 17.599910
# Volume of path rule 291: 17.685694
# Volume of path rule 292: 18.370115
# Volume of path rule 293: 18.804042
# Volume of path rule 294: 18.398161
# Volume of path rule 295: 19.245397
# Volume of path rule 296: 18.429526
# Volume of path rule 297: 18.205473
# Volume of path rule 298: 18.773834
# Volume of path rule 299: 17.963938
# Volume of path rule 300: 18.075769
# Volume of path rule 301: 19.050172
# Volume of path rule 302: 18.036334
# Volume of path rule 303: 18.465289
# Volume of path rule 304: 18.732986
# Volume of path rule 305: 18.489842
# Volume of path rule 306: 16.945446
# Volume of path rule 307: 18.986354
# Volume of path rule 308: 19.189471
# Volume of path rule 309: 19.173328
# Volume of path rule 310: 18.427707
# Volume of path rule 311: 18.906106
# Volume of path rule 312: 18.883096
# Volume of path rule 313: 19.285736
# Volume of path rule 314: 18.342847
# Volume of path rule 315: 18.290241
# Volume of path rule 316: 17.109198
# Volume of path rule 317: 18.605724
# Volume of path rule 318: 17.588318
# Volume of path rule 319: 17.784947
# Volume of path rule 320: 18.053166
# Volume of path rule 321: 18.379702
# Volume of path rule 322: 19.020052
# Volume of path rule 323: 18.188323
# Volume of path rule 324: 18.794699
# Volume of path rule 325: 17.592269
# Volume of path rule 326: 19.096978
# Volume of path rule 327: 18.536008
# Volume of path rule 328: 18.075018
# Volume of path rule 329: 18.189337
# Volume of path rule 330: 18.659889
# Volume of path rule 331: 17.622060
# Volume of path rule 332: 18.548904
# Volume of path rule 333: 18.045425
# Volume of path rule 334: 18.598464
# Volume of path rule 335: 17.729333
# Volume of path rule 336: 17.742089
# Volume of path rule 337: 17.454392
# Volume of path rule 338: 18.865454
# Volume of path rule 339: 18.313984
# Volume of path rule 340: 17.870060
# Volume of path rule 341: 19.195607
# Volume of path rule 342: 18.053081
# Volume of path rule 343: 17.890403
# Volume of path rule 344: 18.548599
# Volume of path rule 345: 18.426515
# Volume of path rule 346: 18.265007
# Volume of path rule 347: 18.044029
# Volume of path rule 348: 17.819530
# Volume of path rule 349: 18.302590
# Volume of path rule 350: 18.377192
# Volume of path rule 351: 18.105510
# Volume of path rule 352: 18.226303
# Volume of path rule 353: 18.731002
# Volume of path rule 354: 17.832478
# Volume of path rule 355: 18.991243
# Volume of path rule 356: 18.682339
# Volume of path rule 357: 17.992483
# Volume of path rule 358: 17.839847
# Volume of path rule 359: 18.479569
# Volume of path rule 360: 18.924670
# Volume of path rule 361: 19.805300
# Volume of path rule 362: 17.707741
# Volume of path rule 363: 19.164929
# Volume of path rule 364: 18.445033
# Volume of path rule 365: 18.127437
# Volume of path rule 366: 19.718145
# Volume of path rule 367: 17.850146
# Volume of path rule 368: 18.311996
# Volume of path rule 369: 18.361102
# Volume of path rule 370: 18.486959
# Volume of path rule 371: 18.508444
# Volume of path rule 372: 18.096892
# Volume of path rule 373: 17.402435
# Volume of path rule 374: 18.367049
# Volume of path rule 375: 18.762899
# Volume of path rule 376: 17.798411
# Volume of path rule 377: 17.577566
# Volume of path rule 378: 18.414408
# Volume of path rule 379: 18.902414
# Volume of path rule 380: 18.254789
# Volume of path rule 381: 17.612973
# Volume of path rule 382: 18.490186
# Volume of path rule 383: 17.803212
# Volume of path rule 384: 18.136192
# Volume of path rule 385: 19.304442
# Volume of path rule 386: 18.497768
# Volume of path rule 387: 18.311503
# Volume of path rule 388: 18.970568
# Volume of path rule 389: 18.834202
# Volume of path rule 390: 18.345315
# Volume of path rule 391: 17.198928
# Volume of path rule 392: 18.035189
# Volume of path rule 393: 18.695349
# Volume of path rule 394: 19.000752
# Volume of path rule 395: 18.028817
# Volume of path rule 396: 18.250564
# Volume of path rule 397: 17.985775
# Volume of path rule 398: 19.591153
# Volume of path rule 399: 18.758120
# Volume of path rule 400: 18.707622
# Volume of path rule 401: 18.519162
# Volume of path rule 402: 18.602416
# Volume of path rule 403: 18.547798
# Volume of path rule 404: 18.044354
# Volume of path rule 405: 18.136048
# Volume of path rule 406: 18.702450
# Volume of path rule 407: 18.324986
# Volume of path rule 408: 17.001721
# Volume of path rule 409: 17.287120
# Volume of path rule 410: 18.524108
# Volume of path rule 411: 18.034447
# Volume of path rule 412: 19.175002
# Volume of path rule 413: 17.878853
# Volume of path rule 414: 18.394054
# Volume of path rule 415: 17.661230
# Volume of path rule 416: 18.603552
# Volume of path rule 417: 18.653534
# Volume of path rule 418: 18.052008
# Volume of path rule 419: 18.948203
# Volume of path rule 420: 16.990642
# Volume of path rule 421: 18.725610
# Volume of path rule 422: 16.970618
# Volume of path rule 423: 18.548645
# Volume of path rule 424: 18.810227
# Volume of path rule 425: 18.222387
# Volume of path rule 426: 18.647301
# Volume of path rule 427: 18.377252
# Volume of path rule 428: 17.606490
# Volume of path rule 429: 18.520157
# Volume of path rule 430: 18.718738
# Volume of path rule 431: 18.467638
# Volume of path rule 432: 19.558562
# Volume of path rule 433: 18.820603
# Volume of path rule 434: 19.429867
# Volume of path rule 435: 18.959228
# Volume of path rule 436: 17.400188
# Volume of path rule 437: 18.119242
# Volume of path rule 438: 19.536625
# Volume of path rule 439: 17.114073
# Volume of path rule 440: 17.291875
# Volume of path rule 441: 18.835123
# Volume of path rule 442: 18.813064
# Volume of path rule 443: 19.148407
# Volume of path rule 444: 19.215197
# Volume of path rule 445: 18.664163
# Volume of path rule 446: 17.817695
# Volume of path rule 447: 18.738870
# Volume of path rule 448: 18.838852
# Volume of path rule 449: 17.858514
# Volume of path rule 450: 18.178383
# Volume of path rule 451: 18.784486
# Volume of path rule 452: 18.946492
# Volume of path rule 453: 18.600515
# Volume of path rule 454: 18.929919
# Volume of path rule 455: 17.595088
# Volume of path rule 456: 18.274883
# Volume of path rule 457: 18.238118
# Volume of path rule 458: 18.305173
# Volume of path rule 459: 18.558025
# Volume of path rule 460: 17.501875
# Volume of path rule 461: 18.410352
# Volume of path rule 462: 18.838851
# Volume of path rule 463: 18.085081
# Volume of path rule 464: 19.258117
# Volume of path rule 465: 18.662121
# Volume of path rule 466: 17.915790
# Volume of path rule 467: 18.206169
# Volume of path rule 468: 17.627533
# Volume of path rule 469: 18.848365
# Volume of path rule 470: 18.710229
# Volume of path rule 471: 18.143102
# Volume of path rule 472: 18.509379
# Volume of path rule 473: 18.688810
# Volume of path rule 474: 17.006224
# Volume of path rule 475: 17.805879
# Volume of path rule 476: 17.413488
# Volume of path rule 477: 18.721913
# Volume of path rule 478: 19.104514
# Volume of path rule 479: 18.009747
# Volume of path rule 480: 18.879177
# Volume of path rule 481: 19.219992
# Volume of path rule 482: 17.669840
# Volume of path rule 483: 18.272043
# Volume of path rule 484: 17.713761
# Volume of path rule 485: 18.754556
# Volume of path rule 486: 18.262225
# Volume of path rule 487: 19.183057
# Volume of path rule 488: 18.681431
# Volume of path rule 489: 18.100103
# Volume of path rule 490: 18.506144
# Volume of path rule 491: 19.126092
# Volume of path rule 492: 17.796766
# Volume of path rule 493: 18.851036
# Volume of path rule 494: 18.336461
# Volume of path rule 495: 19.338311
# Volume of path rule 496: 18.577477
# Volume of path rule 497: 18.285269
# Volume of path rule 498: 17.873209
# Volume of path rule 499: 18.023870
# Volume of MCR: 1.181165
# Volume of path rule 0: 18.328722
# Volume of path rule 1: 18.611171
# Volume of path rule 2: 18.410086
# Volume of path rule 3: 18.491334
# Volume of path rule 4: 18.101919
# Volume of path rule 5: 18.474151
# Volume of path rule 6: 18.621925
# Volume of path rule 7: 18.128923
# Volume of path rule 8: 17.851318
# Volume of path rule 9: 18.615094
# Volume of path rule 10: 18.965489
# Volume of path rule 11: 16.925417
# Volume of path rule 12: 17.748873
# Volume of path rule 13: 18.791730
# Volume of path rule 14: 18.860247
# Volume of path rule 15: 18.530213
# Volume of path rule 16: 18.861313
# Volume of path rule 17: 18.584783
# Volume of path rule 18: 19.199791
# Volume of path rule 19: 19.020026
# Volume of path rule 20: 18.495937
# Volume of path rule 21: 18.657058
# Volume of path rule 22: 18.772462
# Volume of path rule 23: 19.777739
# Volume of path rule 24: 18.921539
# Volume of path rule 25: 18.908913
# Volume of path rule 26: 18.255795
# Volume of path rule 27: 19.397061
# Volume of path rule 28: 17.923791
# Volume of path rule 29: 18.763350
# Volume of path rule 30: 17.812892
# Volume of path rule 31: 17.196138
# Volume of path rule 32: 19.349522
# Volume of path rule 33: 18.383885
# Volume of path rule 34: 19.115956
# Volume of path rule 35: 18.879626
# Volume of path rule 36: 17.941039
# Volume of path rule 37: 18.866604
# Volume of path rule 38: 18.449822
# Volume of path rule 39: 18.954027
# Volume of path rule 40: 18.310453
# Volume of path rule 41: 18.760233
# Volume of path rule 42: 18.943564
# Volume of path rule 43: 18.948914
# Volume of path rule 44: 19.222856
# Volume of path rule 45: 19.081534
# Volume of path rule 46: 18.354756
# Volume of path rule 47: 18.973740
# Volume of path rule 48: 19.411125
# Volume of path rule 49: 18.234355
# Volume of path rule 50: 19.008230
# Volume of path rule 51: 17.762027
# Volume of path rule 52: 17.982132
# Volume of path rule 53: 18.653920
# Volume of path rule 54: 19.051469
# Volume of path rule 55: 18.709351
# Volume of path rule 56: 19.276319
# Volume of path rule 57: 18.077692
# Volume of path rule 58: 18.283519
# Volume of path rule 59: 18.532127
# Volume of path rule 60: 19.137489
# Volume of path rule 61: 18.756559
# Volume of path rule 62: 18.530371
# Volume of path rule 63: 19.718178
# Volume of path rule 64: 18.754976
# Volume of path rule 65: 18.364463
# Volume of path rule 66: 19.358878
# Volume of path rule 67: 18.638349
# Volume of path rule 68: 18.422953
# Volume of path rule 69: 18.531074
# Volume of path rule 70: 18.515685
# Volume of path rule 71: 18.860830
# Volume of path rule 72: 18.662581
# Volume of path rule 73: 18.833056
# Volume of path rule 74: 17.893929
# Volume of path rule 75: 18.296670
# Volume of path rule 76: 17.887715
# Volume of path rule 77: 18.293502
# Volume of path rule 78: 18.851320
# Volume of path rule 79: 18.205180
# Volume of path rule 80: 18.184612
# Volume of path rule 81: 18.026775
# Volume of path rule 82: 18.667051
# Volume of path rule 83: 18.209057
# Volume of path rule 84: 19.197408
# Volume of path rule 85: 18.853948
# Volume of path rule 86: 19.265010
# Volume of path rule 87: 18.206628
# Volume of path rule 88: 18.827822
# Volume of path rule 89: 18.517781
# Volume of path rule 90: 18.300245
# Volume of path rule 91: 17.733398
# Volume of path rule 92: 18.095977
# Volume of path rule 93: 19.195364
# Volume of path rule 94: 18.682997
# Volume of path rule 95: 18.503809
# Volume of path rule 96: 17.811196
# Volume of path rule 97: 19.243189
# Volume of path rule 98: 18.624283
# Volume of path rule 99: 19.332068
# Volume of path rule 100: 18.369297
# Volume of path rule 101: 17.948175
# Volume of path rule 102: 19.029916
# Volume of path rule 103: 19.267208
# Volume of path rule 104: 18.061702
# Volume of path rule 105: 18.882910
# Volume of path rule 106: 18.115258
# Volume of path rule 107: 18.355404
# Volume of path rule 108: 17.503918
# Volume of path rule 109: 18.635752
# Volume of path rule 110: 18.097635
# Volume of path rule 111: 19.072672
# Volume of path rule 112: 18.203611
# Volume of path rule 113: 18.516136
# Volume of path rule 114: 18.663570
# Volume of path rule 115: 17.981645
# Volume of path rule 116: 17.868361
# Volume of path rule 117: 18.199361
# Volume of path rule 118: 17.953167
# Volume of path rule 119: 18.530999
# Volume of path rule 120: 18.357383
# Volume of path rule 121: 18.377279
# Volume of path rule 122: 18.366179
# Volume of path rule 123: 18.507605
# Volume of path rule 124: 18.193311
# Volume of path rule 125: 17.897550
# Volume of path rule 126: 17.830562
# Volume of path rule 127: 19.055849
# Volume of path rule 128: 17.936898
# Volume of path rule 129: 18.674849
# Volume of path rule 130: 18.507347
# Volume of path rule 131: 17.554002
# Volume of path rule 132: 17.918577
# Volume of path rule 133: 18.242038
# Volume of path rule 134: 18.671173
# Volume of path rule 135: 17.991154
# Volume of path rule 136: 18.756399
# Volume of path rule 137: 18.787452
# Volume of path rule 138: 18.172175
# Volume of path rule 139: 18.554635
# Volume of path rule 140: 18.319756
# Volume of path rule 141: 18.209771
# Volume of path rule 142: 19.319702
# Volume of path rule 143: 18.221972
# Volume of path rule 144: 18.132329
# Volume of path rule 145: 18.512800
# Volume of path rule 146: 17.932618
# Volume of path rule 147: 18.685428
# Volume of path rule 148: 18.441725
# Volume of path rule 149: 17.331444
# Volume of path rule 150: 18.761999
# Volume of path rule 151: 19.226747
# Volume of path rule 152: 18.727992
# Volume of path rule 153: 17.929228
# Volume of path rule 154: 18.848422
# Volume of path rule 155: 18.132411
# Volume of path rule 156: 18.733909
# Volume of path rule 157: 18.982826
# Volume of path rule 158: 18.560199
# Volume of path rule 159: 19.165447
# Volume of path rule 160: 18.538208
# Volume of path rule 161: 17.605534
# Volume of path rule 162: 18.776892
# Volume of path rule 163: 19.192053
# Volume of path rule 164: 18.528598
# Volume of path rule 165: 18.748906
# Volume of path rule 166: 18.225875
# Volume of path rule 167: 19.700393
# Volume of path rule 168: 18.714705
# Volume of path rule 169: 18.807268
# Volume of path rule 170: 19.167484
# Volume of path rule 171: 18.391282
# Volume of path rule 172: 18.551381
# Volume of path rule 173: 18.267160
# Volume of path rule 174: 18.909593
# Volume of path rule 175: 18.895138
# Volume of path rule 176: 18.768886
# Volume of path rule 177: 18.247963
# Volume of path rule 178: 18.829904
# Volume of path rule 179: 19.294031
# Volume of path rule 180: 18.765536
# Volume of path rule 181: 18.991127
# Volume of path rule 182: 18.738517
# Volume of path rule 183: 18.846917
# Volume of path rule 184: 18.117311
# Volume of path rule 185: 18.856240
# Volume of path rule 186: 19.393761
# Volume of path rule 187: 18.946314
# Volume of path rule 188: 18.310476
# Volume of path rule 189: 18.220132
# Volume of path rule 190: 18.961401
# Volume of path rule 191: 18.489074
# Volume of path rule 192: 18.729961
# Volume of path rule 193: 19.062128
# Volume of path rule 194: 18.713693
# Volume of path rule 195: 18.566181
# Volume of path rule 196: 18.451072
# Volume of path rule 197: 19.010835
# Volume of path rule 198: 18.818974
# Volume of path rule 199: 19.171131
# Volume of path rule 200: 17.963917
# Volume of path rule 201: 18.221055
# Volume of path rule 202: 18.697084
# Volume of path rule 203: 18.945274
# Volume of path rule 204: 19.556173
# Volume of path rule 205: 18.769148
# Volume of path rule 206: 17.791871
# Volume of path rule 207: 18.534333
# Volume of path rule 208: 18.802577
# Volume of path rule 209: 18.310233
# Volume of path rule 210: 18.107478
# Volume of path rule 211: 18.081860
# Volume of path rule 212: 19.027251
# Volume of path rule 213: 18.801524
# Volume of path rule 214: 18.808402
# Volume of path rule 215: 19.545390
# Volume of path rule 216: 19.092545
# Volume of path rule 217: 18.704769
# Volume of path rule 218: 17.948185
# Volume of path rule 219: 18.304052
# Volume of path rule 220: 19.128367
# Volume of path rule 221: 17.908772
# Volume of path rule 222: 18.311273
# Volume of path rule 223: 17.805717
# Volume of path rule 224: 17.589139
# Volume of path rule 225: 18.608118
# Volume of path rule 226: 19.004967
# Volume of path rule 227: 19.585550
# Volume of path rule 228: 17.641962
# Volume of path rule 229: 19.128372
# Volume of path rule 230: 17.904987
# Volume of path rule 231: 18.446169
# Volume of path rule 232: 18.562952
# Volume of path rule 233: 18.316814
# Volume of path rule 234: 18.981416
# Volume of path rule 235: 18.094894
# Volume of path rule 236: 18.297371
# Volume of path rule 237: 18.396710
# Volume of path rule 238: 17.737615
# Volume of path rule 239: 19.163721
# Volume of path rule 240: 19.291772
# Volume of path rule 241: 18.551923
# Volume of path rule 242: 19.199879
# Volume of path rule 243: 18.368585
# Volume of path rule 244: 18.993671
# Volume of path rule 245: 17.894921
# Volume of path rule 246: 18.814922
# Volume of path rule 247: 19.023905
# Volume of path rule 248: 19.099267
# Volume of path rule 249: 17.819708
# Volume of path rule 250: 18.773089
# Volume of path rule 251: 19.164349
# Volume of path rule 252: 18.918922
# Volume of path rule 253: 18.428922
# Volume of path rule 254: 17.648796
# Volume of path rule 255: 18.561571
# Volume of path rule 256: 18.968690
# Volume of path rule 257: 17.627205
# Volume of path rule 258: 18.202283
# Volume of path rule 259: 17.727203
# Volume of path rule 260: 18.847393
# Volume of path rule 261: 17.432752
# Volume of path rule 262: 18.387380
# Volume of path rule 263: 18.497440
# Volume of path rule 264: 18.832783
# Volume of path rule 265: 18.755086
# Volume of path rule 266: 18.302699
# Volume of path rule 267: 18.173182
# Volume of path rule 268: 17.755614
# Volume of path rule 269: 18.564414
# Volume of path rule 270: 18.611646
# Volume of path rule 271: 18.669708
# Volume of path rule 272: 18.516527
# Volume of path rule 273: 18.759406
# Volume of path rule 274: 19.127350
# Volume of path rule 275: 17.826410
# Volume of path rule 276: 17.790916
# Volume of path rule 277: 18.962205
# Volume of path rule 278: 18.100147
# Volume of path rule 279: 18.573010
# Volume of path rule 280: 18.350840
# Volume of path rule 281: 18.663184
# Volume of path rule 282: 17.502163
# Volume of path rule 283: 19.030361
# Volume of path rule 284: 18.433585
# Volume of path rule 285: 18.646164
# Volume of path rule 286: 18.603819
# Volume of path rule 287: 18.090269
# Volume of path rule 288: 19.562546
# Volume of path rule 289: 18.948572
# Volume of path rule 290: 18.202555
# Volume of path rule 291: 17.734012
# Volume of path rule 292: 18.743803
# Volume of path rule 293: 18.804042
# Volume of path rule 294: 18.648372
# Volume of path rule 295: 19.245397
# Volume of path rule 296: 18.281276
# Volume of path rule 297: 18.217512
# Volume of path rule 298: 18.773834
# Volume of path rule 299: 18.521919
# Volume of path rule 300: 17.787756
# Volume of path rule 301: 19.050172
# Volume of path rule 302: 18.036334
# Volume of path rule 303: 18.465289
# Volume of path rule 304: 18.732986
# Volume of path rule 305: 19.424330
# Volume of path rule 306: 18.187219
# Volume of path rule 307: 18.986354
# Volume of path rule 308: 19.189471
# Volume of path rule 309: 17.705035
# Volume of path rule 310: 17.175374
# Volume of path rule 311: 18.384291
# Volume of path rule 312: 18.883096
# Volume of path rule 313: 19.285736
# Volume of path rule 314: 18.664230
# Volume of path rule 315: 17.887879
# Volume of path rule 316: 18.737156
# Volume of path rule 317: 18.639515
# Volume of path rule 318: 17.420345
# Volume of path rule 319: 17.784947
# Volume of path rule 320: 18.053166
# Volume of path rule 321: 18.107294
# Volume of path rule 322: 19.020052
# Volume of path rule 323: 19.521268
# Volume of path rule 324: 18.794699
# Volume of path rule 325: 19.149218
# Volume of path rule 326: 19.096978
# Volume of path rule 327: 18.536008
# Volume of path rule 328: 18.905304
# Volume of path rule 329: 18.773586
# Volume of path rule 330: 18.659889
# Volume of path rule 331: 19.137342
# Volume of path rule 332: 18.548904
# Volume of path rule 333: 18.811951
# Volume of path rule 334: 18.644939
# Volume of path rule 335: 18.846415
# Volume of path rule 336: 17.997912
# Volume of path rule 337: 18.699062
# Volume of path rule 338: 18.865454
# Volume of path rule 339: 18.211204
# Volume of path rule 340: 18.220576
# Volume of path rule 341: 19.081049
# Volume of path rule 342: 17.417476
# Volume of path rule 343: 18.999863
# Volume of path rule 344: 19.135157
# Volume of path rule 345: 18.146178
# Volume of path rule 346: 18.759243
# Volume of path rule 347: 18.712681
# Volume of path rule 348: 17.840549
# Volume of path rule 349: 17.835880
# Volume of path rule 350: 18.377192
# Volume of path rule 351: 18.105510
# Volume of path rule 352: 19.229124
# Volume of path rule 353: 18.731002
# Volume of path rule 354: 17.832478
# Volume of path rule 355: 18.991243
# Volume of path rule 356: 18.426957
# Volume of path rule 357: 19.057477
# Volume of path rule 358: 17.839847
# Volume of path rule 359: 19.061033
# Volume of path rule 360: 18.924670
# Volume of path rule 361: 19.805300
# Volume of path rule 362: 18.268744
# Volume of path rule 363: 19.164929
# Volume of path rule 364: 18.445033
# Volume of path rule 365: 18.127437
# Volume of path rule 366: 19.718145
# Volume of path rule 367: 17.850146
# Volume of path rule 368: 18.311996
# Volume of path rule 369: 18.361102
# Volume of path rule 370: 18.626277
# Volume of path rule 371: 18.419331
# Volume of path rule 372: 18.096892
# Volume of path rule 373: 17.886359
# Volume of path rule 374: 18.559116
# Volume of path rule 375: 18.765427
# Volume of path rule 376: 18.619047
# Volume of path rule 377: 18.602403
# Volume of path rule 378: 18.414408
# Volume of path rule 379: 18.918958
# Volume of path rule 380: 18.254789
# Volume of path rule 381: 17.939162
# Volume of path rule 382: 18.490186
# Volume of path rule 383: 17.803212
# Volume of path rule 384: 18.751474
# Volume of path rule 385: 19.304442
# Volume of path rule 386: 18.497768
# ...
# Volume of path rule 42: 18.468106
# Volume of path rule 43: 18.948914
# Volume of path rule 44: 19.222856
# Volume of path rule 45: 18.384798
# Volume of path rule 46: 18.818139
# Volume of path rule 47: 18.973740
# Volume of path rule 48: 18.658636
# Volume of path rule 49: 18.600081
# Volume of path rule 50: 17.620479
# Volume of path rule 51: 18.358363
# Volume of path rule 52: 18.392872
# Volume of path rule 53: 18.385643
# Volume of path rule 54: 19.051469
# Volume of path rule 55: 18.806727
# Volume of path rule 56: 19.410347
# Volume of path rule 57: 17.861271
# Volume of path rule 58: 18.283519
# Volume of path rule 59: 17.753021
# Volume of path rule 60: 19.137489
# Volume of path rule 61: 18.443857
# Volume of path rule 62: 17.868702
# Volume of path rule 63: 18.753381
# Volume of path rule 64: 18.754976
# Volume of path rule 65: 18.232404
# Volume of path rule 66: 19.451622
# Volume of path rule 67: 18.064944
# Volume of path rule 68: 18.712966
# Volume of path rule 69: 18.462757
# Volume of path rule 70: 17.904865
# Volume of path rule 71: 18.156662
# Volume of path rule 72: 18.662581
# Volume of path rule 73: 18.622943
# Volume of path rule 74: 18.445113
# Volume of path rule 75: 17.262613
# Volume of path rule 76: 17.222178
# Volume of path rule 77: 18.293502
# Volume of path rule 78: 17.899630
# Volume of path rule 79: 19.376752
# Volume of path rule 80: 18.184612
# Volume of path rule 81: 18.026775
# Volume of path rule 82: 18.098987
# Volume of path rule 83: 18.209057
# Volume of path rule 84: 19.197408
# Volume of path rule 85: 18.853948
# Volume of path rule 86: 18.596576
# Volume of path rule 87: 18.062277
# Volume of path rule 88: 18.143452
# Volume of path rule 89: 17.669578
# Volume of path rule 90: 17.250897
# Volume of path rule 91: 19.055742
# Volume of path rule 92: 18.030902
# Volume of path rule 93: 18.717217
# Volume of path rule 94: 19.258368
# Volume of path rule 95: 18.503809
# Volume of path rule 96: 18.358275
# Volume of path rule 97: 19.420338
# Volume of path rule 98: 17.393798
# Volume of path rule 99: 18.447498
# Volume of path rule 100: 18.369297
# Volume of path rule 101: 18.176768
# Volume of path rule 102: 19.029916
# Volume of path rule 103: 19.464918
# Volume of path rule 104: 18.227685
# Volume of path rule 105: 18.967252
# Volume of path rule 106: 18.480614
# Volume of path rule 107: 18.678000
# Volume of path rule 108: 18.087784
# Volume of path rule 109: 18.321260
# Volume of path rule 110: 18.420465
# Volume of path rule 111: 19.072672
# Volume of path rule 112: 17.968056
# Volume of path rule 113: 17.437241
# Volume of path rule 114: 18.663570
# Volume of path rule 115: 18.764015
# Volume of path rule 116: 18.326834
# Volume of path rule 117: 17.916248
# Volume of path rule 118: 17.953167
# Volume of path rule 119: 18.530999
# Volume of path rule 120: 18.944423
# Volume of path rule 121: 17.496811
# Volume of path rule 122: 17.881035
# Volume of path rule 123: 18.295846
# Volume of path rule 124: 17.477863
# Volume of path rule 125: 17.897550
# Volume of path rule 126: 18.075416
# Volume of path rule 127: 19.055849
# Volume of path rule 128: 17.881433
# Volume of path rule 129: 18.674849
# Volume of path rule 130: 18.507347
# Volume of path rule 131: 18.627198
# Volume of path rule 132: 17.918577
# Volume of path rule 133: 18.242038
# Volume of path rule 134: 18.671173
# Volume of path rule 135: 17.984282
# Volume of path rule 136: 18.332789
# Volume of path rule 137: 18.787452
# Volume of path rule 138: 16.561896
# Volume of path rule 139: 17.846862
# Volume of path rule 140: 18.894411
# Volume of path rule 141: 18.745954
# Volume of path rule 142: 18.819233
# Volume of path rule 143: 18.221972
# Volume of path rule 144: 18.110574
# Volume of path rule 145: 18.406983
# Volume of path rule 146: 17.932618
# Volume of path rule 147: 18.685428
# Volume of path rule 148: 18.155185
# Volume of path rule 149: 18.492691
# Volume of path rule 150: 18.110663
# Volume of path rule 151: 18.025788
# Volume of path rule 152: 18.727992
# Volume of path rule 153: 19.427467
# Volume of path rule 154: 18.780776
# Volume of path rule 155: 18.037628
# Volume of path rule 156: 17.868426
# Volume of path rule 157: 18.213091
# Volume of path rule 158: 16.986288
# Volume of path rule 159: 19.165447
# Volume of path rule 160: 18.567510
# Volume of path rule 161: 17.605534
# Volume of path rule 162: 18.662550
# Volume of path rule 163: 19.192053
# Volume of path rule 164: 18.798787
# Volume of path rule 165: 18.564285
# Volume of path rule 166: 18.697600
# Volume of path rule 167: 19.735860
# Volume of path rule 168: 18.714705
# Volume of path rule 169: 18.465765
# Volume of path rule 170: 19.167484
# Volume of path rule 171: 18.391282
# Volume of path rule 172: 18.093231
# Volume of path rule 173: 18.267160
# Volume of path rule 174: 19.748398
# Volume of path rule 175: 18.895138
# Volume of path rule 176: 18.768886
# Volume of path rule 177: 18.923917
# Volume of path rule 178: 18.492093
# Volume of path rule 179: 19.294031
# Volume of path rule 180: 17.895388
# Volume of path rule 181: 18.125804
# Volume of path rule 182: 18.738517
# Volume of path rule 183: 18.106013
# Volume of path rule 184: 18.224190
# Volume of path rule 185: 18.856240
# Volume of path rule 186: 17.803046
# Volume of path rule 187: 18.065388
# Volume of path rule 188: 17.141379
# Volume of path rule 189: 18.220132
# Volume of path rule 190: 18.961401
# Volume of path rule 191: 17.869383
# Volume of path rule 192: 17.983801
# Volume of path rule 193: 19.062128
# Volume of path rule 194: 17.832029
# Volume of path rule 195: 18.566181
# Volume of path rule 196: 18.451072
# Volume of path rule 197: 18.588214
# Volume of path rule 198: 17.967539
# Volume of path rule 199: 17.674573
# Volume of path rule 200: 19.428051
# Volume of path rule 201: 18.221055
# Volume of path rule 202: 19.021528
# Volume of path rule 203: 18.786100
# Volume of path rule 204: 18.883897
# Volume of path rule 205: 18.836614
# Volume of path rule 206: 18.431537
# Volume of path rule 207: 18.207377
# Volume of path rule 208: 18.802577
# Volume of path rule 209: 18.919924
# Volume of path rule 210: 18.325912
# Volume of path rule 211: 17.979844
# Volume of path rule 212: 19.027251
# Volume of path rule 213: 18.545838
# Volume of path rule 214: 19.552461
# Volume of path rule 215: 19.545390
# Volume of path rule 216: 18.409557
# Volume of path rule 217: 18.276284
# Volume of path rule 218: 17.845639
# Volume of path rule 219: 18.005594
# Volume of path rule 220: 19.128367
# Volume of path rule 221: 18.900458
# Volume of path rule 222: 18.598610
# Volume of path rule 223: 17.660204
# Volume of path rule 224: 17.771421
# Volume of path rule 225: 18.608118
# Volume of path rule 226: 19.004967
# Volume of path rule 227: 19.585550
# Volume of path rule 228: 17.846951
# Volume of path rule 229: 18.255280
# Volume of path rule 230: 19.247062
# Volume of path rule 231: 17.509094
# Volume of path rule 232: 17.725833
# Volume of path rule 233: 18.278314
# Volume of path rule 234: 18.981416
# Volume of path rule 235: 18.613939
# Volume of path rule 236: 18.708649
# Volume of path rule 237: 18.653643
# Volume of path rule 238: 17.925178
# Volume of path rule 239: 18.973045
# Volume of path rule 240: 17.974686
# Volume of path rule 241: 19.203725
# Volume of path rule 242: 19.199879
# Volume of path rule 243: 18.999719
# Volume of path rule 244: 18.973356
# Volume of path rule 245: 19.147664
# Volume of path rule 246: 18.814922
# Volume of path rule 247: 18.998452
# Volume of path rule 248: 19.099267
# Volume of path rule 249: 18.595079
# Volume of path rule 250: 18.614237
# Volume of path rule 251: 18.234844
# Volume of path rule 252: 18.918922
# Volume of path rule 253: 18.684703
# Volume of path rule 254: 18.359048
# Volume of path rule 255: 18.591426
# Volume of path rule 256: 18.968690
# Volume of path rule 257: 18.099075
# Volume of path rule 258: 18.381185
# Volume of path rule 259: 17.727203
# Volume of path rule 260: 18.847393
# Volume of path rule 261: 17.394263
# Volume of path rule 262: 18.367678
# Volume of path rule 263: 18.497440
# Volume of path rule 264: 18.832783
# Volume of path rule 265: 17.804079
# Volume of path rule 266: 18.703748
# Volume of path rule 267: 18.029911
# Volume of path rule 268: 17.604523
# Volume of path rule 269: 18.024804
# Volume of path rule 270: 17.732135
# Volume of path rule 271: 17.877510
# Volume of path rule 272: 18.697385
# Volume of path rule 273: 18.991177
# Volume of path rule 274: 18.534409
# Volume of path rule 275: 17.603475
# Volume of path rule 276: 19.370254
# Volume of path rule 277: 18.291571
# Volume of path rule 278: 18.100147
# Volume of path rule 279: 18.573010
# Volume of path rule 280: 19.502643
# Volume of path rule 281: 18.143035
# Volume of path rule 282: 18.203750
# Volume of path rule 283: 19.030361
# Volume of path rule 284: 17.996063
# Volume of path rule 285: 17.851190
# Volume of path rule 286: 17.957008
# Volume of path rule 287: 18.765652
# Volume of path rule 288: 18.309951
# Volume of path rule 289: 18.948572
# Volume of path rule 290: 18.069396
# Volume of path rule 291: 18.175227
# Volume of path rule 292: 18.370115
# Volume of path rule 293: 18.804042
# Volume of path rule 294: 18.125689
# Volume of path rule 295: 19.245397
# Volume of path rule 296: 19.066734
# Volume of path rule 297: 18.217512
# Volume of path rule 298: 18.773834
# Volume of path rule 299: 18.242013
# Volume of path rule 300: 18.075769
# Volume of path rule 301: 18.633100
# Volume of path rule 302: 18.036334
# Volume of path rule 303: 18.465289
# Volume of path rule 304: 18.629536
# Volume of path rule 305: 17.771040
# Volume of path rule 306: 17.463827
# Volume of path rule 307: 18.986354
# Volume of path rule 308: 19.189471
# Volume of path rule 309: 19.173328
# Volume of path rule 310: 18.427707
# Volume of path rule 311: 18.906106
# Volume of path rule 312: 18.167403
# Volume of path rule 313: 19.285736
# Volume of path rule 314: 18.342847
# Volume of path rule 315: 18.510455
# Volume of path rule 316: 17.109198
# Volume of path rule 317: 18.605724
# Volume of path rule 318: 17.588318
# Volume of path rule 319: 18.668908
# Volume of path rule 320: 18.053166
# Volume of path rule 321: 17.554561
# Volume of path rule 322: 19.020052
# Volume of path rule 323: 19.521268
# Volume of path rule 324: 18.794699
# Volume of path rule 325: 17.592269
# Volume of path rule 326: 18.537838
# Volume of path rule 327: 18.888561
# Volume of path rule 328: 18.075018
# Volume of path rule 329: 19.331558
# Volume of path rule 330: 18.659889
# Volume of path rule 331: 19.137342
# Volume of path rule 332: 18.944853
# Volume of path rule 333: 18.045425
# Volume of path rule 334: 18.598464
# Volume of path rule 335: 18.699039
# Volume of path rule 336: 17.184667
# Volume of path rule 337: 17.563058
# Volume of path rule 338: 19.359879
# Volume of path rule 339: 18.211204
# Volume of path rule 340: 17.870060
# Volume of path rule 341: 19.081049
# Volume of path rule 342: 17.417476
# Volume of path rule 343: 17.890403
# Volume of path rule 344: 18.548599
# Volume of path rule 345: 18.426515
# Volume of path rule 346: 18.265007
# Volume of path rule 347: 19.113759
# Volume of path rule 348: 18.169129
# Volume of path rule 349: 18.302590
# Volume of path rule 350: 18.599989
# Volume of path rule 351: 18.544629
# Volume of path rule 352: 18.226303
# Volume of path rule 353: 18.731002
# Volume of path rule 354: 17.832478
# Volume of path rule 355: 18.991243
# Volume of path rule 356: 18.682339
# Volume of path rule 357: 18.342804
# Volume of path rule 358: 18.650369
# Volume of path rule 359: 18.479569
# Volume of path rule 360: 18.924670
# Volume of path rule 361: 19.805300
# Volume of path rule 362: 17.969551
# Volume of path rule 363: 19.411828
# Volume of path rule 364: 18.445033
# Volume of path rule 365: 19.252338
# Volume of path rule 366: 18.875696
# Volume of path rule 367: 18.681728
# Volume of path rule 368: 18.205579
# Volume of path rule 369: 18.361102
# Volume of path rule 370: 18.486959
# Volume of path rule 371: 18.419331
# Volume of path rule 372: 18.096892
# Volume of path rule 373: 18.907147
# Volume of path rule 374: 18.367049
# Volume of path rule 375: 18.762899
# Volume of path rule 376: 17.798411
# Volume of path rule 377: 17.934057
# Volume of path rule 378: 18.414408
# Volume of path rule 379: 18.902414
# Volume of path rule 380: 18.959059
# Volume of path rule 381: 18.088210
# Volume of path rule 382: 18.490186
# Volume of path rule 383: 18.044476
# Volume of path rule 384: 19.131229
# Volume of path rule 385: 19.304442
# Volume of path rule 386: 18.497768
# Volume of path rule 387: 18.311503
# Volume of path rule 388: 18.556837
# Volume of path rule 389: 18.834202
# Volume of path rule 390: 18.345315
# Volume of path rule 391: 17.055295
# Volume of path rule 392: 19.638049
# Volume of path rule 393: 18.695349
# Volume of path rule 394: 17.715278
# Volume of path rule 395: 18.028817
# Volume of path rule 396: 18.159931
# Volume of path rule 397: 17.985775
# Volume of path rule 398: 19.158764
# Volume of path rule 399: 18.758120
# Volume of path rule 400: 18.680534
# Volume of path rule 401: 18.519162
# Volume of path rule 402: 18.602416
# Volume of path rule 403: 18.547798
# Volume of path rule 404: 19.073110
# Volume of path rule 405: 18.862634
# Volume of path rule 406: 18.702450
# Volume of path rule 407: 18.324986
# Volume of path rule 408: 17.371632
# Volume of path rule 409: 17.287120
# Volume of path rule 410: 18.524108
# Volume of path rule 411: 18.556533
# Volume of path rule 412: 19.175002
# Volume of path rule 413: 18.558419
# Volume of path rule 414: 18.840833
# Volume of path rule 415: 17.661230
# Volume of path rule 416: 19.538161
# Volume of path rule 417: 18.653534
# Volume of path rule 418: 18.052008
# Volume of path rule 419: 18.948203
# Volume of path rule 420: 16.990642
# Volume of path rule 421: 18.725610
# Volume of path rule 422: 18.495330
# Volume of path rule 423: 18.548645
# Volume of path rule 424: 19.389384
# Volume of path rule 425: 18.483071
# Volume of path rule 426: 18.211334
# Volume of path rule 427: 18.377252
# Volume of path rule 428: 18.788627
# Volume of path rule 429: 18.632828
# Volume of path rule 430: 18.083298
# Volume of path rule 431: 18.325011
# Volume of path rule 432: 19.558562
# Volume of path rule 433: 18.820603
# Volume of path rule 434: 19.429867
# Volume of path rule 435: 19.145873
# Volume of path rule 436: 17.974508
# Volume of path rule 437: 19.468287
# Volume of path rule 438: 19.536625
# Volume of path rule 439: 17.114073
# Volume of path rule 440: 17.926889
# Volume of path rule 441: 18.387502
# Volume of path rule 442: 18.758499
# Volume of path rule 443: 19.148407
# Volume of path rule 444: 19.215197
# Volume of path rule 445: 19.058279
# Volume of path rule 446: 17.817695
# Volume of path rule 447: 19.183883
# Volume of path rule 448: 18.838852
# Volume of path rule 449: 17.858514
# Volume of path rule 450: 18.497151
# Volume of path rule 451: 18.784145
# Volume of path rule 452: 18.040136
# Volume of path rule 453: 18.635691
# Volume of path rule 454: 18.482751
# Volume of path rule 455: 17.595088
# Volume of path rule 456: 18.819339
# Volume of path rule 457: 18.477603
# Volume of path rule 458: 18.305173
# Volume of path rule 459: 18.558025
# Volume of path rule 460: 17.501875
# Volume of path rule 461: 19.119295
# Volume of path rule 462: 18.838851
# Volume of path rule 463: 18.073018
# Volume of path rule 464: 19.258117
# Volume of path rule 465: 18.825324
# Volume of path rule 466: 17.915790
# Volume of path rule 467: 19.368576
# Volume of path rule 468: 18.329822
# Volume of path rule 469: 18.848365
# Volume of path rule 470: 18.710229
# Volume of path rule 471: 18.143102
# Volume of path rule 472: 18.509379
# Volume of path rule 473: 18.688810
# Volume of path rule 474: 17.881399
# Volume of path rule 475: 18.400943
# Volume of path rule 476: 17.926910
# Volume of path rule 477: 18.338781
# Volume of path rule 478: 19.104514
# Volume of path rule 479: 18.560024
# Volume of path rule 480: 18.879177
# Volume of path rule 481: 19.219992
# Volume of path rule 482: 19.347120
# Volume of path rule 483: 18.623814
# Volume of path rule 484: 17.713761
# Volume of path rule 485: 18.845996
# Volume of path rule 486: 18.262225
# Volume of path rule 487: 19.403075
# Volume of path rule 488: 18.681431
# Volume of path rule 489: 18.065428
# Volume of path rule 490: 18.506144
# Volume of path rule 491: 19.126092
# Volume of path rule 492: 17.796766
# Volume of path rule 493: 18.249002
# Volume of path rule 494: 17.956128
# Volume of path rule 495: 18.952543
# Volume of path rule 496: 18.969231
# Volume of path rule 497: 18.198825
# Volume of path rule 498: 17.873209
# Volume of path rule 499: 18.023870
# Volume of MCR: 1.180373

# %%
y_pred = np.array(results)

# %%
y_pred.shape
# Out:
# (500, 24)

# %% [markdown]
# ###**COSINE DISTANCE**

# %%
X_test.shape
# Out:
# (500, 24)

# %%
yt = X_test.flatten()
yt.shape
# Out:
# (12000,)

# %%
yp = y_pred.flatten()
yp.shape
# Out:
# (12000,)

# %%
from scipy.spatial.distance import cosine

cos_distance = cosine(yt, yp)

# %%
cos_distance
# Out:
# 0.0006003940203389568
