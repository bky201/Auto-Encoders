# %% [markdown]
# # **TEXT AUTO ENCODER USING SUPERVISED EFOREST ON IMDB TEXT DATASET WITH 1000 TREE**

# %%
from keras.datasets import imdb
import numpy as np

# %%
max_features= 100 # NUMBER OF WORD OR VOCABULARY SIZE
(X_tr, y_tr), (X_te, y_te) =  imdb.load_data(num_words=max_features)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
X_train = X_tr[:500]
y_train = y_tr[:500]
X_test = X_te[:500]
y_test = y_te[:500]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
print("Categories:", np.unique(y_train))
print("Number of unique words:", len(np.unique(np.hstack(X_train))))
# Out:
# Categories: [0 1]
# Number of unique words: 98

# %%
length = [len(i) for i in X_train]
print("Average Review length:", np.mean(length))
print("Standard Deviation:", round(np.std(length)))
# Out:
# Average Review length: 257.8
# Standard Deviation: 196

# %%
print("Label:", y_train[0])
print(X_train[0])
# Out:
# Label: 1
# [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 2, 36, 2, 5, 25, 2, 43, 2, 2, 50, 2, 2, 9, 35, 2, 2, 5, 2, 4, 2, 2, 2, 2, 2, 2, 39, 4, 2, 2, 2, 17, 2, 38, 13, 2, 4, 2, 50, 16, 6, 2, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 2, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 2, 12, 16, 38, 2, 5, 25, 2, 51, 36, 2, 48, 25, 2, 33, 6, 22, 12, 2, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 2, 2, 2, 15, 2, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 2, 88, 4, 2, 15, 2, 98, 32, 2, 56, 26, 2, 6, 2, 2, 18, 4, 2, 22, 21, 2, 2, 26, 2, 5, 2, 30, 2, 18, 51, 36, 28, 2, 92, 25, 2, 4, 2, 65, 16, 38, 2, 88, 12, 16, 2, 5, 16, 2, 2, 2, 32, 15, 16, 2, 19, 2, 32]

# %% [markdown]
# ##**Pre-processing**

# %%
# Used for pre-processing data
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import pandas as pd
from nltk import pos_tag
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocessing(text):
    #splits the word and checks each character to see if it contains any standard punctuations, 
    #if so it will be replaced with a blank or else it just don’t replace with blank
    text2 = " ".join("".join([" " if ch in string.punctuation else ch for ch in text]).split())
    
    #tokenizes the sentences into words based on whitespaces and puts them together as a list for applying further steps
    tokens = [word for sent in nltk.sent_tokenize(text2) for word in nltk.word_tokenize(sent)]
    
    #Converting all the cases (upper, lower and proper) into lower case reduces duplicates in corpus
    tokens = [word.lower() for word in tokens]
    
    #Stop words are the words that do not carry much of weight in understanding the sentence; 
    #they are used for connecting words and so on. We have removed them with the following line of code
    stopwds = stopwords.words('english')
    tokens = [token for token in tokens if token not in stopwds]
    
    #Stemming applied on the words using Porter stemmer which stems the extra suffixes from the words
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    
    #POS tagging is a prerequisite for lemmatization, based on whether the word 
    #is noun or verb or and so on. it will reduce it to the root word
    tagged_corpus = pos_tag(tokens)

    Noun_tags = ['NN','NNP','NNPS','NNS']
    Verb_tags = ['VB','VBD','VBG','VBN','VBP','VBZ']
    lemmatizer = WordNetLemmatizer()

    #  If the tag for any word falls under the respective noun or verb tags category, 
    #  n or v will be applied accordingly in lemmatize function
    def prat_lemmatize(token,tag):
        if tag in Noun_tags:
            return lemmatizer.lemmatize(token,'n')

        elif tag in Verb_tags:
            return lemmatizer.lemmatize(token,'v')
        else:
            return lemmatizer.lemmatize(token,'n')
    
    #we need to join it back to form stings and the following function performs the same
    pre_proc_text =   " ".join([prat_lemmatize(token,tag) for token,tag in tagged_corpus])

    return pre_proc_text

# %% [markdown]
# ###**PREPROCESSING ON TRAIN AND TEST DATA**

# %%
# A dictionary mapping words to an integer index
vocabulary = imdb.get_word_index()

index = dict([(value, key) for (key, value) in vocabulary.items()])

# %%
'''converts encoded text to human readable form.
    each integer in the text is looked up in the index, and 
    replaced by the corresponding word.
'''
X_train = [' '.join([index.get(i, '?') for i in x]) for x in X_train]
X_test = [' '.join([index.get(i, '?') for i in x]) for x in X_test]

# %%
X_train_preprocessed = []
for i in X_train:
    X_train_preprocessed.append(preprocessing(i))

X_test_preprocessed = []
for i in X_test:
    X_test_preprocessed.append(preprocessing(i))

# %%
X_train_preprocessed[0]
# Out:
# 'movi film get movi movi stori one br br one film'

# %%
X_test_preprocessed[0]
# Out:
# 'br one'

# %% [markdown]
# ### **BUILDING TF-IDF vectorizer**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# from keras.preprocessing.sequence import pad_sequences

vectorizer = TfidfVectorizer(max_features= max_features)
vectorizer.fit(X_train_preprocessed) 

X_train_2 = vectorizer.transform(X_train_preprocessed).todense()

X_test_2 = vectorizer.transform(X_test_preprocessed).todense()

# %%
np.set_printoptions(threshold=np.inf) # not usefull for this code just to prevent truncation of output result
print(X_train_2[0][:20])
# Out:
# [[0.         0.         0.30788979 0.         0.         0.40583095
#   0.         0.31603217 0.         0.         0.         0.
#   0.         0.57512642 0.         0.46078001 0.         0.
#   0.         0.31231423 0.         0.         0.         0.        ]]

# %% [markdown]
# ### **DEFINE NODE RULE**

# %%
import copy
import numpy as np

# %%
class NodeRule:

    LT = 0 # 'less than'
    LE = 1 # 'less or equal to'

    def __init__(self, attribute, threshold, op):
        # [lower_bound] [op_left] value [op_right] [upper_bound]
        assert(op in ['gt', 'le'])
        self.attribute = attribute
        if op == 'le':
            self.lower_bound = -np.inf
            self.upper_bound = threshold
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LE
        else:
            self.lower_bound = threshold
            self.upper_bound = np.inf
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LT
    
    def __and__(self, other):
        new_rule = copy.copy(self)
        if self.lower_bound > other.lower_bound:
            new_rule.lower_bound = self.lower_bound
            new_rule.op_left = self.op_left
        elif self.lower_bound < other.lower_bound:
            new_rule.lower_bound = other.lower_bound
            new_rule.op_left = other.op_left
        else:
            new_rule.lower_bound = self.lower_bound
            if NodeRule.LT in [self.op_left, other.op_left]:
                new_rule.op_left = NodeRule.LT
            else:
                new_rule.op_left = NodeRule.LE
        if self.upper_bound < other.upper_bound:
            new_rule.upper_bound = self.upper_bound
            new_rule.op_right = self.op_right
        elif self.upper_bound > other.upper_bound:
            new_rule.upper_bound = other.upper_bound
            new_rule.op_right = other.op_right
        else:
            new_rule.upper_bound = self.upper_bound
            if NodeRule.LT in [self.op_right, other.op_right]:
                new_rule.op_right = NodeRule.LT
            else:
                new_rule.op_right = NodeRule.LE
        return new_rule

    def __str__(self):
        s = str(self.lower_bound) + ' '
        s += '<=' if self.op_left == NodeRule.LE else '<'
        s += ' x_%i ' % self.attribute
        s += '<=' if self.op_right == NodeRule.LE else '<'
        s += ' ' + str(self.upper_bound)
        return s
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ### **DEFINE PATH RULE**

# %%
class PathRule:
    
    def __init__(self, n_attributes):
        self.n_attributes = n_attributes
        self.node_rules = [NodeRule(i, -np.inf, 'gt') for i in range(n_attributes)]
    
    def set_global_bounds(self, lower_bounds, upper_bounds):
        for i in range(self.n_attributes):
            node_rule = NodeRule(i, -np.inf, 'gt')
            node_rule.op_left = NodeRule.LE
            node_rule.op_right = NodeRule.LE
            node_rule.lower_bound = lower_bounds[i]
            node_rule.upper_bound = upper_bounds[i]
            self.add(node_rule)
    
    def add(self, node_rule):
        assert(isinstance(node_rule, NodeRule))
        j = node_rule.attribute
        self.node_rules[j] = self.node_rules[j].__and__(node_rule)
    
    def sample(self, sampling='mean'):
        sample = np.empty(self.n_attributes)
        for i, rule in enumerate(self):
            if sampling == 'mean':
                sample[i] = (rule.lower_bound + rule.upper_bound) / 2.
            else:
                sample[i] = np.random.uniform(rule.lower_bound, rule.upper_bound)
        return sample
    
    def compute_volume(self):
        log_volume = 1
        for i in range(self.n_attributes):
            node_rule = self.node_rules[i]
            log_volume += (node_rule.upper_bound - node_rule.lower_bound)
            assert(node_rule.upper_bound >= node_rule.lower_bound)
        return log_volume
    
    def __len__(self):
        return len(self.node_rules)
    
    def __iter__(self):
        self.current_attribute = 0
        return self
    
    def __next__(self):
        self.current_attribute += 1
        try:
            result = self.node_rules[self.current_attribute-1]
        except IndexError:
            raise StopIteration
        return result
    
    def __str__(self):
        return str(self.node_rules)
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## **RANDOME TREE MODEL**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import ExtraTreeRegressor

# %%
class CompletelyRandomTree:

    def __init__(self, sklearn_extra_tree, n_attributes):
        self.n_attributes = n_attributes
        self.tree = sklearn_extra_tree
        self.n_nodes = self.tree.tree_.node_count
        self.parent_ids = np.full(self.n_nodes, -1, dtype=np.int)
        self.operators = [None] * self.n_nodes
        tree = self.tree.tree_
        for i in range(self.n_nodes):
            parent_from_left = np.where(tree.children_left == i)[0]
            parent_from_right = np.where(tree.children_right == i)[0]
            if len(parent_from_left) == 1:
                self.parent_ids[i] = parent_from_left[0]
                self.operators[i] = 'le'
            elif len(parent_from_right) == 1:
                self.parent_ids[i] = parent_from_right[0]
                self.operators[i] = 'gt'
        self.leaf_to_node = np.where(tree.feature == -2)[0]
        self.node_to_leaf = {node_id: leaf_id for leaf_id, node_id in enumerate(self.leaf_to_node)}
        self.n_leafs = len(self.leaf_to_node)
    
    def encode(self, X):
        node_ids = self.tree.apply(X)
        return [self.node_to_leaf[node_id] for node_id in node_ids]
    
    def get_path_rule(self, default_path_rule, leaf_id):
        path_rule = copy.deepcopy(default_path_rule)
        tree = self.tree.tree_
        current_id = self.leaf_to_node[leaf_id]
        while current_id != 0:
            attribute = tree.feature[self.parent_ids[current_id]]
            bound = tree.threshold[self.parent_ids[current_id]]
            op = self.operators[current_id]
            path_rule.add(NodeRule(attribute, bound, op))
            current_id = self.parent_ids[current_id]
        return path_rule

# %% [markdown]
# ## **DEFINE ENCODER FOREST**

# %%
class EncoderForest:

    def __init__(self, n_components):
        self.trees = list()
        self.n_attributes = 0
        self.in_size = 0
        self.out_size = n_components
        self.global_lower_bounds = None
        self.global_upper_bounds = None
        self.default_path_rule = None
        self.unsupervised = True
    
    def fit(self, X, y=None, max_depth=10):
        self.unsupervised = (y is None)
        self.n_attributes = X.shape[1]
        self.in_size = X.shape[0]
        if y is None:
            forest = RandomTreesEmbedding(self.out_size, max_depth=max_depth)
            forest.fit(X)
        else:
            forest = RandomForestClassifier(n_estimators=self.out_size, max_depth=max_depth)
            forest.fit(X, y)
        for i in range(self.out_size):
            self.trees.append(CompletelyRandomTree(forest.estimators_[i], self.n_attributes))
        
        self.global_lower_bounds = np.min(X, axis=0).astype(np.double)
        self.global_upper_bounds = np.max(X, axis=0).astype(np.double)

        self.default_path_rule = PathRule(self.n_attributes)
        self.default_path_rule.set_global_bounds(self.global_lower_bounds, self.global_upper_bounds)
    
    def encode(self, X):
        n_samples = X.shape[0]
        out_dim = len(self.trees)
        encoded = np.empty((n_samples, out_dim), dtype=np.int)
        for i in range(out_dim):
            encoded[:, i] = self.trees[i].encode(X)
        return encoded

    def compute_rule_list(self, x):
        out_dim = len(self.trees)
        rule_list = list()
        for i in range(out_dim):
            path_rule = self.trees[i].get_path_rule(self.default_path_rule, x[i])
            rule_list.append(path_rule)
        return rule_list
    
    def decode(self, x):
        rule_list = self.compute_rule_list(x)
        MCR = self.calculate_MCR(rule_list)
        return MCR.sample(sampling='mean')

    def calculate_MCR(self, path_rule_list):
        MCR = copy.deepcopy(self.default_path_rule)
        n_attributes = len(MCR)
        n_trees = len(path_rule_list)

        for i in range(len(path_rule_list)):
            path_rule = path_rule_list[i]
            print("Volume of path rule %i: %f" % (i, path_rule.compute_volume()))
            for node_rule in path_rule.node_rules:
                MCR.add(node_rule)
        print("Volume of MCR: %f" % MCR.compute_volume())
        return MCR

# %%
X_train = np.array(X_train_2)
X_test = np.array(X_test_2)
y_train = np.array(y_train)
y_test = np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))
y_train = y_train.reshape((y_train.shape[0], -1))
y_test = y_test.reshape((y_test.shape[0], -1))
print("[IMDB] x_train.shape={}, y_train.shape={}".format(X_train.shape, y_train.shape))
print("[IMDB] x_test.shape={}, y_test.shape={}".format(X_test.shape, y_test.shape))
# Out:
# [IMDB] x_train.shape=(500, 24), y_train.shape=(500, 1)
# [IMDB] x_test.shape=(500, 24), y_test.shape=(500, 1)

# %%
print("Start Autoencoder using supervised model")
#eforest = RandomTreesEmbedding(n_estimators=n_trees, max_depth=None, n_jobs=-1, random_state=0)
encoder = EncoderForest(1000)
encoder.fit(X_train, y_train, max_depth=5)
print("end fit on supervised model")
# Out:
# Start Autoencoder using supervised model
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# end fit on supervised model

# %% [markdown]
# ### **MODEL EVALUATION**

# %%
X_encode = encoder.encode(X_test)

# %%
#X_encode = np.array(X_encode)

# %%
X_encode.shape
# Out:
# (500, 1000)

# %%
X_encode = np.array(X_encode)

# %%
X_encode.shape
# Out:
# (500, 1000)

# %%
results = []
for j in range(len(X_encode)):
    results.append(encoder.decode(X_encode[j]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Volume of path rule 5: 17.624471
# Volume of path rule 6: 17.254787
# Volume of path rule 7: 17.705798
# Volume of path rule 8: 17.190631
# Volume of path rule 9: 17.810939
# Volume of path rule 10: 17.291956
# Volume of path rule 11: 17.117383
# Volume of path rule 12: 18.160952
# Volume of path rule 13: 17.755573
# Volume of path rule 14: 17.702917
# Volume of path rule 15: 17.274361
# Volume of path rule 16: 17.905758
# Volume of path rule 17: 16.512898
# Volume of path rule 18: 17.077132
# Volume of path rule 19: 17.564866
# Volume of path rule 20: 17.480525
# Volume of path rule 21: 17.434655
# Volume of path rule 22: 16.877117
# Volume of path rule 23: 17.713651
# Volume of path rule 24: 17.346506
# Volume of path rule 25: 17.957052
# Volume of path rule 26: 16.528295
# Volume of path rule 27: 18.304829
# Volume of path rule 28: 17.326383
# Volume of path rule 29: 17.266560
# Volume of path rule 30: 18.178981
# Volume of path rule 31: 17.910117
# Volume of path rule 32: 17.572530
# Volume of path rule 33: 17.463994
# Volume of path rule 34: 17.763944
# Volume of path rule 35: 17.632958
# Volume of path rule 36: 17.525138
# Volume of path rule 37: 18.299193
# Volume of path rule 38: 17.329937
# Volume of path rule 39: 17.443879
# Volume of path rule 40: 17.259961
# Volume of path rule 41: 16.893081
# Volume of path rule 42: 17.711123
# Volume of path rule 43: 17.112469
# Volume of path rule 44: 17.206039
# Volume of path rule 45: 18.122407
# Volume of path rule 46: 17.243639
# Volume of path rule 47: 18.073002
# Volume of path rule 48: 18.272503
# Volume of path rule 49: 17.613546
# Volume of path rule 50: 17.931363
# Volume of path rule 51: 17.410680
# Volume of path rule 52: 18.083164
# Volume of path rule 53: 17.030731
# Volume of path rule 54: 17.651724
# Volume of path rule 55: 16.984376
# Volume of path rule 56: 17.370732
# Volume of path rule 57: 17.643640
# Volume of path rule 58: 17.790187
# Volume of path rule 59: 17.583318
# Volume of path rule 60: 17.656544
# Volume of path rule 61: 17.475917
# Volume of path rule 62: 17.654173
# Volume of path rule 63: 17.850448
# Volume of path rule 64: 17.268283
# Volume of path rule 65: 17.595547
# Volume of path rule 66: 17.106528
# Volume of path rule 67: 17.392358
# Volume of path rule 68: 16.799887
# Volume of path rule 69: 18.083967
# Volume of path rule 70: 16.892426
# Volume of path rule 71: 17.487098
# Volume of path rule 72: 17.375923
# Volume of path rule 73: 17.322044
# Volume of path rule 74: 17.168808
# Volume of path rule 75: 17.542506
# Volume of path rule 76: 17.997638
# Volume of path rule 77: 18.002104
# Volume of path rule 78: 17.679098
# Volume of path rule 79: 17.864067
# Volume of path rule 80: 16.959463
# Volume of path rule 81: 17.225928
# Volume of path rule 82: 17.772485
# Volume of path rule 83: 17.200533
# Volume of path rule 84: 17.785525
# Volume of path rule 85: 17.608849
# Volume of path rule 86: 17.689076
# Volume of path rule 87: 18.077563
# Volume of path rule 88: 17.804178
# Volume of path rule 89: 17.715745
# Volume of path rule 90: 17.851728
# Volume of path rule 91: 17.468923
# Volume of path rule 92: 17.821844
# Volume of path rule 93: 17.768632
# Volume of path rule 94: 18.450309
# Volume of path rule 95: 17.808934
# Volume of path rule 96: 17.877821
# Volume of path rule 97: 17.505342
# Volume of path rule 98: 17.298622
# Volume of path rule 99: 17.681432
# Volume of path rule 100: 17.167341
# Volume of path rule 101: 17.104738
# Volume of path rule 102: 17.948938
# Volume of path rule 103: 16.692692
# Volume of path rule 104: 17.158539
# Volume of path rule 105: 17.683228
# Volume of path rule 106: 17.755923
# Volume of path rule 107: 18.601289
# Volume of path rule 108: 16.918006
# Volume of path rule 109: 18.042212
# Volume of path rule 110: 17.508091
# Volume of path rule 111: 16.984020
# Volume of path rule 112: 17.389077
# Volume of path rule 113: 17.384856
# Volume of path rule 114: 18.003775
# Volume of path rule 115: 17.227587
# Volume of path rule 116: 17.764873
# Volume of path rule 117: 16.993928
# Volume of path rule 118: 17.696881
# Volume of path rule 119: 17.777205
# Volume of path rule 120: 16.921337
# Volume of path rule 121: 17.349433
# Volume of path rule 122: 17.069381
# Volume of path rule 123: 18.042696
# Volume of path rule 124: 17.199820
# Volume of path rule 125: 17.396846
# Volume of path rule 126: 17.637323
# Volume of path rule 127: 16.999646
# Volume of path rule 128: 18.013089
# Volume of path rule 129: 18.051054
# Volume of path rule 130: 17.303781
# Volume of path rule 131: 17.959081
# Volume of path rule 132: 17.975453
# Volume of path rule 133: 17.831270
# Volume of path rule 134: 17.822353
# Volume of path rule 135: 17.625624
# Volume of path rule 136: 17.305237
# Volume of path rule 137: 17.719826
# Volume of path rule 138: 17.250226
# Volume of path rule 139: 17.495739
# Volume of path rule 140: 18.070076
# Volume of path rule 141: 16.997003
# Volume of path rule 142: 18.126298
# Volume of path rule 143: 17.484421
# Volume of path rule 144: 17.545395
# Volume of path rule 145: 17.903703
# Volume of path rule 146: 17.508561
# Volume of path rule 147: 17.932169
# Volume of path rule 148: 17.500734
# Volume of path rule 149: 17.378634
# Volume of path rule 150: 17.493354
# Volume of path rule 151: 17.547861
# Volume of path rule 152: 17.123120
# Volume of path rule 153: 18.089248
# Volume of path rule 154: 17.230965
# Volume of path rule 155: 17.447640
# Volume of path rule 156: 17.627093
# Volume of path rule 157: 17.114901
# Volume of path rule 158: 17.418684
# Volume of path rule 159: 16.943085
# Volume of path rule 160: 17.163597
# Volume of path rule 161: 17.561387
# Volume of path rule 162: 17.674222
# Volume of path rule 163: 17.508265
# Volume of path rule 164: 17.367502
# Volume of path rule 165: 17.954392
# Volume of path rule 166: 17.448260
# Volume of path rule 167: 17.370042
# Volume of path rule 168: 17.707908
# Volume of path rule 169: 18.256536
# Volume of path rule 170: 17.933478
# Volume of path rule 171: 17.116161
# Volume of path rule 172: 17.142015
# Volume of path rule 173: 17.332892
# Volume of path rule 174: 17.592573
# Volume of path rule 175: 17.394271
# Volume of path rule 176: 17.217261
# Volume of path rule 177: 17.878559
# Volume of path rule 178: 17.216493
# Volume of path rule 179: 17.675824
# Volume of path rule 180: 17.054066
# Volume of path rule 181: 17.462670
# Volume of path rule 182: 19.883661
# Volume of path rule 183: 17.251282
# Volume of path rule 184: 17.534411
# Volume of path rule 185: 17.424473
# Volume of path rule 186: 17.649318
# Volume of path rule 187: 17.313813
# Volume of path rule 188: 17.695182
# Volume of path rule 189: 17.675501
# Volume of path rule 190: 17.789016
# Volume of path rule 191: 17.055767
# Volume of path rule 192: 16.985764
# Volume of path rule 193: 17.242371
# Volume of path rule 194: 17.911640
# Volume of path rule 195: 17.566255
# Volume of path rule 196: 18.302377
# Volume of path rule 197: 18.105080
# Volume of path rule 198: 17.642681
# Volume of path rule 199: 17.839509
# Volume of path rule 200: 18.709325
# Volume of path rule 201: 17.688126
# Volume of path rule 202: 17.932122
# Volume of path rule 203: 16.500020
# Volume of path rule 204: 17.537350
# Volume of path rule 205: 17.174970
# Volume of path rule 206: 17.007897
# Volume of path rule 207: 17.161330
# Volume of path rule 208: 17.367388
# Volume of path rule 209: 17.579748
# Volume of path rule 210: 17.575226
# Volume of path rule 211: 17.086386
# Volume of path rule 212: 17.769651
# Volume of path rule 213: 17.519100
# Volume of path rule 214: 16.966532
# Volume of path rule 215: 17.392072
# Volume of path rule 216: 16.915973
# Volume of path rule 217: 17.456970
# Volume of path rule 218: 17.543390
# Volume of path rule 219: 17.067223
# Volume of path rule 220: 16.871038
# Volume of path rule 221: 17.603202
# Volume of path rule 222: 17.034325
# Volume of path rule 223: 18.162764
# Volume of path rule 224: 17.526555
# Volume of path rule 225: 17.114318
# Volume of path rule 226: 18.868571
# Volume of path rule 227: 17.759528
# Volume of path rule 228: 17.160127
# Volume of path rule 229: 17.607876
# Volume of path rule 230: 17.175949
# Volume of path rule 231: 18.506104
# Volume of path rule 232: 17.632682
# Volume of path rule 233: 17.696372
# Volume of path rule 234: 17.858862
# Volume of path rule 235: 17.481169
# Volume of path rule 236: 17.650946
# Volume of path rule 237: 17.955624
# Volume of path rule 238: 17.577235
# Volume of path rule 239: 17.654430
# Volume of path rule 240: 18.070644
# Volume of path rule 241: 18.041694
# Volume of path rule 242: 17.647984
# Volume of path rule 243: 17.937748
# Volume of path rule 244: 17.170697
# Volume of path rule 245: 17.800523
# Volume of path rule 246: 17.657820
# Volume of path rule 247: 17.037570
# Volume of path rule 248: 17.306646
# Volume of path rule 249: 17.229776
# Volume of path rule 250: 17.676304
# Volume of path rule 251: 18.211375
# Volume of path rule 252: 17.731543
# Volume of path rule 253: 17.843275
# Volume of path rule 254: 17.415218
# Volume of path rule 255: 17.116803
# Volume of path rule 256: 16.348815
# Volume of path rule 257: 17.529589
# Volume of path rule 258: 17.157426
# Volume of path rule 259: 17.683386
# Volume of path rule 260: 17.106032
# Volume of path rule 261: 17.497304
# Volume of path rule 262: 17.158431
# Volume of path rule 263: 18.027839
# Volume of path rule 264: 17.842534
# Volume of path rule 265: 17.211398
# Volume of path rule 266: 17.393802
# Volume of path rule 267: 18.369345
# Volume of path rule 268: 18.039336
# Volume of path rule 269: 17.886658
# Volume of path rule 270: 17.016174
# Volume of path rule 271: 18.269993
# Volume of path rule 272: 17.224707
# Volume of path rule 273: 17.790303
# Volume of path rule 274: 18.052068
# Volume of path rule 275: 17.623456
# Volume of path rule 276: 17.244660
# Volume of path rule 277: 17.174365
# Volume of path rule 278: 17.097257
# Volume of path rule 279: 17.957298
# Volume of path rule 280: 17.537907
# Volume of path rule 281: 17.424161
# Volume of path rule 282: 17.492384
# Volume of path rule 283: 16.717904
# Volume of path rule 284: 17.429111
# Volume of path rule 285: 17.011002
# Volume of path rule 286: 17.718711
# Volume of path rule 287: 17.422602
# Volume of path rule 288: 17.399617
# Volume of path rule 289: 17.313744
# Volume of path rule 290: 17.068347
# Volume of path rule 291: 17.493880
# Volume of path rule 292: 18.307481
# Volume of path rule 293: 17.461542
# Volume of path rule 294: 16.972922
# Volume of path rule 295: 17.374980
# Volume of path rule 296: 17.593850
# Volume of path rule 297: 17.254154
# Volume of path rule 298: 17.395372
# Volume of path rule 299: 17.808028
# Volume of path rule 300: 17.627641
# Volume of path rule 301: 17.510532
# Volume of path rule 302: 17.050606
# Volume of path rule 303: 17.958235
# Volume of path rule 304: 17.295974
# Volume of path rule 305: 17.625103
# Volume of path rule 306: 17.517344
# Volume of path rule 307: 18.044487
# Volume of path rule 308: 17.902855
# Volume of path rule 309: 17.678381
# Volume of path rule 310: 17.024818
# Volume of path rule 311: 17.745898
# Volume of path rule 312: 17.816062
# Volume of path rule 313: 17.365003
# Volume of path rule 314: 16.797209
# Volume of path rule 315: 17.908200
# Volume of path rule 316: 16.955847
# Volume of path rule 317: 17.436304
# Volume of path rule 318: 17.902672
# Volume of path rule 319: 17.298692
# Volume of path rule 320: 17.521660
# Volume of path rule 321: 17.312500
# Volume of path rule 322: 17.557136
# Volume of path rule 323: 17.336855
# Volume of path rule 324: 17.507070
# Volume of path rule 325: 17.228748
# Volume of path rule 326: 17.607714
# Volume of path rule 327: 17.332148
# Volume of path rule 328: 17.651671
# Volume of path rule 329: 17.139549
# Volume of path rule 330: 17.209384
# Volume of path rule 331: 19.062816
# Volume of path rule 332: 18.268500
# Volume of path rule 333: 17.342471
# Volume of path rule 334: 17.870735
# Volume of path rule 335: 18.110876
# Volume of path rule 336: 18.782005
# Volume of path rule 337: 17.410221
# Volume of path rule 338: 17.624846
# Volume of path rule 339: 17.688453
# Volume of path rule 340: 17.999328
# Volume of path rule 341: 17.781610
# Volume of path rule 342: 17.107855
# Volume of path rule 343: 17.024127
# Volume of path rule 344: 17.902679
# Volume of path rule 345: 17.738844
# Volume of path rule 346: 17.563443
# Volume of path rule 347: 17.515146
# Volume of path rule 348: 17.508346
# Volume of path rule 349: 17.220408
# Volume of path rule 350: 17.354955
# Volume of path rule 351: 17.252146
# Volume of path rule 352: 17.448527
# Volume of path rule 353: 17.342302
# Volume of path rule 354: 17.256315
# Volume of path rule 355: 17.548583
# Volume of path rule 356: 18.439314
# Volume of path rule 357: 17.850310
# Volume of path rule 358: 17.189066
# Volume of path rule 359: 17.522359
# Volume of path rule 360: 17.137105
# Volume of path rule 361: 17.499823
# Volume of path rule 362: 17.564717
# Volume of path rule 363: 17.382603
# Volume of path rule 364: 17.895603
# Volume of path rule 365: 17.600497
# Volume of path rule 366: 17.383763
# Volume of path rule 367: 17.220149
# Volume of path rule 368: 17.238984
# Volume of path rule 369: 17.434674
# Volume of path rule 370: 17.423800
# Volume of path rule 371: 17.938511
# Volume of path rule 372: 18.430296
# Volume of path rule 373: 17.012065
# Volume of path rule 374: 17.655157
# Volume of path rule 375: 17.624215
# Volume of path rule 376: 16.984451
# Volume of path rule 377: 16.672060
# Volume of path rule 378: 17.746483
# Volume of path rule 379: 17.222711
# Volume of path rule 380: 18.148419
# Volume of path rule 381: 16.956920
# Volume of path rule 382: 17.248862
# Volume of path rule 383: 17.138911
# Volume of path rule 384: 17.025790
# Volume of path rule 385: 17.491647
# Volume of path rule 386: 17.394402
# Volume of path rule 387: 16.800056
# Volume of path rule 388: 17.838885
# Volume of path rule 389: 17.445407
# Volume of path rule 390: 17.906409
# Volume of path rule 391: 17.464954
# Volume of path rule 392: 17.088425
# Volume of path rule 393: 17.042886
# Volume of path rule 394: 17.263038
# Volume of path rule 395: 17.420125
# Volume of path rule 396: 17.731866
# Volume of path rule 397: 17.269186
# Volume of path rule 398: 17.732744
# Volume of path rule 399: 17.608779
# Volume of path rule 400: 17.546069
# Volume of path rule 401: 18.012823
# Volume of path rule 402: 17.287985
# Volume of path rule 403: 17.483779
# Volume of path rule 404: 17.256243
# Volume of path rule 405: 17.372110
# Volume of path rule 406: 17.665843
# Volume of path rule 407: 17.730711
# Volume of path rule 408: 17.449327
# Volume of path rule 409: 17.392222
# Volume of path rule 410: 17.514136
# Volume of path rule 411: 16.742587
# Volume of path rule 412: 17.131236
# Volume of path rule 413: 17.748494
# Volume of path rule 414: 17.396715
# Volume of path rule 415: 17.713923
# Volume of path rule 416: 16.867765
# Volume of path rule 417: 18.254516
# Volume of path rule 418: 17.979529
# Volume of path rule 419: 17.422075
# Volume of path rule 420: 17.433081
# Volume of path rule 421: 17.170945
# Volume of path rule 422: 17.239992
# Volume of path rule 423: 17.551165
# Volume of path rule 424: 17.694704
# Volume of path rule 425: 17.438323
# Volume of path rule 426: 17.698652
# Volume of path rule 427: 17.066711
# Volume of path rule 428: 17.196882
# Volume of path rule 429: 18.085836
# Volume of path rule 430: 17.057257
# Volume of path rule 431: 17.339345
# Volume of path rule 432: 17.621895
# Volume of path rule 433: 17.535776
# Volume of path rule 434: 17.897224
# Volume of path rule 435: 17.278327
# Volume of path rule 436: 17.766674
# Volume of path rule 437: 18.287173
# Volume of path rule 438: 17.251030
# Volume of path rule 439: 18.240404
# Volume of path rule 440: 16.982303
# Volume of path rule 441: 18.321190
# Volume of path rule 442: 18.052667
# Volume of path rule 443: 17.318605
# Volume of path rule 444: 17.844212
# Volume of path rule 445: 17.097651
# Volume of path rule 446: 17.955028
# Volume of path rule 447: 17.465586
# Volume of path rule 448: 16.792295
# Volume of path rule 449: 17.656828
# Volume of path rule 450: 18.203848
# Volume of path rule 451: 17.366134
# Volume of path rule 452: 17.419019
# Volume of path rule 453: 17.652965
# Volume of path rule 454: 18.134022
# Volume of path rule 455: 17.630387
# Volume of path rule 456: 17.111344
# Volume of path rule 457: 17.061153
# Volume of path rule 458: 17.683988
# Volume of path rule 459: 18.528681
# Volume of path rule 460: 17.358897
# Volume of path rule 461: 17.615957
# Volume of path rule 462: 17.249167
# Volume of path rule 463: 17.274476
# Volume of path rule 464: 17.681288
# Volume of path rule 465: 17.849306
# Volume of path rule 466: 18.481826
# Volume of path rule 467: 17.713509
# Volume of path rule 468: 17.681827
# Volume of path rule 469: 17.297486
# Volume of path rule 470: 17.331775
# Volume of path rule 471: 18.171130
# Volume of path rule 472: 17.903167
# Volume of path rule 473: 17.235547
# Volume of path rule 474: 16.797762
# Volume of path rule 475: 16.944846
# Volume of path rule 476: 17.475703
# Volume of path rule 477: 17.397933
# Volume of path rule 478: 17.577517
# Volume of path rule 479: 17.509583
# Volume of path rule 480: 17.273006
# Volume of path rule 481: 17.565549
# Volume of path rule 482: 17.665871
# Volume of path rule 483: 17.821324
# Volume of path rule 484: 18.167743
# Volume of path rule 485: 17.519823
# Volume of path rule 486: 17.073457
# Volume of path rule 487: 17.694173
# Volume of path rule 488: 17.852047
# Volume of path rule 489: 17.949209
# Volume of path rule 490: 17.198088
# Volume of path rule 491: 17.148517
# Volume of path rule 492: 16.987760
# Volume of path rule 493: 17.754170
# Volume of path rule 494: 17.730462
# Volume of path rule 495: 17.589948
# Volume of path rule 496: 17.966091
# Volume of path rule 497: 18.410419
# Volume of path rule 498: 17.325237
# Volume of path rule 499: 18.023242
# Volume of path rule 500: 17.871681
# Volume of path rule 501: 17.582724
# Volume of path rule 502: 18.542467
# Volume of path rule 503: 17.739505
# Volume of path rule 504: 17.524518
# Volume of path rule 505: 17.167529
# Volume of path rule 506: 17.184065
# Volume of path rule 507: 17.781959
# Volume of path rule 508: 18.077322
# Volume of path rule 509: 17.593187
# Volume of path rule 510: 17.286462
# Volume of path rule 511: 17.451914
# Volume of path rule 512: 17.082038
# Volume of path rule 513: 17.538348
# Volume of path rule 514: 18.003976
# Volume of path rule 515: 17.944349
# Volume of path rule 516: 18.039706
# Volume of path rule 517: 17.448659
# Volume of path rule 518: 17.394073
# Volume of path rule 519: 17.261787
# Volume of path rule 520: 17.831747
# Volume of path rule 521: 17.649324
# Volume of path rule 522: 17.394601
# Volume of path rule 523: 17.337616
# Volume of path rule 524: 17.701100
# Volume of path rule 525: 17.019732
# Volume of path rule 526: 18.363174
# Volume of path rule 527: 18.087852
# Volume of path rule 528: 17.863805
# Volume of path rule 529: 17.311463
# Volume of path rule 530: 17.327582
# Volume of path rule 531: 17.726610
# Volume of path rule 532: 17.120626
# Volume of path rule 533: 17.503738
# Volume of path rule 534: 17.398676
# Volume of path rule 535: 17.955830
# Volume of path rule 536: 17.703930
# Volume of path rule 537: 17.122163
# Volume of path rule 538: 16.710746
# Volume of path rule 539: 17.629178
# Volume of path rule 540: 17.083497
# Volume of path rule 541: 18.243637
# Volume of path rule 542: 17.289914
# Volume of path rule 543: 17.329225
# Volume of path rule 544: 17.738167
# Volume of path rule 545: 17.216870
# Volume of path rule 546: 17.392998
# Volume of path rule 547: 17.076306
# Volume of path rule 548: 18.215431
# Volume of path rule 549: 17.912322
# Volume of path rule 550: 18.065730
# Volume of path rule 551: 17.312834
# Volume of path rule 552: 17.970077
# Volume of path rule 553: 18.656704
# Volume of path rule 554: 17.356551
# Volume of path rule 555: 17.305676
# Volume of path rule 556: 17.387766
# Volume of path rule 557: 17.754255
# Volume of path rule 558: 17.114061
# Volume of path rule 559: 17.702937
# Volume of path rule 560: 17.323003
# Volume of path rule 561: 16.882412
# Volume of path rule 562: 18.185923
# Volume of path rule 563: 17.235525
# Volume of path rule 564: 17.023145
# Volume of path rule 565: 17.276093
# Volume of path rule 566: 16.837593
# Volume of path rule 567: 17.463569
# Volume of path rule 568: 17.611706
# Volume of path rule 569: 17.255646
# Volume of path rule 570: 18.142246
# Volume of path rule 571: 17.152592
# Volume of path rule 572: 17.786157
# Volume of path rule 573: 17.102627
# Volume of path rule 574: 17.545260
# Volume of path rule 575: 17.385549
# Volume of path rule 576: 16.845173
# Volume of path rule 577: 17.692141
# Volume of path rule 578: 17.570278
# Volume of path rule 579: 17.169786
# Volume of path rule 580: 17.489856
# Volume of path rule 581: 17.846746
# Volume of path rule 582: 16.893505
# Volume of path rule 583: 17.416592
# Volume of path rule 584: 18.018601
# Volume of path rule 585: 17.374157
# Volume of path rule 586: 18.066698
# Volume of path rule 587: 17.477447
# Volume of path rule 588: 17.482153
# Volume of path rule 589: 17.629783
# Volume of path rule 590: 17.201232
# Volume of path rule 591: 17.362464
# Volume of path rule 592: 17.214482
# Volume of path rule 593: 17.027815
# Volume of path rule 594: 17.276285
# Volume of path rule 595: 18.229436
# Volume of path rule 596: 17.687694
# Volume of path rule 597: 17.122036
# Volume of path rule 598: 18.102584
# Volume of path rule 599: 18.131004
# Volume of path rule 600: 17.271902
# Volume of path rule 601: 18.272685
# Volume of path rule 602: 16.802772
# Volume of path rule 603: 16.914333
# Volume of path rule 604: 17.271077
# Volume of path rule 605: 18.672098
# Volume of path rule 606: 16.844182
# Volume of path rule 607: 17.971028
# Volume of path rule 608: 16.919137
# Volume of path rule 609: 17.598967
# Volume of path rule 610: 17.262321
# Volume of path rule 611: 17.784149
# Volume of path rule 612: 17.100831
# Volume of path rule 613: 17.959309
# Volume of path rule 614: 17.023952
# Volume of path rule 615: 17.394463
# Volume of path rule 616: 17.282334
# Volume of path rule 617: 17.865797
# Volume of path rule 618: 17.857785
# Volume of path rule 619: 17.357118
# Volume of path rule 620: 17.826807
# Volume of path rule 621: 17.532718
# Volume of path rule 622: 16.960779
# Volume of path rule 623: 17.824597
# Volume of path rule 624: 17.069619
# Volume of path rule 625: 17.671451
# Volume of path rule 626: 17.380047
# Volume of path rule 627: 16.669965
# Volume of path rule 628: 17.350930
# Volume of path rule 629: 17.612486
# Volume of path rule 630: 17.889718
# Volume of path rule 631: 17.377990
# Volume of path rule 632: 17.741928
# Volume of path rule 633: 17.206488
# Volume of path rule 634: 18.022732
# Volume of path rule 635: 17.741670
# Volume of path rule 636: 17.143663
# Volume of path rule 637: 17.653083
# Volume of path rule 638: 17.426095
# Volume of path rule 639: 17.648710
# Volume of path rule 640: 17.781026
# Volume of path rule 641: 17.603981
# Volume of path rule 642: 17.136428
# Volume of path rule 643: 17.710632
# Volume of path rule 644: 17.560815
# Volume of path rule 645: 17.900558
# Volume of path rule 646: 17.585839
# Volume of path rule 647: 17.865515
# Volume of path rule 648: 17.053524
# Volume of path rule 649: 18.203491
# Volume of path rule 650: 17.711624
# Volume of path rule 651: 17.074622
# Volume of path rule 652: 16.966587
# Volume of path rule 653: 17.234148
# Volume of path rule 654: 18.105040
# Volume of path rule 655: 17.594600
# Volume of path rule 656: 17.215316
# Volume of path rule 657: 17.334814
# Volume of path rule 658: 17.055613
# Volume of path rule 659: 17.273231
# Volume of path rule 660: 18.664143
# Volume of path rule 661: 16.967577
# Volume of path rule 662: 16.941632
# Volume of path rule 663: 17.424344
# Volume of path rule 664: 17.474181
# Volume of path rule 665: 17.551350
# Volume of path rule 666: 17.038447
# Volume of path rule 667: 17.559232
# Volume of path rule 668: 17.200284
# Volume of path rule 669: 17.973110
# Volume of path rule 670: 17.009302
# Volume of path rule 671: 17.671052
# Volume of path rule 672: 17.083439
# Volume of path rule 673: 18.294392
# Volume of path rule 674: 17.921700
# Volume of path rule 675: 17.842449
# Volume of path rule 676: 16.875405
# Volume of path rule 677: 18.027626
# Volume of path rule 678: 17.613497
# Volume of path rule 679: 17.385462
# Volume of path rule 680: 17.931382
# Volume of path rule 681: 17.411140
# Volume of path rule 682: 16.684532
# Volume of path rule 683: 17.599423
# Volume of path rule 684: 18.012236
# Volume of path rule 685: 18.245840
# Volume of path rule 686: 17.611387
# Volume of path rule 687: 17.464495
# Volume of path rule 688: 17.379757
# Volume of path rule 689: 17.686545
# Volume of path rule 690: 17.868397
# Volume of path rule 691: 16.927248
# Volume of path rule 692: 17.557467
# Volume of path rule 693: 17.999600
# Volume of path rule 694: 17.418138
# Volume of path rule 695: 17.044920
# Volume of path rule 696: 17.890470
# Volume of path rule 697: 17.274302
# Volume of path rule 698: 18.054275
# Volume of path rule 699: 17.470687
# Volume of path rule 700: 17.052526
# Volume of path rule 701: 17.963643
# Volume of path rule 702: 17.086787
# Volume of path rule 703: 17.613140
# Volume of path rule 704: 17.795110
# Volume of path rule 705: 17.276949
# Volume of path rule 706: 17.977150
# Volume of path rule 707: 18.342979
# Volume of path rule 708: 17.628886
# Volume of path rule 709: 17.718294
# Volume of path rule 710: 17.315687
# Volume of path rule 711: 17.894317
# Volume of path rule 712: 17.987727
# Volume of path rule 713: 18.202613
# Volume of path rule 714: 17.637219
# Volume of path rule 715: 17.135951
# Volume of path rule 716: 17.475006
# Volume of path rule 717: 17.913146
# Volume of path rule 718: 17.625065
# Volume of path rule 719: 17.220450
# Volume of path rule 720: 17.663320
# Volume of path rule 721: 17.535302
# Volume of path rule 722: 16.984634
# Volume of path rule 723: 17.331481
# Volume of path rule 724: 17.458533
# Volume of path rule 725: 17.326973
# Volume of path rule 726: 16.999939
# Volume of path rule 727: 18.160990
# Volume of path rule 728: 16.944062
# Volume of path rule 729: 17.190680
# Volume of path rule 730: 17.533567
# Volume of path rule 731: 17.804399
# Volume of path rule 732: 17.020504
# Volume of path rule 733: 17.212131
# Volume of path rule 734: 17.063137
# Volume of path rule 735: 17.556936
# Volume of path rule 736: 17.113936
# Volume of path rule 737: 17.753722
# Volume of path rule 738: 17.442259
# Volume of path rule 739: 18.045715
# Volume of path rule 740: 17.788229
# Volume of path rule 741: 18.415135
# Volume of path rule 742: 17.980144
# Volume of path rule 743: 17.958934
# Volume of path rule 744: 17.177943
# Volume of path rule 745: 17.207719
# Volume of path rule 746: 17.634873
# Volume of path rule 747: 17.352648
# Volume of path rule 748: 17.759211
# Volume of path rule 749: 18.373479
# Volume of path rule 750: 17.601553
# Volume of path rule 751: 16.887340
# Volume of path rule 752: 17.599830
# Volume of path rule 753: 17.649402
# Volume of path rule 754: 17.348583
# Volume of path rule 755: 17.250011
# Volume of path rule 756: 18.008561
# Volume of path rule 757: 17.503204
# Volume of path rule 758: 16.731436
# Volume of path rule 759: 18.775555
# Volume of path rule 760: 17.611120
# Volume of path rule 761: 16.849764
# Volume of path rule 762: 17.078514
# Volume of path rule 763: 17.331520
# Volume of path rule 764: 17.537810
# Volume of path rule 765: 17.255566
# Volume of path rule 766: 17.658934
# Volume of path rule 767: 18.073111
# Volume of path rule 768: 18.078704
# Volume of path rule 769: 18.233968
# Volume of path rule 770: 17.485390
# Volume of path rule 771: 17.112972
# Volume of path rule 772: 18.017668
# Volume of path rule 773: 17.927899
# Volume of path rule 774: 17.428223
# Volume of path rule 775: 17.563709
# Volume of path rule 776: 17.913143
# Volume of path rule 777: 17.982880
# Volume of path rule 778: 17.403017
# Volume of path rule 779: 17.239754
# Volume of path rule 780: 16.886367
# Volume of path rule 781: 16.864954
# Volume of path rule 782: 17.439069
# Volume of path rule 783: 16.801350
# Volume of path rule 784: 17.407157
# Volume of path rule 785: 17.396926
# Volume of path rule 786: 16.736567
# Volume of path rule 787: 18.365864
# Volume of path rule 788: 17.397962
# Volume of path rule 789: 17.842163
# Volume of path rule 790: 17.512008
# Volume of path rule 791: 17.760493
# Volume of path rule 792: 17.487700
# Volume of path rule 793: 18.259552
# Volume of path rule 794: 17.395181
# Volume of path rule 795: 17.786415
# Volume of path rule 796: 17.458876
# Volume of path rule 797: 18.395479
# Volume of path rule 798: 18.193546
# Volume of path rule 799: 17.135722
# Volume of path rule 800: 17.502043
# Volume of path rule 801: 16.853197
# Volume of path rule 802: 17.472442
# Volume of path rule 803: 17.722459
# Volume of path rule 804: 17.379665
# Volume of path rule 805: 18.104193
# Volume of path rule 806: 17.626993
# Volume of path rule 807: 17.273078
# Volume of path rule 808: 17.921639
# Volume of path rule 809: 18.201697
# Volume of path rule 810: 17.509104
# Volume of path rule 811: 17.334497
# Volume of path rule 812: 17.491477
# Volume of path rule 813: 17.115974
# Volume of path rule 814: 17.279380
# Volume of path rule 815: 18.224406
# Volume of path rule 816: 17.916903
# Volume of path rule 817: 17.426254
# Volume of path rule 818: 17.772021
# Volume of path rule 819: 18.179435
# Volume of path rule 820: 17.680695
# Volume of path rule 821: 17.210983
# Volume of path rule 822: 17.303304
# Volume of path rule 823: 17.274123
# Volume of path rule 824: 17.949806
# Volume of path rule 825: 17.166109
# Volume of path rule 826: 17.041737
# Volume of path rule 827: 17.298966
# Volume of path rule 828: 17.368220
# Volume of path rule 829: 17.404748
# Volume of path rule 830: 16.970468
# Volume of path rule 831: 17.388814
# Volume of path rule 832: 17.783857
# Volume of path rule 833: 18.024282
# Volume of path rule 834: 17.820824
# Volume of path rule 835: 17.245744
# Volume of path rule 836: 17.644916
# Volume of path rule 837: 18.206863
# Volume of path rule 838: 17.770156
# Volume of path rule 839: 17.234700
# Volume of path rule 840: 17.265017
# Volume of path rule 841: 17.438090
# Volume of path rule 842: 17.164272
# Volume of path rule 843: 17.345196
# Volume of path rule 844: 17.426457
# Volume of path rule 845: 17.570595
# Volume of path rule 846: 17.228838
# Volume of path rule 847: 16.794065
# Volume of path rule 848: 16.812351
# Volume of path rule 849: 17.462812
# Volume of path rule 850: 17.118640
# Volume of path rule 851: 17.992117
# Volume of path rule 852: 17.719145
# Volume of path rule 853: 17.190576
# Volume of path rule 854: 17.509020
# Volume of path rule 855: 17.710438
# Volume of path rule 856: 17.393418
# Volume of path rule 857: 17.075531
# Volume of path rule 858: 17.111203
# Volume of path rule 859: 17.882983
# Volume of path rule 860: 17.621120
# Volume of path rule 861: 17.258343
# Volume of path rule 862: 17.530691
# Volume of path rule 863: 17.524526
# Volume of path rule 864: 17.391488
# Volume of path rule 865: 18.280722
# Volume of path rule 866: 17.074071
# Volume of path rule 867: 17.603908
# Volume of path rule 868: 17.069254
# Volume of path rule 869: 17.661340
# Volume of path rule 870: 17.184049
# Volume of path rule 871: 17.743316
# Volume of path rule 872: 17.367971
# Volume of path rule 873: 16.843460
# Volume of path rule 874: 17.660872
# Volume of path rule 875: 17.433534
# Volume of path rule 876: 17.074530
# Volume of path rule 877: 17.120061
# Volume of path rule 878: 17.391504
# Volume of path rule 879: 18.355086
# Volume of path rule 880: 17.178216
# Volume of path rule 881: 16.927599
# Volume of path rule 882: 17.044242
# Volume of path rule 883: 17.446993
# Volume of path rule 884: 16.892225
# Volume of path rule 885: 17.399039
# Volume of path rule 886: 17.550497
# Volume of path rule 887: 17.826287
# Volume of path rule 888: 18.152428
# Volume of path rule 889: 17.581786
# Volume of path rule 890: 17.157248
# Volume of path rule 891: 19.744784
# Volume of path rule 892: 17.232643
# Volume of path rule 893: 17.678311
# Volume of path rule 894: 17.651903
# Volume of path rule 895: 18.032316
# Volume of path rule 896: 16.857538
# Volume of path rule 897: 17.336619
# Volume of path rule 898: 17.894463
# Volume of path rule 899: 17.129705
# Volume of path rule 900: 17.519579
# Volume of path rule 901: 17.420573
# Volume of path rule 902: 17.187973
# Volume of path rule 903: 17.375697
# Volume of path rule 904: 17.753855
# Volume of path rule 905: 17.166308
# Volume of path rule 906: 17.197983
# Volume of path rule 907: 18.009065
# Volume of path rule 908: 18.190898
# Volume of path rule 909: 16.843173
# Volume of path rule 910: 17.637657
# Volume of path rule 911: 17.904280
# Volume of path rule 912: 16.938030
# Volume of path rule 913: 17.179356
# Volume of path rule 914: 17.893886
# Volume of path rule 915: 17.553901
# Volume of path rule 916: 17.423982
# Volume of path rule 917: 17.228649
# Volume of path rule 918: 17.499161
# Volume of path rule 919: 17.154587
# Volume of path rule 920: 17.483838
# Volume of path rule 921: 17.031710
# Volume of path rule 922: 17.756470
# Volume of path rule 923: 17.736609
# Volume of path rule 924: 17.747696
# Volume of path rule 925: 17.193557
# Volume of path rule 926: 17.161866
# Volume of path rule 927: 16.841231
# Volume of path rule 928: 17.706372
# Volume of path rule 929: 17.955890
# Volume of path rule 930: 17.710593
# Volume of path rule 931: 17.906141
# Volume of path rule 932: 17.794328
# Volume of path rule 933: 17.480074
# Volume of path rule 934: 17.594164
# Volume of path rule 935: 17.537319
# Volume of path rule 936: 17.653565
# Volume of path rule 937: 17.148339
# Volume of path rule 938: 17.630685
# Volume of path rule 939: 17.815536
# Volume of path rule 940: 17.391048
# Volume of path rule 941: 17.593797
# Volume of path rule 942: 16.851521
# Volume of path rule 943: 17.845819
# Volume of path rule 944: 17.387028
# Volume of path rule 945: 17.645967
# Volume of path rule 946: 17.383922
# Volume of path rule 947: 18.159633
# Volume of path rule 948: 17.512507
# Volume of path rule 949: 17.023643
# Volume of path rule 950: 17.027482
# Volume of path rule 951: 19.303746
# Volume of path rule 952: 17.890311
# Volume of path rule 953: 17.739068
# Volume of path rule 954: 17.602562
# Volume of path rule 955: 17.511777
# Volume of path rule 956: 17.200554
# Volume of path rule 957: 16.692746
# Volume of path rule 958: 18.654038
# Volume of path rule 959: 17.440850
# Volume of path rule 960: 16.964530
# Volume of path rule 961: 17.126637
# Volume of path rule 962: 17.716612
# Volume of path rule 963: 17.417957
# Volume of path rule 964: 18.029654
# Volume of path rule 965: 16.984106
# Volume of path rule 966: 17.763181
# Volume of path rule 967: 18.287852
# Volume of path rule 968: 17.641394
# Volume of path rule 969: 18.166338
# Volume of path rule 970: 17.294495
# Volume of path rule 971: 17.644850
# Volume of path rule 972: 17.090698
# Volume of path rule 973: 18.982101
# Volume of path rule 974: 18.274197
# Volume of path rule 975: 17.717870
# Volume of path rule 976: 17.015259
# Volume of path rule 977: 17.422488
# Volume of path rule 978: 18.485964
# Volume of path rule 979: 17.073444
# Volume of path rule 980: 17.744708
# Volume of path rule 981: 17.529049
# Volume of path rule 982: 17.265752
# Volume of path rule 983: 17.130332
# Volume of path rule 984: 17.544228
# Volume of path rule 985: 17.388289
# Volume of path rule 986: 17.534863
# Volume of path rule 987: 17.039191
# Volume of path rule 988: 16.931345
# Volume of path rule 989: 17.634804
# Volume of path rule 990: 17.052264
# Volume of path rule 991: 18.816793
# Volume of path rule 992: 17.403323
# Volume of path rule 993: 17.591309
# Volume of path rule 994: 18.210872
# Volume of path rule 995: 17.544136
# Volume of path rule 996: 17.423452
# Volume of path rule 997: 18.102998
# Volume of path rule 998: 17.529298
# Volume of path rule 999: 17.696124
# Volume of MCR: 1.849409
# Volume of path rule 0: 17.641395
# Volume of path rule 1: 17.145785
# Volume of path rule 2: 17.457605
# Volume of path rule 3: 17.844634
# Volume of path rule 4: 17.379325
# Volume of path rule 5: 18.408004
# Volume of path rule 6: 17.254787
# Volume of path rule 7: 17.350110
# Volume of path rule 8: 17.190631
# Volume of path rule 9: 18.001162
# Volume of path rule 10: 17.291956
# Volume of path rule 11: 17.938962
# Volume of path rule 12: 18.160952
# Volume of path rule 13: 18.318432
# Volume of path rule 14: 17.702917
# Volume of path rule 15: 17.274361
# Volume of path rule 16: 17.047489
# Volume of path rule 17: 17.843562
# Volume of path rule 18: 17.628420
# Volume of path rule 19: 17.564866
# Volume of path rule 20: 17.795097
# Volume of path rule 21: 18.514904
# Volume of path rule 22: 17.728982
# Volume of path rule 23: 17.673557
# Volume of path rule 24: 18.055223
# Volume of path rule 25: 17.480735
# Volume of path rule 26: 18.815063
# Volume of path rule 27: 18.304829
# Volume of path rule 28: 18.547808
# Volume of path rule 29: 18.827900
# Volume of path rule 30: 18.616824
# Volume of path rule 31: 17.895310
# Volume of path rule 32: 18.823725
# Volume of path rule 33: 17.463994
# Volume of path rule 34: 17.763944
# Volume of path rule 35: 17.632958
# Volume of path rule 36: 17.920729
# Volume of path rule 37: 18.299193
# Volume of path rule 38: 17.329937
# Volume of path rule 39: 17.443879
# Volume of path rule 40: 17.669129
# Volume of path rule 41: 16.893081
# Volume of path rule 42: 17.437698
# Volume of path rule 43: 17.112469
# Volume of path rule 44: 18.328339
# Volume of path rule 45: 17.696128
# Volume of path rule 46: 17.243639
# Volume of path rule 47: 18.073002
# Volume of path rule 48: 18.272503
# Volume of path rule 49: 18.831745
# Volume of path rule 50: 17.280004
# Volume of path rule 51: 17.042421
# Volume of path rule 52: 18.083164
# Volume of path rule 53: 17.030731
# Volume of path rule 54: 17.651724
# Volume of path rule 55: 17.890200
# Volume of path rule 56: 18.852490
# Volume of path rule 57: 18.016418
# Volume of path rule 58: 19.096176
# Volume of path rule 59: 17.918499
# Volume of path rule 60: 17.656544
# Volume of path rule 61: 17.855229
# Volume of path rule 62: 18.052466
# Volume of path rule 63: 17.321999
# Volume of path rule 64: 17.268283
# Volume of path rule 65: 17.127119
# Volume of path rule 66: 17.106528
# Volume of path rule 67: 19.043955
# Volume of path rule 68: 17.366400
# Volume of path rule 69: 17.096230
# Volume of path rule 70: 17.824809
# Volume of path rule 71: 17.906050
# Volume of path rule 72: 17.375923
# Volume of path rule 73: 17.322044
# Volume of path rule 74: 17.599610
# Volume of path rule 75: 17.818507
# Volume of path rule 76: 18.785161
# Volume of path rule 77: 18.002104
# Volume of path rule 78: 18.203156
# Volume of path rule 79: 17.936714
# Volume of path rule 80: 16.959463
# Volume of path rule 81: 17.225928
# Volume of path rule 82: 17.772485
# Volume of path rule 83: 17.200533
# Volume of path rule 84: 18.544865
# Volume of path rule 85: 17.766646
# Volume of path rule 86: 17.689076
# Volume of path rule 87: 18.002432
# Volume of path rule 88: 17.514086
# Volume of path rule 89: 18.342976
# Volume of path rule 90: 17.236183
# Volume of path rule 91: 17.839006
# Volume of path rule 92: 18.018774
# Volume of path rule 93: 17.567934
# Volume of path rule 94: 17.381341
# Volume of path rule 95: 17.829731
# Volume of path rule 96: 16.894069
# Volume of path rule 97: 17.505342
# Volume of path rule 98: 16.888341
# Volume of path rule 99: 17.250061
# Volume of path rule 100: 17.924752
# Volume of path rule 101: 18.164832
# Volume of path rule 102: 18.200012
# Volume of path rule 103: 16.692692
# Volume of path rule 104: 17.158539
# Volume of path rule 105: 18.143471
# Volume of path rule 106: 17.755923
# Volume of path rule 107: 17.444165
# Volume of path rule 108: 17.401056
# Volume of path rule 109: 18.042212
# Volume of path rule 110: 17.695326
# Volume of path rule 111: 17.672010
# Volume of path rule 112: 17.389077
# Volume of path rule 113: 17.384856
# Volume of path rule 114: 18.003775
# Volume of path rule 115: 17.908253
# Volume of path rule 116: 18.218800
# Volume of path rule 117: 17.651933
# Volume of path rule 118: 18.063141
# Volume of path rule 119: 16.832053
# Volume of path rule 120: 18.827052
# Volume of path rule 121: 18.087314
# Volume of path rule 122: 17.069381
# Volume of path rule 123: 17.669786
# Volume of path rule 124: 17.696204
# Volume of path rule 125: 17.396846
# Volume of path rule 126: 17.637323
# Volume of path rule 127: 18.198144
# Volume of path rule 128: 17.692446
# Volume of path rule 129: 17.580438
# Volume of path rule 130: 17.303781
# Volume of path rule 131: 17.354421
# Volume of path rule 132: 17.061040
# Volume of path rule 133: 18.759540
# Volume of path rule 134: 17.411905
# Volume of path rule 135: 18.102255
# Volume of path rule 136: 17.996139
# Volume of path rule 137: 17.662829
# Volume of path rule 138: 17.250226
# Volume of path rule 139: 17.071170
# Volume of path rule 140: 18.861644
# Volume of path rule 141: 17.596530
# Volume of path rule 142: 16.924810
# Volume of path rule 143: 16.868760
# Volume of path rule 144: 18.072591
# Volume of path rule 145: 17.903703
# Volume of path rule 146: 17.508561
# Volume of path rule 147: 17.833625
# Volume of path rule 148: 18.791461
# Volume of path rule 149: 17.635384
# Volume of path rule 150: 17.356322
# Volume of path rule 151: 17.547861
# Volume of path rule 152: 18.649470
# Volume of path rule 153: 18.061331
# Volume of path rule 154: 18.525602
# Volume of path rule 155: 17.447640
# Volume of path rule 156: 17.627093
# Volume of path rule 157: 18.420795
# Volume of path rule 158: 18.122876
# Volume of path rule 159: 17.884635
# Volume of path rule 160: 17.163597
# Volume of path rule 161: 17.549323
# Volume of path rule 162: 17.867457
# Volume of path rule 163: 17.691158
# Volume of path rule 164: 18.303785
# Volume of path rule 165: 18.130537
# Volume of path rule 166: 17.976092
# Volume of path rule 167: 17.370042
# Volume of path rule 168: 17.707908
# Volume of path rule 169: 18.063955
# Volume of path rule 170: 17.544103
# Volume of path rule 171: 18.463802
# Volume of path rule 172: 18.641182
# Volume of path rule 173: 17.332892
# Volume of path rule 174: 17.192280
# Volume of path rule 175: 17.070123
# Volume of path rule 176: 18.032592
# Volume of path rule 177: 17.878559
# Volume of path rule 178: 16.671316
# Volume of path rule 179: 17.448535
# Volume of path rule 180: 17.054066
# Volume of path rule 181: 18.398178
# Volume of path rule 182: 17.869905
# Volume of path rule 183: 17.607240
# Volume of path rule 184: 17.534411
# Volume of path rule 185: 17.707956
# Volume of path rule 186: 17.649318
# Volume of path rule 187: 17.313813
# Volume of path rule 188: 17.691419
# Volume of path rule 189: 18.004431
# Volume of path rule 190: 17.522831
# Volume of path rule 191: 18.188769
# Volume of path rule 192: 16.985764
# Volume of path rule 193: 16.965265
# Volume of path rule 194: 19.382051
# Volume of path rule 195: 17.566255
# Volume of path rule 196: 18.302377
# Volume of path rule 197: 16.856571
# Volume of path rule 198: 17.642681
# Volume of path rule 199: 17.602697
# Volume of path rule 200: 18.709325
# Volume of path rule 201: 18.826516
# Volume of path rule 202: 18.084889
# Volume of path rule 203: 17.672633
# Volume of path rule 204: 18.343394
# Volume of path rule 205: 17.366068
# Volume of path rule 206: 17.007897
# Volume of path rule 207: 17.808655
# Volume of path rule 208: 17.367388
# Volume of path rule 209: 17.547970
# Volume of path rule 210: 16.734524
# Volume of path rule 211: 17.086386
# Volume of path rule 212: 18.352886
# Volume of path rule 213: 17.047014
# Volume of path rule 214: 17.677776
# Volume of path rule 215: 18.188308
# Volume of path rule 216: 16.915973
# Volume of path rule 217: 18.478609
# Volume of path rule 218: 17.543390
# Volume of path rule 219: 17.067223
# Volume of path rule 220: 17.804003
# Volume of path rule 221: 17.603202
# Volume of path rule 222: 17.034325
# Volume of path rule 223: 18.162764
# Volume of path rule 224: 17.526555
# Volume of path rule 225: 17.114318
# Volume of path rule 226: 18.522203
# Volume of path rule 227: 18.317756
# Volume of path rule 228: 17.160127
# Volume of path rule 229: 17.920772
# Volume of path rule 230: 17.175949
# Volume of path rule 231: 19.058261
# Volume of path rule 232: 17.632682
# Volume of path rule 233: 17.699447
# Volume of path rule 234: 17.531340
# Volume of path rule 235: 17.948724
# Volume of path rule 236: 17.434111
# Volume of path rule 237: 18.480124
# Volume of path rule 238: 17.860731
# Volume of path rule 239: 17.654430
# Volume of path rule 240: 18.456382
# Volume of path rule 241: 18.041694
# Volume of path rule 242: 18.802625
# Volume of path rule 243: 17.937748
# Volume of path rule 244: 17.170697
# Volume of path rule 245: 17.867803
# Volume of path rule 246: 17.570474
# Volume of path rule 247: 17.037570
# Volume of path rule 248: 17.961664
# Volume of path rule 249: 17.229776
# Volume of path rule 250: 17.676304
# Volume of path rule 251: 17.190872
# Volume of path rule 252: 16.711211
# Volume of path rule 253: 17.351686
# Volume of path rule 254: 18.199990
# Volume of path rule 255: 17.523508
# Volume of path rule 256: 17.610456
# Volume of path rule 257: 17.529589
# Volume of path rule 258: 17.157426
# Volume of path rule 259: 18.544234
# Volume of path rule 260: 17.132089
# Volume of path rule 261: 17.497304
# Volume of path rule 262: 17.521379
# Volume of path rule 263: 18.027839
# Volume of path rule 264: 18.015235
# Volume of path rule 265: 17.572382
# Volume of path rule 266: 18.259747
# Volume of path rule 267: 17.839291
# Volume of path rule 268: 17.580958
# Volume of path rule 269: 18.764823
# Volume of path rule 270: 17.016174
# Volume of path rule 271: 17.494392
# Volume of path rule 272: 17.224707
# Volume of path rule 273: 17.790303
# Volume of path rule 274: 18.052068
# Volume of path rule 275: 18.692632
# Volume of path rule 276: 17.244660
# Volume of path rule 277: 17.174365
# Volume of path rule 278: 17.645203
# Volume of path rule 279: 18.145601
# Volume of path rule 280: 17.519822
# Volume of path rule 281: 19.046951
# Volume of path rule 282: 17.821486
# Volume of path rule 283: 17.709932
# Volume of path rule 284: 17.429111
# Volume of path rule 285: 18.132464
# Volume of path rule 286: 17.718711
# Volume of path rule 287: 17.422602
# Volume of path rule 288: 17.399617
# Volume of path rule 289: 17.313744
# Volume of path rule 290: 17.068347
# Volume of path rule 291: 17.023950
# Volume of path rule 292: 17.853076
# Volume of path rule 293: 17.589093
# Volume of path rule 294: 17.811743
# Volume of path rule 295: 17.789705
# Volume of path rule 296: 17.364812
# Volume of path rule 297: 17.990360
# Volume of path rule 298: 17.483277
# Volume of path rule 299: 17.808028
# Volume of path rule 300: 17.231766
# Volume of path rule 301: 17.510532
# Volume of path rule 302: 18.186198
# Volume of path rule 303: 17.270767
# Volume of path rule 304: 17.371231
# Volume of path rule 305: 17.521240
# Volume of path rule 306: 17.517344
# Volume of path rule 307: 18.044487
# Volume of path rule 308: 17.257730
# Volume of path rule 309: 17.678381
# Volume of path rule 310: 17.024818
# Volume of path rule 311: 17.139008
# Volume of path rule 312: 17.816062
# Volume of path rule 313: 17.365003
# Volume of path rule 314: 17.756906
# Volume of path rule 315: 18.424656
# Volume of path rule 316: 18.190243
# Volume of path rule 317: 17.436304
# Volume of path rule 318: 17.902672
# Volume of path rule 319: 17.867365
# Volume of path rule 320: 17.521660
# Volume of path rule 321: 17.828773
# Volume of path rule 322: 17.452805
# Volume of path rule 323: 18.510598
# Volume of path rule 324: 18.806759
# Volume of path rule 325: 17.815703
# Volume of path rule 326: 17.186267
# Volume of path rule 327: 17.745239
# Volume of path rule 328: 17.651671
# Volume of path rule 329: 17.139549
# Volume of path rule 330: 17.966795
# Volume of path rule 331: 17.731768
# Volume of path rule 332: 18.092578
# Volume of path rule 333: 17.742620
# Volume of path rule 334: 16.938894
# Volume of path rule 335: 18.300117
# Volume of path rule 336: 18.782005
# Volume of path rule 337: 17.410221
# Volume of path rule 338: 17.624846
# Volume of path rule 339: 17.688453
# Volume of path rule 340: 17.987463
# Volume of path rule 341: 17.781610
# Volume of path rule 342: 18.189715
# Volume of path rule 343: 17.024127
# Volume of path rule 344: 16.938142
# Volume of path rule 345: 17.738844
# Volume of path rule 346: 18.072668
# Volume of path rule 347: 17.678560
# Volume of path rule 348: 17.508346
# Volume of path rule 349: 17.220408
# Volume of path rule 350: 17.354955
# Volume of path rule 351: 17.252146
# Volume of path rule 352: 16.945259
# Volume of path rule 353: 17.792220
# Volume of path rule 354: 17.256315
# Volume of path rule 355: 17.548583
# Volume of path rule 356: 17.991032
# Volume of path rule 357: 18.529092
# Volume of path rule 358: 18.475230
# Volume of path rule 359: 17.522359
# Volume of path rule 360: 17.767765
# Volume of path rule 361: 16.946962
# Volume of path rule 362: 17.666500
# Volume of path rule 363: 17.805512
# Volume of path rule 364: 17.990537
# Volume of path rule 365: 18.504155
# Volume of path rule 366: 18.064481
# Volume of path rule 367: 17.220149
# Volume of path rule 368: 17.704945
# Volume of path rule 369: 17.434674
# Volume of path rule 370: 17.918923
# Volume of path rule 371: 17.291370
# Volume of path rule 372: 18.071914
# Volume of path rule 373: 17.012065
# Volume of path rule 374: 18.513127
# Volume of path rule 375: 17.988939
# Volume of path rule 376: 17.983461
# Volume of path rule 377: 18.487551
# Volume of path rule 378: 17.934448
# Volume of path rule 379: 17.222711
# ...
# Volume of path rule 544: 18.920458
# Volume of path rule 545: 17.867849
# Volume of path rule 546: 17.342953
# Volume of path rule 547: 18.112286
# Volume of path rule 548: 17.980558
# Volume of path rule 549: 17.845403
# Volume of path rule 550: 18.528527
# Volume of path rule 551: 17.524816
# Volume of path rule 552: 18.706093
# Volume of path rule 553: 17.473056
# Volume of path rule 554: 17.356551
# Volume of path rule 555: 18.746913
# Volume of path rule 556: 17.387766
# Volume of path rule 557: 17.754255
# Volume of path rule 558: 18.008523
# Volume of path rule 559: 17.855831
# Volume of path rule 560: 17.728876
# Volume of path rule 561: 17.143034
# Volume of path rule 562: 18.185923
# Volume of path rule 563: 18.298435
# Volume of path rule 564: 17.300338
# Volume of path rule 565: 19.821633
# Volume of path rule 566: 18.001859
# Volume of path rule 567: 18.798338
# Volume of path rule 568: 17.611706
# Volume of path rule 569: 18.797390
# Volume of path rule 570: 18.938720
# Volume of path rule 571: 17.589942
# Volume of path rule 572: 19.116606
# Volume of path rule 573: 17.663744
# Volume of path rule 574: 19.076625
# Volume of path rule 575: 17.606044
# Volume of path rule 576: 16.845173
# Volume of path rule 577: 18.599304
# Volume of path rule 578: 17.645571
# Volume of path rule 579: 18.823988
# Volume of path rule 580: 19.184951
# Volume of path rule 581: 18.461092
# Volume of path rule 582: 18.320808
# Volume of path rule 583: 18.894542
# Volume of path rule 584: 18.512772
# Volume of path rule 585: 17.713749
# Volume of path rule 586: 18.395874
# Volume of path rule 587: 17.280099
# Volume of path rule 588: 17.637290
# Volume of path rule 589: 17.792953
# Volume of path rule 590: 19.294846
# Volume of path rule 591: 17.621509
# Volume of path rule 592: 17.644952
# Volume of path rule 593: 17.372804
# Volume of path rule 594: 19.108642
# Volume of path rule 595: 18.356240
# Volume of path rule 596: 18.067458
# Volume of path rule 597: 18.038886
# Volume of path rule 598: 18.926127
# Volume of path rule 599: 17.337312
# Volume of path rule 600: 17.685112
# Volume of path rule 601: 18.364035
# Volume of path rule 602: 16.802772
# Volume of path rule 603: 18.559691
# Volume of path rule 604: 18.266811
# Volume of path rule 605: 18.575059
# Volume of path rule 606: 17.839546
# Volume of path rule 607: 18.449468
# Volume of path rule 608: 17.833297
# Volume of path rule 609: 17.592223
# Volume of path rule 610: 17.262321
# Volume of path rule 611: 17.679167
# Volume of path rule 612: 18.099237
# Volume of path rule 613: 18.102644
# Volume of path rule 614: 18.857077
# Volume of path rule 615: 18.457623
# Volume of path rule 616: 18.143279
# Volume of path rule 617: 17.865797
# Volume of path rule 618: 17.857785
# Volume of path rule 619: 17.376197
# Volume of path rule 620: 17.747429
# Volume of path rule 621: 17.532718
# Volume of path rule 622: 18.178782
# Volume of path rule 623: 17.653020
# Volume of path rule 624: 18.626248
# Volume of path rule 625: 17.950931
# Volume of path rule 626: 18.814574
# Volume of path rule 627: 17.689470
# Volume of path rule 628: 19.442293
# Volume of path rule 629: 18.468761
# Volume of path rule 630: 17.889718
# Volume of path rule 631: 17.931462
# Volume of path rule 632: 17.870579
# Volume of path rule 633: 18.041304
# Volume of path rule 634: 18.022732
# Volume of path rule 635: 17.741670
# Volume of path rule 636: 17.593148
# Volume of path rule 637: 18.320661
# Volume of path rule 638: 18.277656
# Volume of path rule 639: 17.350083
# Volume of path rule 640: 19.374758
# Volume of path rule 641: 17.603981
# Volume of path rule 642: 18.473617
# Volume of path rule 643: 17.963950
# Volume of path rule 644: 18.468709
# Volume of path rule 645: 17.900558
# Volume of path rule 646: 17.946378
# Volume of path rule 647: 17.865515
# Volume of path rule 648: 17.630460
# Volume of path rule 649: 17.720720
# Volume of path rule 650: 18.137170
# Volume of path rule 651: 18.433673
# Volume of path rule 652: 16.966587
# Volume of path rule 653: 17.234148
# Volume of path rule 654: 17.705259
# Volume of path rule 655: 18.238778
# Volume of path rule 656: 17.751480
# Volume of path rule 657: 17.661698
# Volume of path rule 658: 18.419503
# Volume of path rule 659: 17.683087
# Volume of path rule 660: 18.276795
# Volume of path rule 661: 18.471614
# Volume of path rule 662: 18.674235
# Volume of path rule 663: 17.424344
# Volume of path rule 664: 17.343891
# Volume of path rule 665: 17.114437
# Volume of path rule 666: 17.333307
# Volume of path rule 667: 17.559232
# Volume of path rule 668: 17.372986
# Volume of path rule 669: 18.123303
# Volume of path rule 670: 17.897982
# Volume of path rule 671: 18.059981
# Volume of path rule 672: 17.413727
# Volume of path rule 673: 19.055828
# Volume of path rule 674: 17.921700
# Volume of path rule 675: 17.198892
# Volume of path rule 676: 18.613103
# Volume of path rule 677: 17.683011
# Volume of path rule 678: 17.956606
# Volume of path rule 679: 17.981026
# Volume of path rule 680: 18.556259
# Volume of path rule 681: 17.411140
# Volume of path rule 682: 18.441897
# Volume of path rule 683: 18.346557
# Volume of path rule 684: 18.363554
# Volume of path rule 685: 19.777968
# Volume of path rule 686: 17.579564
# Volume of path rule 687: 18.543583
# Volume of path rule 688: 18.016336
# Volume of path rule 689: 18.719882
# Volume of path rule 690: 18.729079
# Volume of path rule 691: 17.663481
# Volume of path rule 692: 19.497275
# Volume of path rule 693: 18.590660
# Volume of path rule 694: 17.827410
# Volume of path rule 695: 18.404366
# Volume of path rule 696: 18.035229
# Volume of path rule 697: 17.628967
# Volume of path rule 698: 17.634807
# Volume of path rule 699: 18.506538
# Volume of path rule 700: 17.817223
# Volume of path rule 701: 17.963643
# Volume of path rule 702: 17.668396
# Volume of path rule 703: 17.613140
# Volume of path rule 704: 18.243318
# Volume of path rule 705: 17.709865
# Volume of path rule 706: 17.961784
# Volume of path rule 707: 18.506150
# Volume of path rule 708: 17.767594
# Volume of path rule 709: 17.933760
# Volume of path rule 710: 17.676316
# Volume of path rule 711: 18.491242
# Volume of path rule 712: 18.457976
# Volume of path rule 713: 18.202613
# Volume of path rule 714: 17.742911
# Volume of path rule 715: 18.140332
# Volume of path rule 716: 17.526241
# Volume of path rule 717: 18.524417
# Volume of path rule 718: 17.876657
# Volume of path rule 719: 18.107727
# Volume of path rule 720: 18.020785
# Volume of path rule 721: 17.882961
# Volume of path rule 722: 16.984634
# Volume of path rule 723: 17.331481
# Volume of path rule 724: 17.458533
# Volume of path rule 725: 18.886840
# Volume of path rule 726: 17.896985
# Volume of path rule 727: 18.160990
# Volume of path rule 728: 16.944062
# Volume of path rule 729: 18.142676
# Volume of path rule 730: 17.841641
# Volume of path rule 731: 18.188856
# Volume of path rule 732: 17.867824
# Volume of path rule 733: 17.976156
# Volume of path rule 734: 17.063137
# Volume of path rule 735: 18.327743
# Volume of path rule 736: 18.010139
# Volume of path rule 737: 18.876205
# Volume of path rule 738: 17.893317
# Volume of path rule 739: 17.934780
# Volume of path rule 740: 17.426797
# Volume of path rule 741: 18.064000
# Volume of path rule 742: 17.980144
# Volume of path rule 743: 18.371073
# Volume of path rule 744: 18.409206
# Volume of path rule 745: 19.300659
# Volume of path rule 746: 17.634873
# Volume of path rule 747: 17.952591
# Volume of path rule 748: 17.579791
# Volume of path rule 749: 18.479249
# Volume of path rule 750: 17.703939
# Volume of path rule 751: 18.664150
# Volume of path rule 752: 17.599830
# Volume of path rule 753: 17.649402
# Volume of path rule 754: 18.728226
# Volume of path rule 755: 17.250011
# Volume of path rule 756: 17.988931
# Volume of path rule 757: 20.050013
# Volume of path rule 758: 18.418313
# Volume of path rule 759: 18.008970
# Volume of path rule 760: 17.559432
# Volume of path rule 761: 17.885513
# Volume of path rule 762: 17.323680
# Volume of path rule 763: 17.785686
# Volume of path rule 764: 17.504473
# Volume of path rule 765: 17.921706
# Volume of path rule 766: 18.131245
# Volume of path rule 767: 17.258326
# Volume of path rule 768: 18.490939
# Volume of path rule 769: 18.470186
# Volume of path rule 770: 18.692743
# Volume of path rule 771: 17.112972
# Volume of path rule 772: 18.277995
# Volume of path rule 773: 17.377475
# Volume of path rule 774: 17.862720
# Volume of path rule 775: 17.690005
# Volume of path rule 776: 18.610959
# Volume of path rule 777: 19.342707
# Volume of path rule 778: 17.956315
# Volume of path rule 779: 17.239754
# Volume of path rule 780: 19.273125
# Volume of path rule 781: 17.683715
# Volume of path rule 782: 17.874186
# Volume of path rule 783: 18.793587
# Volume of path rule 784: 18.989449
# Volume of path rule 785: 17.445606
# Volume of path rule 786: 18.818134
# Volume of path rule 787: 18.557433
# Volume of path rule 788: 17.980416
# Volume of path rule 789: 18.586260
# Volume of path rule 790: 17.492901
# Volume of path rule 791: 18.536256
# Volume of path rule 792: 19.415483
# Volume of path rule 793: 18.477573
# Volume of path rule 794: 19.049328
# Volume of path rule 795: 19.215533
# Volume of path rule 796: 17.458876
# Volume of path rule 797: 18.228208
# Volume of path rule 798: 18.193546
# Volume of path rule 799: 18.275152
# Volume of path rule 800: 18.271936
# Volume of path rule 801: 16.853197
# Volume of path rule 802: 18.243309
# Volume of path rule 803: 18.002712
# Volume of path rule 804: 17.023900
# Volume of path rule 805: 18.362425
# Volume of path rule 806: 17.626993
# Volume of path rule 807: 18.722018
# Volume of path rule 808: 17.453693
# Volume of path rule 809: 18.201697
# Volume of path rule 810: 17.898114
# Volume of path rule 811: 17.741585
# Volume of path rule 812: 18.484937
# Volume of path rule 813: 18.654621
# Volume of path rule 814: 17.002754
# Volume of path rule 815: 18.224406
# Volume of path rule 816: 17.956159
# Volume of path rule 817: 17.426254
# Volume of path rule 818: 17.574700
# Volume of path rule 819: 18.228983
# Volume of path rule 820: 17.680695
# Volume of path rule 821: 17.210983
# Volume of path rule 822: 19.688529
# Volume of path rule 823: 18.342179
# Volume of path rule 824: 18.064372
# Volume of path rule 825: 17.559058
# Volume of path rule 826: 18.364839
# Volume of path rule 827: 17.793153
# Volume of path rule 828: 19.264616
# Volume of path rule 829: 18.398519
# Volume of path rule 830: 18.244238
# Volume of path rule 831: 17.691251
# Volume of path rule 832: 18.115814
# Volume of path rule 833: 18.407273
# Volume of path rule 834: 18.811611
# Volume of path rule 835: 19.334783
# Volume of path rule 836: 18.040189
# Volume of path rule 837: 18.162903
# Volume of path rule 838: 18.944590
# Volume of path rule 839: 17.477281
# Volume of path rule 840: 17.514960
# Volume of path rule 841: 18.526993
# Volume of path rule 842: 17.164272
# Volume of path rule 843: 18.457724
# Volume of path rule 844: 17.426457
# Volume of path rule 845: 17.794153
# Volume of path rule 846: 17.657224
# Volume of path rule 847: 17.434572
# Volume of path rule 848: 19.118555
# Volume of path rule 849: 18.412845
# Volume of path rule 850: 17.118640
# Volume of path rule 851: 17.992117
# Volume of path rule 852: 17.641601
# Volume of path rule 853: 18.077439
# Volume of path rule 854: 18.187189
# Volume of path rule 855: 18.158026
# Volume of path rule 856: 18.891566
# Volume of path rule 857: 17.473269
# Volume of path rule 858: 18.752445
# Volume of path rule 859: 17.882983
# Volume of path rule 860: 18.336855
# Volume of path rule 861: 18.415710
# Volume of path rule 862: 17.192065
# Volume of path rule 863: 17.524526
# Volume of path rule 864: 17.712727
# Volume of path rule 865: 18.280722
# Volume of path rule 866: 18.346001
# Volume of path rule 867: 18.313098
# Volume of path rule 868: 17.577482
# Volume of path rule 869: 17.661340
# Volume of path rule 870: 18.272433
# Volume of path rule 871: 17.648057
# Volume of path rule 872: 17.367971
# Volume of path rule 873: 17.845947
# Volume of path rule 874: 17.281610
# Volume of path rule 875: 17.618386
# Volume of path rule 876: 19.090861
# Volume of path rule 877: 17.120061
# Volume of path rule 878: 18.341630
# Volume of path rule 879: 18.860854
# Volume of path rule 880: 17.834368
# Volume of path rule 881: 18.023983
# Volume of path rule 882: 18.406264
# Volume of path rule 883: 19.188928
# Volume of path rule 884: 17.296799
# Volume of path rule 885: 18.740859
# Volume of path rule 886: 18.194060
# Volume of path rule 887: 18.706531
# Volume of path rule 888: 18.152428
# Volume of path rule 889: 18.699091
# Volume of path rule 890: 18.449739
# Volume of path rule 891: 17.873835
# Volume of path rule 892: 19.967486
# Volume of path rule 893: 17.902718
# Volume of path rule 894: 19.120691
# Volume of path rule 895: 18.177284
# Volume of path rule 896: 18.328822
# Volume of path rule 897: 18.357055
# Volume of path rule 898: 18.048007
# Volume of path rule 899: 18.039242
# Volume of path rule 900: 18.656237
# Volume of path rule 901: 19.408997
# Volume of path rule 902: 18.099570
# Volume of path rule 903: 18.096924
# Volume of path rule 904: 17.804396
# Volume of path rule 905: 18.993143
# Volume of path rule 906: 17.197983
# Volume of path rule 907: 17.233690
# Volume of path rule 908: 19.297586
# Volume of path rule 909: 18.066697
# Volume of path rule 910: 17.567360
# Volume of path rule 911: 17.856886
# Volume of path rule 912: 17.735979
# Volume of path rule 913: 18.474769
# Volume of path rule 914: 18.194330
# Volume of path rule 915: 16.974469
# Volume of path rule 916: 17.653017
# Volume of path rule 917: 17.856668
# Volume of path rule 918: 19.198795
# Volume of path rule 919: 17.933592
# Volume of path rule 920: 18.554199
# Volume of path rule 921: 18.925983
# Volume of path rule 922: 17.802615
# Volume of path rule 923: 17.736609
# Volume of path rule 924: 17.808848
# Volume of path rule 925: 17.630383
# Volume of path rule 926: 18.065696
# Volume of path rule 927: 17.735622
# Volume of path rule 928: 18.338597
# Volume of path rule 929: 18.958031
# Volume of path rule 930: 17.549288
# Volume of path rule 931: 18.376245
# Volume of path rule 932: 17.633918
# Volume of path rule 933: 18.349863
# Volume of path rule 934: 18.886763
# Volume of path rule 935: 18.044991
# Volume of path rule 936: 18.041720
# Volume of path rule 937: 17.417374
# Volume of path rule 938: 17.830797
# Volume of path rule 939: 17.815536
# Volume of path rule 940: 17.639035
# Volume of path rule 941: 18.409538
# Volume of path rule 942: 16.851521
# Volume of path rule 943: 17.845819
# Volume of path rule 944: 17.614963
# Volume of path rule 945: 17.645967
# Volume of path rule 946: 17.502107
# Volume of path rule 947: 18.159633
# Volume of path rule 948: 18.554773
# Volume of path rule 949: 18.435056
# Volume of path rule 950: 17.851269
# Volume of path rule 951: 19.629474
# Volume of path rule 952: 18.792530
# Volume of path rule 953: 17.739068
# Volume of path rule 954: 18.613115
# Volume of path rule 955: 18.171161
# Volume of path rule 956: 19.829604
# Volume of path rule 957: 17.723185
# Volume of path rule 958: 18.100604
# Volume of path rule 959: 19.120640
# Volume of path rule 960: 17.658321
# Volume of path rule 961: 17.765415
# Volume of path rule 962: 18.073577
# Volume of path rule 963: 17.841257
# Volume of path rule 964: 18.029654
# Volume of path rule 965: 17.587060
# Volume of path rule 966: 18.432651
# Volume of path rule 967: 17.716259
# Volume of path rule 968: 17.734705
# Volume of path rule 969: 18.166338
# Volume of path rule 970: 17.516619
# Volume of path rule 971: 17.644850
# Volume of path rule 972: 18.196640
# Volume of path rule 973: 17.846472
# Volume of path rule 974: 17.759215
# Volume of path rule 975: 17.717870
# Volume of path rule 976: 17.614638
# Volume of path rule 977: 20.047743
# Volume of path rule 978: 17.666299
# Volume of path rule 979: 17.073444
# Volume of path rule 980: 19.287279
# Volume of path rule 981: 17.754075
# Volume of path rule 982: 19.296380
# Volume of path rule 983: 17.946856
# Volume of path rule 984: 18.120393
# Volume of path rule 985: 17.640528
# Volume of path rule 986: 17.492486
# Volume of path rule 987: 17.881900
# Volume of path rule 988: 17.718651
# Volume of path rule 989: 17.771758
# Volume of path rule 990: 18.379483
# Volume of path rule 991: 18.668890
# Volume of path rule 992: 18.505771
# Volume of path rule 993: 17.994430
# Volume of path rule 994: 17.590660
# Volume of path rule 995: 17.305036
# Volume of path rule 996: 18.642972
# Volume of path rule 997: 18.606194
# Volume of path rule 998: 17.529298
# Volume of path rule 999: 18.634492
# Volume of MCR: 1.706402

# %%
y_pred = np.array(results)

# %%
y_pred.shape
# Out:
# (500, 24)

# %% [markdown]
# ###**COSINE DISTANCE**

# %%
X_test.shape
# Out:
# (500, 24)

# %%
yt = X_test.flatten()
yt.shape
# Out:
# (12000,)

# %%
yp = y_pred.flatten()
yp.shape
# Out:
# (12000,)

# %%
from scipy.spatial.distance import cosine

cos_distance = cosine(yt, yp)

# %%
cos_distance
# Out:
# 0.005226915080154493
