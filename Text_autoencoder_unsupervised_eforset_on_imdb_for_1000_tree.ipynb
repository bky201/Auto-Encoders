# %% [markdown]
# # **TEXT AUTO ENCODER USING UNSUPERVISED EFOREST ON IMDB TEXT DATASET WITH 1000 TREE**

# %%
from keras.datasets import imdb
import numpy as np

# %%
max_features= 100 # NUMBER OF WORD OR VOCABULARY SIZE
(X_tr, y_tr), (X_te, y_te) =  imdb.load_data(num_words=max_features)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
X_train = X_tr[:500]
y_train = y_tr[:500]
X_test = X_te[:500]
y_test = y_te[:500]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
print("Categories:", np.unique(y_train))
print("Number of unique words:", len(np.unique(np.hstack(X_train))))
# Out:
# Categories: [0 1]
# Number of unique words: 98

# %%
length = [len(i) for i in X_train]
print("Average Review length:", np.mean(length))
print("Standard Deviation:", round(np.std(length)))
# Out:
# Average Review length: 257.8
# Standard Deviation: 196

# %%
print("Label:", y_train[0])
print(X_train[0])
# Out:
# Label: 1
# [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 2, 36, 2, 5, 25, 2, 43, 2, 2, 50, 2, 2, 9, 35, 2, 2, 5, 2, 4, 2, 2, 2, 2, 2, 2, 39, 4, 2, 2, 2, 17, 2, 38, 13, 2, 4, 2, 50, 16, 6, 2, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 2, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 2, 12, 16, 38, 2, 5, 25, 2, 51, 36, 2, 48, 25, 2, 33, 6, 22, 12, 2, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 2, 2, 2, 15, 2, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 2, 88, 4, 2, 15, 2, 98, 32, 2, 56, 26, 2, 6, 2, 2, 18, 4, 2, 22, 21, 2, 2, 26, 2, 5, 2, 30, 2, 18, 51, 36, 28, 2, 92, 25, 2, 4, 2, 65, 16, 38, 2, 88, 12, 16, 2, 5, 16, 2, 2, 2, 32, 15, 16, 2, 19, 2, 32]

# %% [markdown]
# ##**Pre-processing**

# %%
# Used for pre-processing data
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import pandas as pd
from nltk import pos_tag
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocessing(text):
    #splits the word and checks each character to see if it contains any standard punctuations, 
    #if so it will be replaced with a blank or else it just don’t replace with blank
    text2 = " ".join("".join([" " if ch in string.punctuation else ch for ch in text]).split())
    
    #tokenizes the sentences into words based on whitespaces and puts them together as a list for applying further steps
    tokens = [word for sent in nltk.sent_tokenize(text2) for word in nltk.word_tokenize(sent)]
    
    #Converting all the cases (upper, lower and proper) into lower case reduces duplicates in corpus
    tokens = [word.lower() for word in tokens]
    
    #Stop words are the words that do not carry much of weight in understanding the sentence; 
    #they are used for connecting words and so on. We have removed them with the following line of code
    stopwds = stopwords.words('english')
    tokens = [token for token in tokens if token not in stopwds]
    
    #Stemming applied on the words using Porter stemmer which stems the extra suffixes from the words
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    
    #POS tagging is a prerequisite for lemmatization, based on whether the word 
    #is noun or verb or and so on. it will reduce it to the root word
    tagged_corpus = pos_tag(tokens)

    Noun_tags = ['NN','NNP','NNPS','NNS']
    Verb_tags = ['VB','VBD','VBG','VBN','VBP','VBZ']
    lemmatizer = WordNetLemmatizer()

    #  If the tag for any word falls under the respective noun or verb tags category, 
    #  n or v will be applied accordingly in lemmatize function
    def prat_lemmatize(token,tag):
        if tag in Noun_tags:
            return lemmatizer.lemmatize(token,'n')

        elif tag in Verb_tags:
            return lemmatizer.lemmatize(token,'v')
        else:
            return lemmatizer.lemmatize(token,'n')
    
    #we need to join it back to form stings and the following function performs the same
    pre_proc_text =   " ".join([prat_lemmatize(token,tag) for token,tag in tagged_corpus])

    return pre_proc_text

# %% [markdown]
# ###**PREPROCESSING ON TRAIN AND TEST DATA**

# %%
# A dictionary mapping words to an integer index
vocabulary = imdb.get_word_index()

index = dict([(value, key) for (key, value) in vocabulary.items()])

# %%
'''converts encoded text to human readable form.
    each integer in the text is looked up in the index, and 
    replaced by the corresponding word.
'''
X_train = [' '.join([index.get(i, '?') for i in x]) for x in X_train]
X_test = [' '.join([index.get(i, '?') for i in x]) for x in X_test]

# %%
X_train_preprocessed = []
for i in X_train:
    X_train_preprocessed.append(preprocessing(i))

X_test_preprocessed = []
for i in X_test:
    X_test_preprocessed.append(preprocessing(i))

# %%
X_train_preprocessed[0]
# Out:
# 'movi film get movi movi stori one br br one film'

# %%
X_test_preprocessed[0]
# Out:
# 'br one'

# %% [markdown]
# ### **BUILDING TF-IDF vectorizer**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# from keras.preprocessing.sequence import pad_sequences



vectorizer = TfidfVectorizer(max_features= max_features)
vectorizer.fit(X_train_preprocessed) 

X_train_2 = vectorizer.transform(X_train_preprocessed).todense()

X_test_2 = vectorizer.transform(X_test_preprocessed).todense()

# %%
np.set_printoptions(threshold=np.inf) # to prevent truncation out output resut
print(X_train_2[0][:20])
# Out:
# [[0.         0.         0.30788979 0.         0.         0.40583095
#   0.         0.31603217 0.         0.         0.         0.
#   0.         0.57512642 0.         0.46078001 0.         0.
#   0.         0.31231423 0.         0.         0.         0.        ]]

# %% [markdown]
# ### **DEFINE NODE RULE**

# %%
import copy
import numpy as np

# %%
class NodeRule:

    LT = 0 # 'less than'
    LE = 1 # 'less or equal to'

    def __init__(self, attribute, threshold, op):
        # [lower_bound] [op_left] value [op_right] [upper_bound]
        assert(op in ['gt', 'le'])
        self.attribute = attribute
        if op == 'le':
            self.lower_bound = -np.inf
            self.upper_bound = threshold
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LE
        else:
            self.lower_bound = threshold
            self.upper_bound = np.inf
            self.op_left = NodeRule.LT
            self.op_right = NodeRule.LT
    
    def __and__(self, other):
        new_rule = copy.copy(self)
        if self.lower_bound > other.lower_bound:
            new_rule.lower_bound = self.lower_bound
            new_rule.op_left = self.op_left
        elif self.lower_bound < other.lower_bound:
            new_rule.lower_bound = other.lower_bound
            new_rule.op_left = other.op_left
        else:
            new_rule.lower_bound = self.lower_bound
            if NodeRule.LT in [self.op_left, other.op_left]:
                new_rule.op_left = NodeRule.LT
            else:
                new_rule.op_left = NodeRule.LE
        if self.upper_bound < other.upper_bound:
            new_rule.upper_bound = self.upper_bound
            new_rule.op_right = self.op_right
        elif self.upper_bound > other.upper_bound:
            new_rule.upper_bound = other.upper_bound
            new_rule.op_right = other.op_right
        else:
            new_rule.upper_bound = self.upper_bound
            if NodeRule.LT in [self.op_right, other.op_right]:
                new_rule.op_right = NodeRule.LT
            else:
                new_rule.op_right = NodeRule.LE
        return new_rule

    def __str__(self):
        s = str(self.lower_bound) + ' '
        s += '<=' if self.op_left == NodeRule.LE else '<'
        s += ' x_%i ' % self.attribute
        s += '<=' if self.op_right == NodeRule.LE else '<'
        s += ' ' + str(self.upper_bound)
        return s
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ### **DEFINE PATH RULE**

# %%
class PathRule:
    
    def __init__(self, n_attributes):
        self.n_attributes = n_attributes
        self.node_rules = [NodeRule(i, -np.inf, 'gt') for i in range(n_attributes)]
    
    def set_global_bounds(self, lower_bounds, upper_bounds):
        for i in range(self.n_attributes):
            node_rule = NodeRule(i, -np.inf, 'gt')
            node_rule.op_left = NodeRule.LE
            node_rule.op_right = NodeRule.LE
            node_rule.lower_bound = lower_bounds[i]
            node_rule.upper_bound = upper_bounds[i]
            self.add(node_rule)
    
    def add(self, node_rule):
        assert(isinstance(node_rule, NodeRule))
        j = node_rule.attribute
        self.node_rules[j] = self.node_rules[j].__and__(node_rule)
    
    def sample(self, sampling='mean'):
        sample = np.empty(self.n_attributes)
        for i, rule in enumerate(self):
            if sampling == 'mean':
                sample[i] = (rule.lower_bound + rule.upper_bound) / 2.
            else:
                sample[i] = np.random.uniform(rule.lower_bound, rule.upper_bound)
        return sample
    
    def compute_volume(self):
        log_volume = 1
        for i in range(self.n_attributes):
            node_rule = self.node_rules[i]
            log_volume += (node_rule.upper_bound - node_rule.lower_bound)
            assert(node_rule.upper_bound >= node_rule.lower_bound)
        return log_volume
    
    def __len__(self):
        return len(self.node_rules)
    
    def __iter__(self):
        self.current_attribute = 0
        return self
    
    def __next__(self):
        self.current_attribute += 1
        try:
            result = self.node_rules[self.current_attribute-1]
        except IndexError:
            raise StopIteration
        return result
    
    def __str__(self):
        return str(self.node_rules)
    
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## **RANDOME TREE MODEL**

# %%
from sklearn.ensemble import RandomTreesEmbedding
from sklearn.tree import ExtraTreeRegressor

# %%
class CompletelyRandomTree:

    def __init__(self, sklearn_extra_tree, n_attributes):
        self.n_attributes = n_attributes
        self.tree = sklearn_extra_tree
        self.n_nodes = self.tree.tree_.node_count
        self.parent_ids = np.full(self.n_nodes, -1, dtype=np.int)
        self.operators = [None] * self.n_nodes
        tree = self.tree.tree_
        for i in range(self.n_nodes):
            parent_from_left = np.where(tree.children_left == i)[0]
            parent_from_right = np.where(tree.children_right == i)[0]
            if len(parent_from_left) == 1:
                self.parent_ids[i] = parent_from_left[0]
                self.operators[i] = 'le'
            elif len(parent_from_right) == 1:
                self.parent_ids[i] = parent_from_right[0]
                self.operators[i] = 'gt'
        self.leaf_to_node = np.where(tree.feature == -2)[0]
        self.node_to_leaf = {node_id: leaf_id for leaf_id, node_id in enumerate(self.leaf_to_node)}
        self.n_leafs = len(self.leaf_to_node)
    
    def encode(self, X):
        node_ids = self.tree.apply(X)
        return [self.node_to_leaf[node_id] for node_id in node_ids]
    
    def get_path_rule(self, default_path_rule, leaf_id):
        path_rule = copy.deepcopy(default_path_rule)
        tree = self.tree.tree_
        current_id = self.leaf_to_node[leaf_id]
        while current_id != 0:
            attribute = tree.feature[self.parent_ids[current_id]]
            bound = tree.threshold[self.parent_ids[current_id]]
            op = self.operators[current_id]
            path_rule.add(NodeRule(attribute, bound, op))
            current_id = self.parent_ids[current_id]
        return path_rule

# %% [markdown]
# ## **DEFINE ENCODER FOREST**

# %%
class EncoderForest:

    def __init__(self, n_components):
        self.trees = list()
        self.n_attributes = 0
        self.in_size = 0
        self.out_size = n_components
        self.global_lower_bounds = None
        self.global_upper_bounds = None
        self.default_path_rule = None
        self.unsupervised = True
    
    def fit(self, X, y=None, max_depth=10):
        self.unsupervised = (y is None)
        self.n_attributes = X.shape[1]
        self.in_size = X.shape[0]
        if y is None:
            forest = RandomTreesEmbedding(self.out_size, max_depth=max_depth)
            forest.fit(X)
        else:
            forest = RandomForestClassifier(n_estimators=self.out_size, max_depth=max_depth)
            forest.fit(X, y)
        for i in range(self.out_size):
            self.trees.append(CompletelyRandomTree(forest.estimators_[i], self.n_attributes))
        
        self.global_lower_bounds = np.min(X, axis=0).astype(np.double)
        self.global_upper_bounds = np.max(X, axis=0).astype(np.double)

        self.default_path_rule = PathRule(self.n_attributes)
        self.default_path_rule.set_global_bounds(self.global_lower_bounds, self.global_upper_bounds)
    
    def encode(self, X):
        n_samples = X.shape[0]
        out_dim = len(self.trees)
        encoded = np.empty((n_samples, out_dim), dtype=np.int)
        for i in range(out_dim):
            encoded[:, i] = self.trees[i].encode(X)
        return encoded

    def compute_rule_list(self, x):
        out_dim = len(self.trees)
        rule_list = list()
        for i in range(out_dim):
            path_rule = self.trees[i].get_path_rule(self.default_path_rule, x[i])
            rule_list.append(path_rule)
        return rule_list
    
    def decode(self, x):
        rule_list = self.compute_rule_list(x)
        MCR = self.calculate_MCR(rule_list)
        return MCR.sample(sampling='mean')

    def calculate_MCR(self, path_rule_list):
        MCR = copy.deepcopy(self.default_path_rule)
        n_attributes = len(MCR)
        n_trees = len(path_rule_list)

        for i in range(len(path_rule_list)):
            path_rule = path_rule_list[i]
            print("Volume of path rule %i: %f" % (i, path_rule.compute_volume()))
            for node_rule in path_rule.node_rules:
                MCR.add(node_rule)
        print("Volume of MCR: %f" % MCR.compute_volume())
        return MCR

# %%
X_train = np.array(X_train_2)
X_test = np.array(X_test_2)
y_train = np.array(y_train)
y_test = np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))
y_train = y_train.reshape((y_train.shape[0], -1))
y_test = y_test.reshape((y_test.shape[0], -1))
print("[IMDB] x_train.shape={}, y_train.shape={}".format(X_train.shape, y_train.shape))
print("[IMDB] x_test.shape={}, y_test.shape={}".format(X_test.shape, y_test.shape))
# Out:
# [IMDB] x_train.shape=(500, 24), y_train.shape=(500, 1)
# [IMDB] x_test.shape=(500, 24), y_test.shape=(500, 1)

# %%
print("Start Autoencoder using unsupervised model")
#eforest = RandomTreesEmbedding(n_estimators=n_trees, max_depth=None, n_jobs=-1, random_state=0)
encoder = EncoderForest(1000)
encoder.fit(X_train, max_depth=5)
print("end fit on unsupervised model")
# Out:
# Start Autoencoder using unsupervised model
# end fit on unsupervised model

# %% [markdown]
# ### **MODEL EVALUATION**

# %%
X_encode = encoder.encode(X_test)

# %%
X_encode.shape
# Out:
# (500, 1000)

# %%
len(X_encode)# = np.array(X_encode)
# Out:
# 500

# %%
#X_encode.shape

# %%
X_test.shape
# Out:
# (500, 24)

# %%
results = []
# for i in range(500):
for j in range(len(X_encode)):
    results.append(encoder.decode(X_encode[j]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Volume of path rule 5: 18.830339
# Volume of path rule 6: 18.483092
# Volume of path rule 7: 17.634047
# Volume of path rule 8: 18.382050
# Volume of path rule 9: 17.759197
# Volume of path rule 10: 17.524835
# Volume of path rule 11: 17.787146
# Volume of path rule 12: 18.265934
# Volume of path rule 13: 17.947879
# Volume of path rule 14: 18.708503
# Volume of path rule 15: 17.938761
# Volume of path rule 16: 18.259346
# Volume of path rule 17: 19.300599
# Volume of path rule 18: 18.216770
# Volume of path rule 19: 18.193441
# Volume of path rule 20: 18.499627
# Volume of path rule 21: 18.409971
# Volume of path rule 22: 18.390022
# Volume of path rule 23: 18.930251
# Volume of path rule 24: 18.395668
# Volume of path rule 25: 17.308239
# Volume of path rule 26: 19.079458
# Volume of path rule 27: 18.199461
# Volume of path rule 28: 18.399412
# Volume of path rule 29: 18.494621
# Volume of path rule 30: 18.137171
# Volume of path rule 31: 18.538897
# Volume of path rule 32: 17.974699
# Volume of path rule 33: 18.450153
# Volume of path rule 34: 19.429914
# Volume of path rule 35: 19.411301
# Volume of path rule 36: 17.853277
# Volume of path rule 37: 18.552176
# Volume of path rule 38: 17.077687
# Volume of path rule 39: 18.188785
# Volume of path rule 40: 19.125972
# Volume of path rule 41: 18.719698
# Volume of path rule 42: 17.905559
# Volume of path rule 43: 18.418607
# Volume of path rule 44: 17.926919
# Volume of path rule 45: 18.253328
# Volume of path rule 46: 18.598724
# Volume of path rule 47: 18.878226
# Volume of path rule 48: 18.388051
# Volume of path rule 49: 17.941900
# Volume of path rule 50: 17.881866
# Volume of path rule 51: 18.367900
# Volume of path rule 52: 19.494853
# Volume of path rule 53: 18.701047
# Volume of path rule 54: 19.031082
# Volume of path rule 55: 17.578282
# Volume of path rule 56: 18.523883
# Volume of path rule 57: 19.525840
# Volume of path rule 58: 19.041905
# Volume of path rule 59: 19.745474
# Volume of path rule 60: 17.968175
# Volume of path rule 61: 17.774736
# Volume of path rule 62: 17.441919
# Volume of path rule 63: 18.285172
# Volume of path rule 64: 18.855325
# Volume of path rule 65: 17.790601
# Volume of path rule 66: 18.384245
# Volume of path rule 67: 18.669113
# Volume of path rule 68: 18.388222
# Volume of path rule 69: 17.663266
# Volume of path rule 70: 18.379279
# Volume of path rule 71: 18.654766
# Volume of path rule 72: 18.537982
# Volume of path rule 73: 17.738363
# Volume of path rule 74: 19.028703
# Volume of path rule 75: 18.418838
# Volume of path rule 76: 18.005361
# Volume of path rule 77: 17.931713
# Volume of path rule 78: 18.136136
# Volume of path rule 79: 17.888181
# Volume of path rule 80: 17.958932
# Volume of path rule 81: 17.830700
# Volume of path rule 82: 18.084351
# Volume of path rule 83: 18.095105
# Volume of path rule 84: 18.269906
# Volume of path rule 85: 18.552605
# Volume of path rule 86: 18.605334
# Volume of path rule 87: 17.441820
# Volume of path rule 88: 17.564843
# Volume of path rule 89: 19.304869
# Volume of path rule 90: 17.472947
# Volume of path rule 91: 19.100586
# Volume of path rule 92: 18.371570
# Volume of path rule 93: 19.196767
# Volume of path rule 94: 18.087571
# Volume of path rule 95: 19.414645
# Volume of path rule 96: 19.156401
# Volume of path rule 97: 18.887300
# Volume of path rule 98: 18.324068
# Volume of path rule 99: 18.189456
# Volume of path rule 100: 17.174549
# Volume of path rule 101: 18.571897
# Volume of path rule 102: 18.686866
# Volume of path rule 103: 19.233526
# Volume of path rule 104: 18.194057
# Volume of path rule 105: 19.149796
# Volume of path rule 106: 18.010666
# Volume of path rule 107: 18.494063
# Volume of path rule 108: 18.452175
# Volume of path rule 109: 17.733559
# Volume of path rule 110: 17.618375
# Volume of path rule 111: 18.144952
# Volume of path rule 112: 17.506362
# Volume of path rule 113: 18.478205
# Volume of path rule 114: 18.596230
# Volume of path rule 115: 18.623276
# Volume of path rule 116: 18.189332
# Volume of path rule 117: 18.700696
# Volume of path rule 118: 18.375319
# Volume of path rule 119: 18.820798
# Volume of path rule 120: 19.052179
# Volume of path rule 121: 18.383128
# Volume of path rule 122: 17.990517
# Volume of path rule 123: 18.755583
# Volume of path rule 124: 17.988387
# Volume of path rule 125: 19.056731
# Volume of path rule 126: 17.813246
# Volume of path rule 127: 19.529373
# Volume of path rule 128: 18.107274
# Volume of path rule 129: 18.529558
# Volume of path rule 130: 17.832690
# Volume of path rule 131: 18.812805
# Volume of path rule 132: 18.705176
# Volume of path rule 133: 19.086766
# Volume of path rule 134: 18.328496
# Volume of path rule 135: 17.622008
# Volume of path rule 136: 18.030439
# Volume of path rule 137: 17.543213
# Volume of path rule 138: 18.530211
# Volume of path rule 139: 17.060691
# Volume of path rule 140: 18.587005
# Volume of path rule 141: 18.666316
# Volume of path rule 142: 18.124283
# Volume of path rule 143: 17.782906
# Volume of path rule 144: 17.906982
# Volume of path rule 145: 17.629223
# Volume of path rule 146: 18.307129
# Volume of path rule 147: 18.836249
# Volume of path rule 148: 18.127360
# Volume of path rule 149: 18.493448
# Volume of path rule 150: 18.299873
# Volume of path rule 151: 18.518597
# Volume of path rule 152: 17.936734
# Volume of path rule 153: 17.870221
# Volume of path rule 154: 19.088679
# Volume of path rule 155: 17.890206
# Volume of path rule 156: 18.473100
# Volume of path rule 157: 18.273923
# Volume of path rule 158: 18.428883
# Volume of path rule 159: 17.684887
# Volume of path rule 160: 18.381201
# Volume of path rule 161: 17.888696
# Volume of path rule 162: 18.200011
# Volume of path rule 163: 17.941164
# Volume of path rule 164: 18.367048
# Volume of path rule 165: 18.570431
# Volume of path rule 166: 18.303675
# Volume of path rule 167: 17.893242
# Volume of path rule 168: 18.463383
# Volume of path rule 169: 17.403532
# Volume of path rule 170: 17.779753
# Volume of path rule 171: 17.923466
# Volume of path rule 172: 18.700514
# Volume of path rule 173: 18.429732
# Volume of path rule 174: 18.407808
# Volume of path rule 175: 17.972750
# Volume of path rule 176: 18.296843
# Volume of path rule 177: 18.673455
# Volume of path rule 178: 18.844222
# Volume of path rule 179: 18.032341
# Volume of path rule 180: 17.173046
# Volume of path rule 181: 17.953494
# Volume of path rule 182: 18.313285
# Volume of path rule 183: 18.377019
# Volume of path rule 184: 17.541387
# Volume of path rule 185: 18.325891
# Volume of path rule 186: 18.563505
# Volume of path rule 187: 18.985329
# Volume of path rule 188: 17.610484
# Volume of path rule 189: 17.966180
# Volume of path rule 190: 19.005217
# Volume of path rule 191: 17.634936
# Volume of path rule 192: 18.568179
# Volume of path rule 193: 16.421639
# Volume of path rule 194: 19.600147
# Volume of path rule 195: 18.578100
# Volume of path rule 196: 18.159063
# Volume of path rule 197: 18.584596
# Volume of path rule 198: 17.592732
# Volume of path rule 199: 17.645090
# Volume of path rule 200: 17.397652
# Volume of path rule 201: 18.036559
# Volume of path rule 202: 18.160070
# Volume of path rule 203: 17.872888
# Volume of path rule 204: 19.075911
# Volume of path rule 205: 18.006036
# Volume of path rule 206: 18.442599
# Volume of path rule 207: 18.650880
# Volume of path rule 208: 18.599368
# Volume of path rule 209: 18.724199
# Volume of path rule 210: 18.429279
# Volume of path rule 211: 17.939780
# Volume of path rule 212: 19.106725
# Volume of path rule 213: 17.253205
# Volume of path rule 214: 18.596576
# Volume of path rule 215: 17.668960
# Volume of path rule 216: 19.137854
# Volume of path rule 217: 18.896020
# Volume of path rule 218: 18.046310
# Volume of path rule 219: 19.397817
# Volume of path rule 220: 17.945454
# Volume of path rule 221: 17.987955
# Volume of path rule 222: 19.297180
# Volume of path rule 223: 17.966146
# Volume of path rule 224: 19.189918
# Volume of path rule 225: 18.485714
# Volume of path rule 226: 17.689768
# Volume of path rule 227: 18.015813
# Volume of path rule 228: 18.835054
# Volume of path rule 229: 18.917352
# Volume of path rule 230: 17.489465
# Volume of path rule 231: 18.938092
# Volume of path rule 232: 18.733552
# Volume of path rule 233: 18.295747
# Volume of path rule 234: 17.518142
# Volume of path rule 235: 18.117917
# Volume of path rule 236: 17.563255
# Volume of path rule 237: 17.546503
# Volume of path rule 238: 18.241149
# Volume of path rule 239: 18.480634
# Volume of path rule 240: 18.590545
# Volume of path rule 241: 18.353766
# Volume of path rule 242: 18.325507
# Volume of path rule 243: 19.054115
# Volume of path rule 244: 17.924804
# Volume of path rule 245: 19.613981
# Volume of path rule 246: 19.400339
# Volume of path rule 247: 18.679820
# Volume of path rule 248: 18.494508
# Volume of path rule 249: 17.891074
# Volume of path rule 250: 17.325158
# Volume of path rule 251: 18.049129
# Volume of path rule 252: 17.859646
# Volume of path rule 253: 18.769083
# Volume of path rule 254: 17.163119
# Volume of path rule 255: 18.224773
# Volume of path rule 256: 18.938071
# Volume of path rule 257: 18.880489
# Volume of path rule 258: 17.599171
# Volume of path rule 259: 19.673591
# Volume of path rule 260: 18.145151
# Volume of path rule 261: 17.559174
# Volume of path rule 262: 18.518578
# Volume of path rule 263: 17.694661
# Volume of path rule 264: 18.298544
# Volume of path rule 265: 19.146220
# Volume of path rule 266: 18.621560
# Volume of path rule 267: 17.692618
# Volume of path rule 268: 18.904118
# Volume of path rule 269: 18.729161
# Volume of path rule 270: 19.037508
# Volume of path rule 271: 17.751936
# Volume of path rule 272: 18.223887
# Volume of path rule 273: 17.694539
# Volume of path rule 274: 18.967824
# Volume of path rule 275: 18.637107
# Volume of path rule 276: 18.574003
# Volume of path rule 277: 18.733874
# Volume of path rule 278: 17.833463
# Volume of path rule 279: 18.774494
# Volume of path rule 280: 18.344533
# Volume of path rule 281: 18.019904
# Volume of path rule 282: 19.446501
# Volume of path rule 283: 19.501533
# Volume of path rule 284: 18.410364
# Volume of path rule 285: 18.405584
# Volume of path rule 286: 18.185918
# Volume of path rule 287: 18.833239
# Volume of path rule 288: 18.208433
# Volume of path rule 289: 18.067998
# Volume of path rule 290: 18.397682
# Volume of path rule 291: 18.714948
# Volume of path rule 292: 18.429812
# Volume of path rule 293: 17.660479
# Volume of path rule 294: 19.119777
# Volume of path rule 295: 18.065485
# Volume of path rule 296: 19.026975
# Volume of path rule 297: 18.888733
# Volume of path rule 298: 18.520349
# Volume of path rule 299: 18.096538
# Volume of path rule 300: 17.955889
# Volume of path rule 301: 18.904743
# Volume of path rule 302: 17.896223
# Volume of path rule 303: 19.330852
# Volume of path rule 304: 17.481755
# Volume of path rule 305: 18.365216
# Volume of path rule 306: 18.237060
# Volume of path rule 307: 18.818702
# Volume of path rule 308: 18.410774
# Volume of path rule 309: 18.249824
# Volume of path rule 310: 19.093267
# Volume of path rule 311: 18.322445
# Volume of path rule 312: 18.507867
# Volume of path rule 313: 18.252073
# Volume of path rule 314: 18.845559
# Volume of path rule 315: 18.738150
# Volume of path rule 316: 17.646222
# Volume of path rule 317: 18.168732
# Volume of path rule 318: 17.757006
# Volume of path rule 319: 17.754812
# Volume of path rule 320: 19.151985
# Volume of path rule 321: 18.561606
# Volume of path rule 322: 18.213877
# Volume of path rule 323: 17.837472
# Volume of path rule 324: 18.125210
# Volume of path rule 325: 19.179371
# Volume of path rule 326: 18.646552
# Volume of path rule 327: 18.668781
# Volume of path rule 328: 17.855299
# Volume of path rule 329: 19.132016
# Volume of path rule 330: 18.824037
# Volume of path rule 331: 19.020497
# Volume of path rule 332: 17.842991
# Volume of path rule 333: 18.041518
# Volume of path rule 334: 17.589675
# Volume of path rule 335: 18.456572
# Volume of path rule 336: 17.555922
# Volume of path rule 337: 19.306907
# Volume of path rule 338: 17.690864
# Volume of path rule 339: 18.995869
# Volume of path rule 340: 18.558627
# Volume of path rule 341: 18.542147
# Volume of path rule 342: 19.428645
# Volume of path rule 343: 18.657161
# Volume of path rule 344: 17.849710
# Volume of path rule 345: 18.905202
# Volume of path rule 346: 18.232985
# Volume of path rule 347: 17.834619
# Volume of path rule 348: 18.602415
# Volume of path rule 349: 18.058527
# Volume of path rule 350: 18.260677
# Volume of path rule 351: 18.158495
# Volume of path rule 352: 17.794800
# Volume of path rule 353: 18.054258
# Volume of path rule 354: 18.109922
# Volume of path rule 355: 18.174604
# Volume of path rule 356: 18.560477
# Volume of path rule 357: 19.082993
# Volume of path rule 358: 18.298497
# Volume of path rule 359: 18.561394
# Volume of path rule 360: 17.557372
# Volume of path rule 361: 18.608478
# Volume of path rule 362: 17.310298
# Volume of path rule 363: 17.516299
# Volume of path rule 364: 18.830411
# Volume of path rule 365: 19.381075
# Volume of path rule 366: 17.566439
# Volume of path rule 367: 18.060880
# Volume of path rule 368: 17.743541
# Volume of path rule 369: 18.171734
# Volume of path rule 370: 17.363332
# Volume of path rule 371: 18.050589
# Volume of path rule 372: 18.200069
# Volume of path rule 373: 18.511645
# Volume of path rule 374: 18.357051
# Volume of path rule 375: 17.566924
# Volume of path rule 376: 17.667784
# Volume of path rule 377: 19.238598
# Volume of path rule 378: 18.507875
# Volume of path rule 379: 19.212531
# Volume of path rule 380: 17.578655
# Volume of path rule 381: 18.399751
# Volume of path rule 382: 17.511798
# Volume of path rule 383: 18.395458
# Volume of path rule 384: 19.264427
# Volume of path rule 385: 19.004353
# Volume of path rule 386: 18.627093
# Volume of path rule 387: 18.395048
# Volume of path rule 388: 18.086589
# Volume of path rule 389: 19.429430
# Volume of path rule 390: 18.416544
# Volume of path rule 391: 18.844425
# Volume of path rule 392: 17.590704
# Volume of path rule 393: 18.721279
# Volume of path rule 394: 19.328990
# Volume of path rule 395: 18.224961
# Volume of path rule 396: 18.420085
# Volume of path rule 397: 18.126525
# Volume of path rule 398: 18.579577
# Volume of path rule 399: 18.382598
# Volume of path rule 400: 18.695021
# Volume of path rule 401: 19.127881
# Volume of path rule 402: 19.575402
# Volume of path rule 403: 17.645319
# Volume of path rule 404: 18.307267
# Volume of path rule 405: 17.930766
# Volume of path rule 406: 17.505882
# Volume of path rule 407: 17.700816
# Volume of path rule 408: 18.214068
# Volume of path rule 409: 18.828100
# Volume of path rule 410: 18.308101
# Volume of path rule 411: 18.558626
# Volume of path rule 412: 17.376342
# Volume of path rule 413: 18.229862
# Volume of path rule 414: 18.305918
# Volume of path rule 415: 18.785069
# Volume of path rule 416: 19.622377
# Volume of path rule 417: 18.944642
# Volume of path rule 418: 18.618218
# Volume of path rule 419: 18.030182
# Volume of path rule 420: 18.364152
# Volume of path rule 421: 18.646480
# Volume of path rule 422: 17.809553
# Volume of path rule 423: 18.389389
# Volume of path rule 424: 18.377685
# Volume of path rule 425: 19.116669
# Volume of path rule 426: 18.457826
# Volume of path rule 427: 17.803890
# Volume of path rule 428: 17.542896
# Volume of path rule 429: 18.825221
# Volume of path rule 430: 18.579741
# Volume of path rule 431: 18.749730
# Volume of path rule 432: 18.496474
# Volume of path rule 433: 17.924706
# Volume of path rule 434: 17.288076
# Volume of path rule 435: 18.393658
# Volume of path rule 436: 18.160416
# Volume of path rule 437: 19.111859
# Volume of path rule 438: 17.602477
# Volume of path rule 439: 18.091313
# Volume of path rule 440: 19.252249
# Volume of path rule 441: 18.131037
# Volume of path rule 442: 17.930357
# Volume of path rule 443: 18.031587
# Volume of path rule 444: 19.464474
# Volume of path rule 445: 18.271572
# Volume of path rule 446: 19.374881
# Volume of path rule 447: 18.560233
# Volume of path rule 448: 18.536282
# Volume of path rule 449: 18.343605
# Volume of path rule 450: 18.754979
# Volume of path rule 451: 18.321340
# Volume of path rule 452: 19.057383
# Volume of path rule 453: 19.242024
# Volume of path rule 454: 17.439594
# Volume of path rule 455: 19.101749
# Volume of path rule 456: 18.499189
# Volume of path rule 457: 17.845617
# Volume of path rule 458: 18.088502
# Volume of path rule 459: 19.354325
# Volume of path rule 460: 19.260809
# Volume of path rule 461: 17.959239
# Volume of path rule 462: 18.434907
# Volume of path rule 463: 18.085995
# Volume of path rule 464: 18.797403
# Volume of path rule 465: 18.832008
# Volume of path rule 466: 18.410349
# Volume of path rule 467: 18.663617
# Volume of path rule 468: 19.402614
# Volume of path rule 469: 18.268658
# Volume of path rule 470: 17.841272
# Volume of path rule 471: 17.399595
# Volume of path rule 472: 17.889961
# Volume of path rule 473: 17.643589
# Volume of path rule 474: 18.296719
# Volume of path rule 475: 17.846024
# Volume of path rule 476: 18.026830
# Volume of path rule 477: 17.957021
# Volume of path rule 478: 18.210477
# Volume of path rule 479: 19.039107
# Volume of path rule 480: 18.561131
# Volume of path rule 481: 19.001946
# Volume of path rule 482: 18.811529
# Volume of path rule 483: 18.899404
# Volume of path rule 484: 17.582259
# Volume of path rule 485: 18.260768
# Volume of path rule 486: 18.426083
# Volume of path rule 487: 17.876873
# Volume of path rule 488: 17.184531
# Volume of path rule 489: 18.947696
# Volume of path rule 490: 18.550633
# Volume of path rule 491: 17.053713
# Volume of path rule 492: 18.752290
# Volume of path rule 493: 18.068655
# Volume of path rule 494: 18.672130
# Volume of path rule 495: 18.957870
# Volume of path rule 496: 18.044685
# Volume of path rule 497: 17.966474
# Volume of path rule 498: 18.071986
# Volume of path rule 499: 18.622484
# Volume of path rule 500: 18.341733
# Volume of path rule 501: 18.642458
# Volume of path rule 502: 18.185958
# Volume of path rule 503: 17.772523
# Volume of path rule 504: 18.490501
# Volume of path rule 505: 18.008366
# Volume of path rule 506: 18.576483
# Volume of path rule 507: 18.482414
# Volume of path rule 508: 18.792126
# Volume of path rule 509: 18.581925
# Volume of path rule 510: 19.328054
# Volume of path rule 511: 17.750893
# Volume of path rule 512: 18.815533
# Volume of path rule 513: 19.116565
# Volume of path rule 514: 18.879049
# Volume of path rule 515: 18.711346
# Volume of path rule 516: 18.650195
# Volume of path rule 517: 17.345730
# Volume of path rule 518: 18.292324
# Volume of path rule 519: 18.533453
# Volume of path rule 520: 17.984646
# Volume of path rule 521: 18.383333
# Volume of path rule 522: 19.210670
# Volume of path rule 523: 17.380934
# Volume of path rule 524: 18.773705
# Volume of path rule 525: 19.054264
# Volume of path rule 526: 18.615302
# Volume of path rule 527: 18.071525
# Volume of path rule 528: 18.133831
# Volume of path rule 529: 18.519645
# Volume of path rule 530: 17.648799
# Volume of path rule 531: 18.892294
# Volume of path rule 532: 17.239099
# Volume of path rule 533: 17.261084
# Volume of path rule 534: 18.536252
# Volume of path rule 535: 17.876260
# Volume of path rule 536: 18.412427
# Volume of path rule 537: 18.212900
# Volume of path rule 538: 18.323268
# Volume of path rule 539: 18.173040
# Volume of path rule 540: 17.739329
# Volume of path rule 541: 17.885463
# Volume of path rule 542: 18.957982
# Volume of path rule 543: 17.637856
# Volume of path rule 544: 18.130292
# Volume of path rule 545: 18.040297
# Volume of path rule 546: 18.718757
# Volume of path rule 547: 18.572743
# Volume of path rule 548: 16.752464
# Volume of path rule 549: 18.350266
# Volume of path rule 550: 18.225555
# Volume of path rule 551: 18.427976
# Volume of path rule 552: 19.163530
# Volume of path rule 553: 18.197496
# Volume of path rule 554: 19.243854
# Volume of path rule 555: 17.617529
# Volume of path rule 556: 18.886407
# Volume of path rule 557: 18.489666
# Volume of path rule 558: 18.189223
# Volume of path rule 559: 18.181342
# Volume of path rule 560: 18.914331
# Volume of path rule 561: 17.991290
# Volume of path rule 562: 19.215137
# Volume of path rule 563: 18.401801
# Volume of path rule 564: 18.930756
# Volume of path rule 565: 17.641353
# Volume of path rule 566: 17.631742
# Volume of path rule 567: 18.537648
# Volume of path rule 568: 19.068799
# Volume of path rule 569: 19.011632
# Volume of path rule 570: 18.436686
# Volume of path rule 571: 18.477985
# Volume of path rule 572: 18.066778
# Volume of path rule 573: 18.601541
# Volume of path rule 574: 19.893537
# Volume of path rule 575: 19.092989
# Volume of path rule 576: 19.517205
# Volume of path rule 577: 18.257956
# Volume of path rule 578: 18.293953
# Volume of path rule 579: 17.962848
# Volume of path rule 580: 18.373437
# Volume of path rule 581: 18.633210
# Volume of path rule 582: 17.226045
# Volume of path rule 583: 19.039099
# Volume of path rule 584: 18.574215
# Volume of path rule 585: 18.198727
# Volume of path rule 586: 17.667718
# Volume of path rule 587: 17.964087
# Volume of path rule 588: 17.919409
# Volume of path rule 589: 17.900467
# Volume of path rule 590: 18.338976
# Volume of path rule 591: 17.199698
# Volume of path rule 592: 18.512779
# Volume of path rule 593: 18.138041
# Volume of path rule 594: 17.177095
# Volume of path rule 595: 17.853929
# Volume of path rule 596: 18.000837
# Volume of path rule 597: 17.462599
# Volume of path rule 598: 18.984328
# Volume of path rule 599: 18.476547
# Volume of path rule 600: 18.824281
# Volume of path rule 601: 18.027638
# Volume of path rule 602: 19.145762
# Volume of path rule 603: 19.286886
# Volume of path rule 604: 18.122383
# Volume of path rule 605: 18.307402
# Volume of path rule 606: 18.559286
# Volume of path rule 607: 18.507713
# Volume of path rule 608: 19.132151
# Volume of path rule 609: 18.085486
# Volume of path rule 610: 18.501747
# Volume of path rule 611: 17.917190
# Volume of path rule 612: 17.815187
# Volume of path rule 613: 18.256729
# Volume of path rule 614: 18.264231
# Volume of path rule 615: 18.270498
# Volume of path rule 616: 18.869382
# Volume of path rule 617: 18.928709
# Volume of path rule 618: 18.487624
# Volume of path rule 619: 17.694482
# Volume of path rule 620: 18.161856
# Volume of path rule 621: 18.677840
# Volume of path rule 622: 18.003292
# Volume of path rule 623: 18.047288
# Volume of path rule 624: 17.800142
# Volume of path rule 625: 18.961508
# Volume of path rule 626: 18.027143
# Volume of path rule 627: 17.978711
# Volume of path rule 628: 18.954605
# Volume of path rule 629: 17.681804
# Volume of path rule 630: 18.253540
# Volume of path rule 631: 18.718774
# Volume of path rule 632: 18.028456
# Volume of path rule 633: 18.290963
# Volume of path rule 634: 19.212583
# Volume of path rule 635: 19.469608
# Volume of path rule 636: 19.319670
# Volume of path rule 637: 18.395612
# Volume of path rule 638: 18.672378
# Volume of path rule 639: 18.506866
# Volume of path rule 640: 18.349804
# Volume of path rule 641: 18.057385
# Volume of path rule 642: 17.955385
# Volume of path rule 643: 17.597451
# Volume of path rule 644: 18.529980
# Volume of path rule 645: 18.071391
# Volume of path rule 646: 19.973172
# Volume of path rule 647: 18.235544
# Volume of path rule 648: 17.792801
# Volume of path rule 649: 18.416723
# Volume of path rule 650: 17.887475
# Volume of path rule 651: 18.397893
# Volume of path rule 652: 18.495255
# Volume of path rule 653: 17.135639
# Volume of path rule 654: 18.421440
# Volume of path rule 655: 18.681183
# Volume of path rule 656: 18.890951
# Volume of path rule 657: 17.929441
# Volume of path rule 658: 17.967111
# Volume of path rule 659: 18.269040
# Volume of path rule 660: 19.035107
# Volume of path rule 661: 17.175634
# Volume of path rule 662: 18.673341
# Volume of path rule 663: 16.987128
# Volume of path rule 664: 18.891258
# Volume of path rule 665: 16.744780
# Volume of path rule 666: 17.399489
# Volume of path rule 667: 18.615265
# Volume of path rule 668: 19.125850
# Volume of path rule 669: 18.199606
# Volume of path rule 670: 19.214620
# Volume of path rule 671: 17.616351
# Volume of path rule 672: 19.291229
# Volume of path rule 673: 18.416414
# Volume of path rule 674: 17.859990
# Volume of path rule 675: 18.059943
# Volume of path rule 676: 18.078679
# Volume of path rule 677: 17.256265
# Volume of path rule 678: 19.185332
# Volume of path rule 679: 19.066966
# Volume of path rule 680: 18.405290
# Volume of path rule 681: 18.075007
# Volume of path rule 682: 18.424716
# Volume of path rule 683: 17.666012
# Volume of path rule 684: 18.438777
# Volume of path rule 685: 18.328053
# Volume of path rule 686: 18.891096
# Volume of path rule 687: 18.911482
# Volume of path rule 688: 18.337156
# Volume of path rule 689: 18.550873
# Volume of path rule 690: 19.002219
# Volume of path rule 691: 18.974378
# Volume of path rule 692: 17.793202
# Volume of path rule 693: 18.077116
# Volume of path rule 694: 18.246500
# Volume of path rule 695: 18.672658
# Volume of path rule 696: 19.446438
# Volume of path rule 697: 18.662984
# Volume of path rule 698: 17.670553
# Volume of path rule 699: 18.937078
# Volume of path rule 700: 18.546100
# Volume of path rule 701: 18.222025
# Volume of path rule 702: 19.115897
# Volume of path rule 703: 17.855935
# Volume of path rule 704: 18.580631
# Volume of path rule 705: 19.393445
# Volume of path rule 706: 17.363400
# Volume of path rule 707: 17.989878
# Volume of path rule 708: 17.944000
# Volume of path rule 709: 18.484742
# Volume of path rule 710: 19.372189
# Volume of path rule 711: 18.575327
# Volume of path rule 712: 18.086381
# Volume of path rule 713: 18.416466
# Volume of path rule 714: 18.073702
# Volume of path rule 715: 18.158540
# Volume of path rule 716: 17.797233
# Volume of path rule 717: 18.419455
# Volume of path rule 718: 18.428789
# Volume of path rule 719: 17.521340
# Volume of path rule 720: 18.389856
# Volume of path rule 721: 18.390201
# Volume of path rule 722: 18.582128
# Volume of path rule 723: 18.157397
# Volume of path rule 724: 19.292387
# Volume of path rule 725: 18.179176
# Volume of path rule 726: 18.080429
# Volume of path rule 727: 18.839779
# Volume of path rule 728: 18.353791
# Volume of path rule 729: 18.709943
# Volume of path rule 730: 18.315019
# Volume of path rule 731: 18.749483
# Volume of path rule 732: 18.998377
# Volume of path rule 733: 18.974824
# Volume of path rule 734: 18.627637
# Volume of path rule 735: 18.401981
# Volume of path rule 736: 18.449954
# Volume of path rule 737: 18.418786
# Volume of path rule 738: 18.830026
# Volume of path rule 739: 18.243669
# Volume of path rule 740: 18.114587
# Volume of path rule 741: 17.900783
# Volume of path rule 742: 18.540016
# Volume of path rule 743: 17.682760
# Volume of path rule 744: 18.721804
# Volume of path rule 745: 18.287241
# Volume of path rule 746: 19.096399
# Volume of path rule 747: 17.837945
# Volume of path rule 748: 18.197609
# Volume of path rule 749: 18.559734
# Volume of path rule 750: 18.619221
# Volume of path rule 751: 18.267625
# Volume of path rule 752: 18.241163
# Volume of path rule 753: 18.992682
# Volume of path rule 754: 18.473759
# Volume of path rule 755: 18.413639
# Volume of path rule 756: 18.272700
# Volume of path rule 757: 17.984562
# Volume of path rule 758: 19.038734
# Volume of path rule 759: 18.608509
# Volume of path rule 760: 17.977848
# Volume of path rule 761: 18.962664
# Volume of path rule 762: 18.661962
# Volume of path rule 763: 18.829689
# Volume of path rule 764: 18.678750
# Volume of path rule 765: 18.274866
# Volume of path rule 766: 17.924333
# Volume of path rule 767: 18.544408
# Volume of path rule 768: 19.071840
# Volume of path rule 769: 18.096879
# Volume of path rule 770: 19.186510
# Volume of path rule 771: 18.352540
# Volume of path rule 772: 18.779246
# Volume of path rule 773: 17.729118
# Volume of path rule 774: 17.552480
# Volume of path rule 775: 18.323151
# Volume of path rule 776: 16.946526
# Volume of path rule 777: 17.645204
# Volume of path rule 778: 17.760665
# Volume of path rule 779: 18.219546
# Volume of path rule 780: 18.238632
# Volume of path rule 781: 18.511060
# Volume of path rule 782: 17.774224
# Volume of path rule 783: 17.954898
# Volume of path rule 784: 19.157502
# Volume of path rule 785: 17.522014
# Volume of path rule 786: 18.410104
# Volume of path rule 787: 18.327478
# Volume of path rule 788: 18.970382
# Volume of path rule 789: 18.769578
# Volume of path rule 790: 18.762773
# Volume of path rule 791: 17.983872
# Volume of path rule 792: 18.648508
# Volume of path rule 793: 18.227206
# Volume of path rule 794: 18.551212
# Volume of path rule 795: 18.722099
# Volume of path rule 796: 18.506999
# Volume of path rule 797: 18.281922
# Volume of path rule 798: 17.545152
# Volume of path rule 799: 18.403611
# Volume of path rule 800: 18.889573
# Volume of path rule 801: 18.398247
# Volume of path rule 802: 18.652201
# Volume of path rule 803: 18.145338
# Volume of path rule 804: 17.967857
# Volume of path rule 805: 18.149387
# Volume of path rule 806: 18.908158
# Volume of path rule 807: 18.418133
# Volume of path rule 808: 19.174034
# Volume of path rule 809: 18.905523
# Volume of path rule 810: 18.305452
# Volume of path rule 811: 19.386850
# Volume of path rule 812: 17.919207
# Volume of path rule 813: 18.505864
# Volume of path rule 814: 19.065674
# Volume of path rule 815: 18.315232
# Volume of path rule 816: 18.390049
# Volume of path rule 817: 18.351482
# Volume of path rule 818: 17.201748
# Volume of path rule 819: 18.340364
# Volume of path rule 820: 19.219559
# Volume of path rule 821: 17.271002
# Volume of path rule 822: 18.604255
# Volume of path rule 823: 18.292149
# Volume of path rule 824: 18.233312
# Volume of path rule 825: 18.532983
# Volume of path rule 826: 17.175866
# Volume of path rule 827: 19.388599
# Volume of path rule 828: 18.376837
# Volume of path rule 829: 18.152153
# Volume of path rule 830: 18.132049
# Volume of path rule 831: 18.993146
# Volume of path rule 832: 18.614997
# Volume of path rule 833: 17.484972
# Volume of path rule 834: 18.579087
# Volume of path rule 835: 18.862962
# Volume of path rule 836: 19.047420
# Volume of path rule 837: 18.014769
# Volume of path rule 838: 18.534358
# Volume of path rule 839: 19.054294
# Volume of path rule 840: 18.168499
# Volume of path rule 841: 17.774122
# Volume of path rule 842: 18.290221
# Volume of path rule 843: 17.857844
# Volume of path rule 844: 18.631450
# Volume of path rule 845: 18.324341
# Volume of path rule 846: 18.126558
# Volume of path rule 847: 17.929969
# Volume of path rule 848: 19.408733
# Volume of path rule 849: 18.500942
# Volume of path rule 850: 18.189463
# Volume of path rule 851: 18.263110
# Volume of path rule 852: 17.774415
# Volume of path rule 853: 17.883451
# Volume of path rule 854: 18.622243
# Volume of path rule 855: 17.629998
# Volume of path rule 856: 18.370903
# Volume of path rule 857: 18.397729
# Volume of path rule 858: 17.124862
# Volume of path rule 859: 18.859413
# Volume of path rule 860: 18.104744
# Volume of path rule 861: 18.282021
# Volume of path rule 862: 18.465274
# Volume of path rule 863: 18.526313
# Volume of path rule 864: 18.290308
# Volume of path rule 865: 18.337880
# Volume of path rule 866: 18.323850
# Volume of path rule 867: 17.925186
# Volume of path rule 868: 17.949864
# Volume of path rule 869: 18.071031
# Volume of path rule 870: 18.181750
# Volume of path rule 871: 18.755249
# Volume of path rule 872: 18.992705
# Volume of path rule 873: 17.773458
# Volume of path rule 874: 18.605390
# Volume of path rule 875: 18.256583
# Volume of path rule 876: 17.485009
# Volume of path rule 877: 17.978664
# Volume of path rule 878: 17.804702
# Volume of path rule 879: 18.280266
# Volume of path rule 880: 18.363579
# Volume of path rule 881: 19.360658
# Volume of path rule 882: 18.086161
# Volume of path rule 883: 18.646462
# Volume of path rule 884: 19.911282
# Volume of path rule 885: 18.156786
# Volume of path rule 886: 18.094385
# Volume of path rule 887: 17.937623
# Volume of path rule 888: 19.113944
# Volume of path rule 889: 18.493431
# Volume of path rule 890: 17.780570
# Volume of path rule 891: 18.070368
# Volume of path rule 892: 18.608386
# Volume of path rule 893: 18.672767
# Volume of path rule 894: 18.706399
# Volume of path rule 895: 18.450415
# Volume of path rule 896: 18.415699
# Volume of path rule 897: 18.149621
# Volume of path rule 898: 18.363662
# Volume of path rule 899: 19.093145
# Volume of path rule 900: 17.378922
# Volume of path rule 901: 18.665036
# Volume of path rule 902: 18.029606
# Volume of path rule 903: 19.165068
# Volume of path rule 904: 17.931269
# Volume of path rule 905: 17.832445
# Volume of path rule 906: 18.799219
# Volume of path rule 907: 17.997151
# Volume of path rule 908: 18.977263
# Volume of path rule 909: 17.918227
# Volume of path rule 910: 19.013521
# Volume of path rule 911: 17.785498
# Volume of path rule 912: 17.711891
# Volume of path rule 913: 18.079144
# Volume of path rule 914: 17.708033
# Volume of path rule 915: 18.806780
# Volume of path rule 916: 17.350350
# Volume of path rule 917: 17.989703
# Volume of path rule 918: 18.186179
# Volume of path rule 919: 17.327685
# Volume of path rule 920: 18.542271
# Volume of path rule 921: 17.672802
# Volume of path rule 922: 18.393423
# Volume of path rule 923: 18.518502
# Volume of path rule 924: 18.195388
# Volume of path rule 925: 18.714253
# Volume of path rule 926: 17.981666
# Volume of path rule 927: 18.536321
# Volume of path rule 928: 19.201495
# Volume of path rule 929: 18.369774
# Volume of path rule 930: 18.119853
# Volume of path rule 931: 17.355354
# Volume of path rule 932: 18.470256
# Volume of path rule 933: 18.094362
# Volume of path rule 934: 18.737125
# Volume of path rule 935: 19.236925
# Volume of path rule 936: 18.128192
# Volume of path rule 937: 18.235639
# Volume of path rule 938: 17.387727
# Volume of path rule 939: 18.825874
# Volume of path rule 940: 19.304941
# Volume of path rule 941: 18.268883
# Volume of path rule 942: 18.456846
# Volume of path rule 943: 18.346278
# Volume of path rule 944: 17.839199
# Volume of path rule 945: 18.263697
# Volume of path rule 946: 17.791064
# Volume of path rule 947: 18.597255
# Volume of path rule 948: 18.329953
# Volume of path rule 949: 17.916609
# Volume of path rule 950: 16.980888
# Volume of path rule 951: 18.239094
# Volume of path rule 952: 18.585431
# Volume of path rule 953: 17.055259
# Volume of path rule 954: 18.597231
# Volume of path rule 955: 18.656126
# Volume of path rule 956: 18.110375
# Volume of path rule 957: 18.484989
# Volume of path rule 958: 17.896117
# Volume of path rule 959: 18.912009
# Volume of path rule 960: 18.349579
# Volume of path rule 961: 17.865984
# Volume of path rule 962: 18.535245
# Volume of path rule 963: 18.309636
# Volume of path rule 964: 18.083441
# Volume of path rule 965: 18.374349
# Volume of path rule 966: 16.698978
# Volume of path rule 967: 19.241897
# Volume of path rule 968: 18.377572
# Volume of path rule 969: 17.314809
# Volume of path rule 970: 17.849808
# Volume of path rule 971: 19.511730
# Volume of path rule 972: 19.641727
# Volume of path rule 973: 18.883885
# Volume of path rule 974: 18.718222
# Volume of path rule 975: 17.503709
# Volume of path rule 976: 17.881791
# Volume of path rule 977: 18.420404
# Volume of path rule 978: 18.179366
# Volume of path rule 979: 17.955827
# Volume of path rule 980: 17.018711
# Volume of path rule 981: 18.074456
# Volume of path rule 982: 17.866527
# Volume of path rule 983: 17.807526
# Volume of path rule 984: 18.581037
# Volume of path rule 985: 19.924254
# Volume of path rule 986: 17.873236
# Volume of path rule 987: 17.490025
# Volume of path rule 988: 18.325050
# Volume of path rule 989: 18.926237
# Volume of path rule 990: 18.030890
# Volume of path rule 991: 18.764070
# Volume of path rule 992: 17.577545
# Volume of path rule 993: 18.011581
# Volume of path rule 994: 17.803184
# Volume of path rule 995: 17.876364
# Volume of path rule 996: 18.460705
# Volume of path rule 997: 18.480731
# Volume of path rule 998: 17.400902
# Volume of path rule 999: 18.019266
# Volume of MCR: 1.063034
# Volume of path rule 0: 18.398030
# Volume of path rule 1: 19.375686
# Volume of path rule 2: 18.951706
# Volume of path rule 3: 18.789811
# Volume of path rule 4: 18.083745
# Volume of path rule 5: 18.830339
# Volume of path rule 6: 18.483092
# Volume of path rule 7: 18.124967
# Volume of path rule 8: 18.382050
# Volume of path rule 9: 17.759197
# Volume of path rule 10: 17.524835
# Volume of path rule 11: 17.941028
# Volume of path rule 12: 18.265934
# Volume of path rule 13: 17.947879
# Volume of path rule 14: 18.708503
# Volume of path rule 15: 17.938761
# Volume of path rule 16: 18.259346
# Volume of path rule 17: 19.300599
# Volume of path rule 18: 18.216770
# Volume of path rule 19: 18.032031
# Volume of path rule 20: 17.745495
# Volume of path rule 21: 18.265253
# Volume of path rule 22: 18.390022
# Volume of path rule 23: 18.930251
# Volume of path rule 24: 18.892085
# Volume of path rule 25: 18.721465
# Volume of path rule 26: 19.079458
# Volume of path rule 27: 18.199461
# Volume of path rule 28: 18.750460
# Volume of path rule 29: 19.435782
# Volume of path rule 30: 17.346154
# Volume of path rule 31: 18.538897
# Volume of path rule 32: 17.697058
# Volume of path rule 33: 18.222437
# Volume of path rule 34: 19.429914
# Volume of path rule 35: 19.411301
# Volume of path rule 36: 18.044694
# Volume of path rule 37: 19.608905
# Volume of path rule 38: 17.077687
# Volume of path rule 39: 18.452503
# Volume of path rule 40: 19.125972
# Volume of path rule 41: 18.541940
# Volume of path rule 42: 18.360259
# Volume of path rule 43: 18.418607
# Volume of path rule 44: 18.711359
# Volume of path rule 45: 18.253328
# Volume of path rule 46: 19.382253
# Volume of path rule 47: 18.878226
# Volume of path rule 48: 18.712180
# Volume of path rule 49: 17.988374
# Volume of path rule 50: 18.020012
# Volume of path rule 51: 18.367900
# Volume of path rule 52: 19.494853
# Volume of path rule 53: 18.847543
# Volume of path rule 54: 19.031082
# Volume of path rule 55: 18.792585
# Volume of path rule 56: 19.092465
# Volume of path rule 57: 19.525840
# Volume of path rule 58: 18.550460
# Volume of path rule 59: 19.745474
# Volume of path rule 60: 17.968175
# Volume of path rule 61: 17.694676
# Volume of path rule 62: 17.375337
# Volume of path rule 63: 18.285172
# Volume of path rule 64: 18.855325
# Volume of path rule 65: 17.928725
# Volume of path rule 66: 17.128992
# Volume of path rule 67: 17.843495
# Volume of path rule 68: 18.044422
# Volume of path rule 69: 17.839171
# Volume of path rule 70: 19.482731
# Volume of path rule 71: 19.263771
# Volume of path rule 72: 19.569871
# Volume of path rule 73: 17.885880
# Volume of path rule 74: 18.515000
# Volume of path rule 75: 18.813676
# Volume of path rule 76: 18.773416
# Volume of path rule 77: 18.528429
# Volume of path rule 78: 18.317759
# Volume of path rule 79: 17.888181
# Volume of path rule 80: 17.958932
# Volume of path rule 81: 18.053709
# Volume of path rule 82: 18.779134
# Volume of path rule 83: 18.095105
# Volume of path rule 84: 18.779925
# Volume of path rule 85: 19.107812
# Volume of path rule 86: 18.605334
# Volume of path rule 87: 18.691233
# Volume of path rule 88: 18.925335
# Volume of path rule 89: 19.304869
# Volume of path rule 90: 18.893030
# Volume of path rule 91: 18.819042
# Volume of path rule 92: 17.949161
# Volume of path rule 93: 19.196767
# Volume of path rule 94: 18.859360
# Volume of path rule 95: 19.414645
# Volume of path rule 96: 19.006777
# Volume of path rule 97: 18.887300
# Volume of path rule 98: 18.718836
# Volume of path rule 99: 18.189456
# Volume of path rule 100: 17.935862
# Volume of path rule 101: 18.744039
# Volume of path rule 102: 18.892734
# Volume of path rule 103: 19.233526
# Volume of path rule 104: 18.194057
# Volume of path rule 105: 19.149796
# Volume of path rule 106: 18.876114
# Volume of path rule 107: 18.494063
# Volume of path rule 108: 18.746584
# Volume of path rule 109: 17.733559
# Volume of path rule 110: 18.114118
# Volume of path rule 111: 17.826722
# Volume of path rule 112: 18.830688
# Volume of path rule 113: 19.268013
# Volume of path rule 114: 18.596230
# Volume of path rule 115: 18.623276
# Volume of path rule 116: 19.277942
# Volume of path rule 117: 18.700696
# Volume of path rule 118: 18.529590
# Volume of path rule 119: 18.820798
# Volume of path rule 120: 19.052179
# Volume of path rule 121: 17.826551
# Volume of path rule 122: 17.980007
# Volume of path rule 123: 19.360540
# Volume of path rule 124: 17.988387
# Volume of path rule 125: 19.056731
# Volume of path rule 126: 18.373111
# Volume of path rule 127: 19.529373
# Volume of path rule 128: 18.509484
# Volume of path rule 129: 18.529558
# Volume of path rule 130: 19.241191
# Volume of path rule 131: 19.677082
# Volume of path rule 132: 18.705176
# Volume of path rule 133: 19.086766
# Volume of path rule 134: 18.583654
# Volume of path rule 135: 18.558475
# Volume of path rule 136: 18.255588
# Volume of path rule 137: 18.012913
# Volume of path rule 138: 18.670565
# Volume of path rule 139: 18.450916
# Volume of path rule 140: 18.496121
# Volume of path rule 141: 19.223731
# Volume of path rule 142: 18.342053
# Volume of path rule 143: 19.089622
# Volume of path rule 144: 18.132096
# Volume of path rule 145: 17.629223
# Volume of path rule 146: 19.062705
# Volume of path rule 147: 18.836249
# Volume of path rule 148: 18.127360
# Volume of path rule 149: 18.886880
# Volume of path rule 150: 18.299873
# Volume of path rule 151: 18.518597
# Volume of path rule 152: 17.936734
# Volume of path rule 153: 18.158550
# Volume of path rule 154: 17.694477
# Volume of path rule 155: 18.634062
# Volume of path rule 156: 18.473100
# Volume of path rule 157: 19.183149
# Volume of path rule 158: 19.028443
# Volume of path rule 159: 17.684887
# Volume of path rule 160: 18.434964
# Volume of path rule 161: 17.574574
# Volume of path rule 162: 18.200011
# Volume of path rule 163: 18.438939
# Volume of path rule 164: 18.367048
# Volume of path rule 165: 17.825416
# Volume of path rule 166: 18.303675
# Volume of path rule 167: 17.893242
# Volume of path rule 168: 18.463383
# Volume of path rule 169: 17.230207
# Volume of path rule 170: 17.836356
# Volume of path rule 171: 17.923466
# Volume of path rule 172: 17.986124
# Volume of path rule 173: 18.429732
# Volume of path rule 174: 19.230740
# Volume of path rule 175: 18.597338
# Volume of path rule 176: 18.035182
# Volume of path rule 177: 18.673455
# Volume of path rule 178: 18.844222
# Volume of path rule 179: 18.827809
# Volume of path rule 180: 17.711491
# Volume of path rule 181: 18.993159
# Volume of path rule 182: 18.172431
# Volume of path rule 183: 18.582241
# Volume of path rule 184: 18.010977
# Volume of path rule 185: 18.060026
# Volume of path rule 186: 19.140544
# Volume of path rule 187: 18.818057
# Volume of path rule 188: 18.066349
# Volume of path rule 189: 17.952959
# Volume of path rule 190: 18.600012
# Volume of path rule 191: 18.386632
# Volume of path rule 192: 19.241792
# Volume of path rule 193: 17.959089
# Volume of path rule 194: 18.637329
# Volume of path rule 195: 18.187613
# Volume of path rule 196: 18.159063
# Volume of path rule 197: 18.284671
# Volume of path rule 198: 18.068800
# Volume of path rule 199: 18.304888
# Volume of path rule 200: 18.848477
# Volume of path rule 201: 19.248143
# Volume of path rule 202: 19.069717
# Volume of path rule 203: 17.872888
# Volume of path rule 204: 19.075911
# Volume of path rule 205: 17.977963
# Volume of path rule 206: 18.442599
# Volume of path rule 207: 18.650880
# Volume of path rule 208: 18.070019
# Volume of path rule 209: 17.181787
# Volume of path rule 210: 17.912089
# Volume of path rule 211: 18.560127
# Volume of path rule 212: 19.106725
# Volume of path rule 213: 19.395087
# Volume of path rule 214: 18.596576
# Volume of path rule 215: 17.668960
# Volume of path rule 216: 18.753842
# Volume of path rule 217: 17.798470
# Volume of path rule 218: 18.795114
# Volume of path rule 219: 19.397817
# Volume of path rule 220: 17.945454
# Volume of path rule 221: 18.598735
# Volume of path rule 222: 18.966135
# Volume of path rule 223: 17.966146
# Volume of path rule 224: 19.189918
# Volume of path rule 225: 18.485714
# Volume of path rule 226: 17.689768
# Volume of path rule 227: 18.015813
# Volume of path rule 228: 18.835054
# Volume of path rule 229: 18.917352
# Volume of path rule 230: 17.100193
# Volume of path rule 231: 18.938092
# Volume of path rule 232: 18.733552
# Volume of path rule 233: 18.295747
# Volume of path rule 234: 18.624350
# Volume of path rule 235: 19.455833
# Volume of path rule 236: 18.518189
# Volume of path rule 237: 18.837709
# Volume of path rule 238: 18.241149
# Volume of path rule 239: 18.661101
# Volume of path rule 240: 18.685622
# Volume of path rule 241: 18.353766
# Volume of path rule 242: 18.325507
# Volume of path rule 243: 19.126135
# Volume of path rule 244: 17.899190
# Volume of path rule 245: 19.613981
# Volume of path rule 246: 19.400339
# Volume of path rule 247: 18.679820
# Volume of path rule 248: 18.548940
# Volume of path rule 249: 18.184992
# Volume of path rule 250: 18.838787
# Volume of path rule 251: 17.846846
# Volume of path rule 252: 18.738191
# Volume of path rule 253: 18.769083
# Volume of path rule 254: 17.537220
# Volume of path rule 255: 19.214630
# Volume of path rule 256: 18.283819
# Volume of path rule 257: 18.781049
# Volume of path rule 258: 18.071812
# Volume of path rule 259: 19.673591
# Volume of path rule 260: 18.145151
# Volume of path rule 261: 19.157916
# Volume of path rule 262: 18.518578
# Volume of path rule 263: 17.837864
# Volume of path rule 264: 18.298544
# Volume of path rule 265: 18.142821
# Volume of path rule 266: 19.333641
# Volume of path rule 267: 17.692618
# Volume of path rule 268: 18.904118
# Volume of path rule 269: 18.729161
# Volume of path rule 270: 19.037508
# Volume of path rule 271: 17.751936
# Volume of path rule 272: 18.270046
# Volume of path rule 273: 17.694539
# Volume of path rule 274: 18.967824
# Volume of path rule 275: 18.878955
# Volume of path rule 276: 18.574003
# Volume of path rule 277: 18.982528
# Volume of path rule 278: 19.455916
# Volume of path rule 279: 18.897387
# Volume of path rule 280: 18.279408
# Volume of path rule 281: 18.019904
# Volume of path rule 282: 19.446501
# Volume of path rule 283: 19.501533
# Volume of path rule 284: 18.678045
# Volume of path rule 285: 18.405584
# Volume of path rule 286: 19.168820
# Volume of path rule 287: 18.833239
# Volume of path rule 288: 18.208433
# Volume of path rule 289: 18.013040
# Volume of path rule 290: 18.397682
# Volume of path rule 291: 18.714948
# Volume of path rule 292: 18.429812
# Volume of path rule 293: 18.763502
# Volume of path rule 294: 19.119777
# Volume of path rule 295: 18.065485
# Volume of path rule 296: 19.026975
# Volume of path rule 297: 19.013883
# Volume of path rule 298: 18.520349
# Volume of path rule 299: 17.909682
# Volume of path rule 300: 18.376736
# Volume of path rule 301: 18.904743
# Volume of path rule 302: 18.831404
# Volume of path rule 303: 18.261341
# Volume of path rule 304: 18.492180
# Volume of path rule 305: 18.365216
# Volume of path rule 306: 18.237060
# Volume of path rule 307: 18.507263
# Volume of path rule 308: 18.291346
# Volume of path rule 309: 17.457795
# Volume of path rule 310: 18.593335
# Volume of path rule 311: 18.322445
# Volume of path rule 312: 18.507867
# Volume of path rule 313: 18.252073
# Volume of path rule 314: 18.845559
# Volume of path rule 315: 18.738150
# Volume of path rule 316: 18.756688
# Volume of path rule 317: 18.026185
# Volume of path rule 318: 18.553570
# Volume of path rule 319: 18.700642
# Volume of path rule 320: 18.615883
# Volume of path rule 321: 18.561606
# Volume of path rule 322: 18.213877
# Volume of path rule 323: 18.632788
# Volume of path rule 324: 17.710727
# Volume of path rule 325: 19.179371
# Volume of path rule 326: 18.943892
# Volume of path rule 327: 17.771270
# Volume of path rule 328: 18.761122
# Volume of path rule 329: 19.132016
# Volume of path rule 330: 18.952032
# Volume of path rule 331: 19.020497
# Volume of path rule 332: 17.574898
# Volume of path rule 333: 18.441075
# Volume of path rule 334: 18.831671
# Volume of path rule 335: 18.456572
# Volume of path rule 336: 18.034889
# Volume of path rule 337: 18.581275
# Volume of path rule 338: 18.917760
# Volume of path rule 339: 18.526587
# Volume of path rule 340: 18.558627
# Volume of path rule 341: 18.542147
# Volume of path rule 342: 19.428645
# Volume of path rule 343: 17.766742
# Volume of path rule 344: 17.849710
# Volume of path rule 345: 18.905202
# Volume of path rule 346: 19.102149
# Volume of path rule 347: 17.420471
# Volume of path rule 348: 17.516012
# Volume of path rule 349: 17.892587
# Volume of path rule 350: 17.179686
# Volume of path rule 351: 18.218781
# Volume of path rule 352: 18.732519
# Volume of path rule 353: 18.054258
# Volume of path rule 354: 17.899533
# Volume of path rule 355: 18.174604
# Volume of path rule 356: 18.560477
# Volume of path rule 357: 19.082993
# Volume of path rule 358: 17.938878
# Volume of path rule 359: 18.561394
# Volume of path rule 360: 17.557372
# Volume of path rule 361: 18.608478
# Volume of path rule 362: 18.779410
# Volume of path rule 363: 19.225810
# Volume of path rule 364: 17.160390
# Volume of path rule 365: 19.381075
# Volume of path rule 366: 16.674414
# Volume of path rule 367: 18.060880
# Volume of path rule 368: 17.028748
# Volume of path rule 369: 18.364910
# Volume of path rule 370: 17.363332
# Volume of path rule 371: 18.799041
# Volume of path rule 372: 19.304838
# Volume of path rule 373: 18.511645
# Volume of path rule 374: 18.357051
# Volume of path rule 375: 18.117988
# Volume of path rule 376: 17.667784
# Volume of path rule 377: 19.238598
# Volume of path rule 378: 18.277501
# Volume of path rule 379: 19.212531
# ...
# Volume of path rule 544: 18.130292
# Volume of path rule 545: 17.971964
# Volume of path rule 546: 18.718757
# Volume of path rule 547: 19.202684
# Volume of path rule 548: 18.716602
# Volume of path rule 549: 18.350266
# Volume of path rule 550: 18.196944
# Volume of path rule 551: 19.255186
# Volume of path rule 552: 18.931784
# Volume of path rule 553: 18.503756
# Volume of path rule 554: 19.243854
# Volume of path rule 555: 17.617529
# Volume of path rule 556: 18.886407
# Volume of path rule 557: 18.812305
# Volume of path rule 558: 18.384755
# Volume of path rule 559: 18.086745
# Volume of path rule 560: 18.914331
# Volume of path rule 561: 18.769242
# Volume of path rule 562: 19.215137
# Volume of path rule 563: 19.631264
# Volume of path rule 564: 18.930756
# Volume of path rule 565: 17.641353
# Volume of path rule 566: 17.929322
# Volume of path rule 567: 19.393128
# Volume of path rule 568: 19.068799
# Volume of path rule 569: 18.272547
# Volume of path rule 570: 18.840551
# Volume of path rule 571: 17.984053
# Volume of path rule 572: 18.066778
# Volume of path rule 573: 18.544347
# Volume of path rule 574: 19.893537
# Volume of path rule 575: 19.092989
# Volume of path rule 576: 19.517205
# Volume of path rule 577: 17.865603
# Volume of path rule 578: 19.252791
# Volume of path rule 579: 17.962848
# Volume of path rule 580: 18.151956
# Volume of path rule 581: 18.652406
# Volume of path rule 582: 18.749890
# Volume of path rule 583: 19.039099
# Volume of path rule 584: 18.653544
# Volume of path rule 585: 18.198727
# Volume of path rule 586: 18.351026
# Volume of path rule 587: 18.166740
# Volume of path rule 588: 18.934125
# Volume of path rule 589: 17.900467
# Volume of path rule 590: 18.338976
# Volume of path rule 591: 17.599715
# Volume of path rule 592: 18.435092
# Volume of path rule 593: 18.138041
# Volume of path rule 594: 17.892844
# Volume of path rule 595: 18.285913
# Volume of path rule 596: 17.623175
# Volume of path rule 597: 18.647559
# Volume of path rule 598: 18.984328
# Volume of path rule 599: 18.122468
# Volume of path rule 600: 18.824281
# Volume of path rule 601: 18.250140
# Volume of path rule 602: 19.145762
# Volume of path rule 603: 18.935474
# Volume of path rule 604: 17.515486
# Volume of path rule 605: 18.587261
# Volume of path rule 606: 17.784563
# Volume of path rule 607: 18.361682
# Volume of path rule 608: 19.132151
# Volume of path rule 609: 18.085486
# Volume of path rule 610: 18.832995
# Volume of path rule 611: 17.917190
# Volume of path rule 612: 18.475830
# Volume of path rule 613: 17.915000
# Volume of path rule 614: 18.398497
# Volume of path rule 615: 18.123927
# Volume of path rule 616: 18.657076
# Volume of path rule 617: 18.471064
# Volume of path rule 618: 17.365215
# Volume of path rule 619: 18.283751
# Volume of path rule 620: 18.161856
# Volume of path rule 621: 18.677840
# Volume of path rule 622: 18.003292
# Volume of path rule 623: 18.047288
# Volume of path rule 624: 17.800142
# Volume of path rule 625: 18.987024
# Volume of path rule 626: 18.027143
# Volume of path rule 627: 18.902335
# Volume of path rule 628: 18.719675
# Volume of path rule 629: 18.041874
# Volume of path rule 630: 18.253540
# Volume of path rule 631: 18.718774
# Volume of path rule 632: 18.028456
# Volume of path rule 633: 18.986833
# Volume of path rule 634: 19.212583
# Volume of path rule 635: 19.469608
# Volume of path rule 636: 19.319670
# Volume of path rule 637: 17.620583
# Volume of path rule 638: 18.106829
# Volume of path rule 639: 18.506866
# Volume of path rule 640: 18.209813
# Volume of path rule 641: 18.173360
# Volume of path rule 642: 17.955385
# Volume of path rule 643: 17.597451
# Volume of path rule 644: 18.183422
# Volume of path rule 645: 18.071391
# Volume of path rule 646: 19.973172
# Volume of path rule 647: 19.170227
# Volume of path rule 648: 18.343176
# Volume of path rule 649: 18.416723
# Volume of path rule 650: 17.491472
# Volume of path rule 651: 19.065069
# Volume of path rule 652: 18.495255
# Volume of path rule 653: 18.783643
# Volume of path rule 654: 18.421440
# Volume of path rule 655: 17.675828
# Volume of path rule 656: 18.890951
# Volume of path rule 657: 19.130015
# Volume of path rule 658: 18.736288
# Volume of path rule 659: 18.269040
# Volume of path rule 660: 19.147770
# Volume of path rule 661: 17.175634
# Volume of path rule 662: 18.673341
# Volume of path rule 663: 18.257840
# Volume of path rule 664: 18.891258
# Volume of path rule 665: 18.452228
# Volume of path rule 666: 18.296139
# Volume of path rule 667: 19.162180
# Volume of path rule 668: 18.794046
# Volume of path rule 669: 17.873929
# Volume of path rule 670: 19.214620
# Volume of path rule 671: 18.719653
# Volume of path rule 672: 19.310972
# Volume of path rule 673: 19.503704
# Volume of path rule 674: 18.369369
# Volume of path rule 675: 18.059943
# Volume of path rule 676: 18.922645
# Volume of path rule 677: 18.426789
# Volume of path rule 678: 18.769890
# Volume of path rule 679: 19.066966
# Volume of path rule 680: 18.732068
# Volume of path rule 681: 18.618622
# Volume of path rule 682: 18.618369
# Volume of path rule 683: 18.097357
# Volume of path rule 684: 18.438777
# Volume of path rule 685: 18.411673
# Volume of path rule 686: 18.891096
# Volume of path rule 687: 18.911482
# Volume of path rule 688: 18.337156
# Volume of path rule 689: 18.550873
# Volume of path rule 690: 17.928996
# Volume of path rule 691: 18.974378
# Volume of path rule 692: 17.793202
# Volume of path rule 693: 18.030309
# Volume of path rule 694: 18.246500
# Volume of path rule 695: 18.909920
# Volume of path rule 696: 19.446438
# Volume of path rule 697: 18.662984
# Volume of path rule 698: 18.566879
# Volume of path rule 699: 18.650193
# Volume of path rule 700: 17.605496
# Volume of path rule 701: 18.141335
# Volume of path rule 702: 19.295664
# Volume of path rule 703: 19.824248
# Volume of path rule 704: 18.580631
# Volume of path rule 705: 17.755731
# Volume of path rule 706: 18.082040
# Volume of path rule 707: 18.171522
# Volume of path rule 708: 17.944000
# Volume of path rule 709: 18.892019
# Volume of path rule 710: 19.372189
# Volume of path rule 711: 18.575327
# Volume of path rule 712: 18.086381
# Volume of path rule 713: 19.279301
# Volume of path rule 714: 18.073702
# Volume of path rule 715: 18.158540
# Volume of path rule 716: 17.664155
# Volume of path rule 717: 18.419455
# Volume of path rule 718: 18.155050
# Volume of path rule 719: 18.307578
# Volume of path rule 720: 18.478740
# Volume of path rule 721: 18.390201
# Volume of path rule 722: 19.313391
# Volume of path rule 723: 19.286882
# Volume of path rule 724: 19.292387
# Volume of path rule 725: 18.179176
# Volume of path rule 726: 18.080429
# Volume of path rule 727: 19.007557
# Volume of path rule 728: 18.353791
# Volume of path rule 729: 18.709943
# Volume of path rule 730: 18.315019
# Volume of path rule 731: 19.438008
# Volume of path rule 732: 18.977594
# Volume of path rule 733: 18.974824
# Volume of path rule 734: 18.115090
# Volume of path rule 735: 18.401981
# Volume of path rule 736: 17.758126
# Volume of path rule 737: 18.418786
# Volume of path rule 738: 19.396144
# Volume of path rule 739: 18.243669
# Volume of path rule 740: 18.513399
# Volume of path rule 741: 18.152122
# Volume of path rule 742: 18.540016
# Volume of path rule 743: 18.649071
# Volume of path rule 744: 18.721804
# Volume of path rule 745: 17.763775
# Volume of path rule 746: 18.786921
# Volume of path rule 747: 17.837945
# Volume of path rule 748: 18.253020
# Volume of path rule 749: 18.303383
# Volume of path rule 750: 18.619221
# Volume of path rule 751: 19.010954
# Volume of path rule 752: 18.241163
# Volume of path rule 753: 18.674749
# Volume of path rule 754: 18.373923
# Volume of path rule 755: 18.250086
# Volume of path rule 756: 18.272700
# Volume of path rule 757: 17.265132
# Volume of path rule 758: 18.987183
# Volume of path rule 759: 18.608509
# Volume of path rule 760: 17.944296
# Volume of path rule 761: 18.962664
# Volume of path rule 762: 17.583184
# Volume of path rule 763: 18.939822
# Volume of path rule 764: 18.678750
# Volume of path rule 765: 18.274866
# Volume of path rule 766: 17.924333
# Volume of path rule 767: 18.326670
# Volume of path rule 768: 19.071840
# Volume of path rule 769: 18.227794
# Volume of path rule 770: 19.186510
# Volume of path rule 771: 18.352540
# Volume of path rule 772: 18.779246
# Volume of path rule 773: 18.996912
# Volume of path rule 774: 17.552480
# Volume of path rule 775: 18.803146
# Volume of path rule 776: 18.653154
# Volume of path rule 777: 17.645204
# Volume of path rule 778: 17.680527
# Volume of path rule 779: 18.845337
# Volume of path rule 780: 18.817863
# Volume of path rule 781: 19.309170
# Volume of path rule 782: 18.656444
# Volume of path rule 783: 18.347121
# Volume of path rule 784: 17.732554
# Volume of path rule 785: 17.973526
# Volume of path rule 786: 18.668257
# Volume of path rule 787: 18.407151
# Volume of path rule 788: 18.970382
# Volume of path rule 789: 18.670242
# Volume of path rule 790: 18.762773
# Volume of path rule 791: 17.858114
# Volume of path rule 792: 18.659496
# Volume of path rule 793: 18.227206
# Volume of path rule 794: 18.880718
# Volume of path rule 795: 18.386554
# Volume of path rule 796: 18.506999
# Volume of path rule 797: 18.281922
# Volume of path rule 798: 18.858753
# Volume of path rule 799: 18.403611
# Volume of path rule 800: 18.889573
# Volume of path rule 801: 18.398247
# Volume of path rule 802: 18.435516
# Volume of path rule 803: 18.145338
# Volume of path rule 804: 18.862530
# Volume of path rule 805: 18.719267
# Volume of path rule 806: 18.908158
# Volume of path rule 807: 18.457598
# Volume of path rule 808: 19.174034
# Volume of path rule 809: 17.654098
# Volume of path rule 810: 18.966235
# Volume of path rule 811: 19.386850
# Volume of path rule 812: 18.320250
# Volume of path rule 813: 18.203230
# Volume of path rule 814: 17.940640
# Volume of path rule 815: 18.953846
# Volume of path rule 816: 18.872617
# Volume of path rule 817: 19.330967
# Volume of path rule 818: 17.761062
# Volume of path rule 819: 19.346618
# Volume of path rule 820: 19.219559
# Volume of path rule 821: 18.049006
# Volume of path rule 822: 18.604255
# Volume of path rule 823: 18.292149
# Volume of path rule 824: 18.233312
# Volume of path rule 825: 19.051204
# Volume of path rule 826: 17.904718
# Volume of path rule 827: 19.388599
# Volume of path rule 828: 18.474999
# Volume of path rule 829: 18.432549
# Volume of path rule 830: 18.132049
# Volume of path rule 831: 18.993146
# Volume of path rule 832: 18.533437
# Volume of path rule 833: 18.123581
# Volume of path rule 834: 18.579087
# Volume of path rule 835: 19.036312
# Volume of path rule 836: 19.047420
# Volume of path rule 837: 18.686359
# Volume of path rule 838: 18.534358
# Volume of path rule 839: 19.054294
# Volume of path rule 840: 19.192278
# Volume of path rule 841: 17.774122
# Volume of path rule 842: 18.205238
# Volume of path rule 843: 17.857844
# Volume of path rule 844: 18.822544
# Volume of path rule 845: 18.324341
# Volume of path rule 846: 18.126558
# Volume of path rule 847: 16.737418
# Volume of path rule 848: 19.408733
# Volume of path rule 849: 18.500942
# Volume of path rule 850: 18.189463
# Volume of path rule 851: 18.263110
# Volume of path rule 852: 18.158372
# Volume of path rule 853: 18.561650
# Volume of path rule 854: 18.622243
# Volume of path rule 855: 17.629998
# Volume of path rule 856: 18.370903
# Volume of path rule 857: 18.318184
# Volume of path rule 858: 18.493575
# Volume of path rule 859: 18.859413
# Volume of path rule 860: 18.078416
# Volume of path rule 861: 18.282021
# Volume of path rule 862: 17.494023
# Volume of path rule 863: 18.413691
# Volume of path rule 864: 19.156591
# Volume of path rule 865: 18.337880
# Volume of path rule 866: 18.323850
# Volume of path rule 867: 17.925186
# Volume of path rule 868: 18.184717
# Volume of path rule 869: 17.702576
# Volume of path rule 870: 18.142077
# Volume of path rule 871: 18.755249
# Volume of path rule 872: 17.357405
# Volume of path rule 873: 18.210002
# Volume of path rule 874: 18.605390
# Volume of path rule 875: 18.256583
# Volume of path rule 876: 17.690633
# Volume of path rule 877: 18.459712
# Volume of path rule 878: 18.233642
# Volume of path rule 879: 18.280266
# Volume of path rule 880: 18.342263
# Volume of path rule 881: 19.360658
# Volume of path rule 882: 18.692057
# Volume of path rule 883: 18.448548
# Volume of path rule 884: 19.911282
# Volume of path rule 885: 19.107874
# Volume of path rule 886: 18.280372
# Volume of path rule 887: 18.630616
# Volume of path rule 888: 19.330830
# Volume of path rule 889: 17.529586
# Volume of path rule 890: 17.780570
# Volume of path rule 891: 18.070368
# Volume of path rule 892: 18.667333
# Volume of path rule 893: 19.060692
# Volume of path rule 894: 17.788979
# Volume of path rule 895: 18.553591
# Volume of path rule 896: 18.427234
# Volume of path rule 897: 18.119685
# Volume of path rule 898: 18.363662
# Volume of path rule 899: 19.093145
# Volume of path rule 900: 18.921328
# Volume of path rule 901: 18.665036
# Volume of path rule 902: 18.029606
# Volume of path rule 903: 19.165068
# Volume of path rule 904: 18.009417
# Volume of path rule 905: 18.078084
# Volume of path rule 906: 19.021656
# Volume of path rule 907: 17.997151
# Volume of path rule 908: 18.397523
# Volume of path rule 909: 18.691856
# Volume of path rule 910: 19.013521
# Volume of path rule 911: 17.953154
# Volume of path rule 912: 19.019232
# Volume of path rule 913: 18.079144
# Volume of path rule 914: 18.632625
# Volume of path rule 915: 18.806780
# Volume of path rule 916: 17.741531
# Volume of path rule 917: 18.424594
# Volume of path rule 918: 18.186179
# Volume of path rule 919: 18.765395
# Volume of path rule 920: 18.542271
# Volume of path rule 921: 17.672802
# Volume of path rule 922: 19.470912
# Volume of path rule 923: 18.518502
# Volume of path rule 924: 18.613421
# Volume of path rule 925: 18.714253
# Volume of path rule 926: 17.238324
# Volume of path rule 927: 18.536321
# Volume of path rule 928: 19.201495
# Volume of path rule 929: 18.512740
# Volume of path rule 930: 18.119853
# Volume of path rule 931: 17.355354
# Volume of path rule 932: 18.470256
# Volume of path rule 933: 18.046768
# Volume of path rule 934: 18.388944
# Volume of path rule 935: 19.235634
# Volume of path rule 936: 18.128192
# Volume of path rule 937: 18.652533
# Volume of path rule 938: 18.110359
# Volume of path rule 939: 18.880634
# Volume of path rule 940: 18.473968
# Volume of path rule 941: 18.268883
# Volume of path rule 942: 18.239621
# Volume of path rule 943: 18.346278
# Volume of path rule 944: 17.839199
# Volume of path rule 945: 18.263697
# Volume of path rule 946: 18.663442
# Volume of path rule 947: 19.201035
# Volume of path rule 948: 18.329953
# Volume of path rule 949: 18.411172
# Volume of path rule 950: 18.072371
# Volume of path rule 951: 18.443700
# Volume of path rule 952: 17.982207
# Volume of path rule 953: 18.366216
# Volume of path rule 954: 18.597231
# Volume of path rule 955: 18.656126
# Volume of path rule 956: 17.886632
# Volume of path rule 957: 19.329640
# Volume of path rule 958: 17.896117
# Volume of path rule 959: 18.912009
# Volume of path rule 960: 19.338722
# Volume of path rule 961: 17.758385
# Volume of path rule 962: 18.535245
# Volume of path rule 963: 18.301930
# Volume of path rule 964: 18.769423
# Volume of path rule 965: 18.374349
# Volume of path rule 966: 18.809430
# Volume of path rule 967: 19.241897
# Volume of path rule 968: 18.377572
# Volume of path rule 969: 18.309588
# Volume of path rule 970: 17.963307
# Volume of path rule 971: 19.511730
# Volume of path rule 972: 19.641727
# Volume of path rule 973: 17.613278
# Volume of path rule 974: 19.435459
# Volume of path rule 975: 18.389284
# Volume of path rule 976: 18.306660
# Volume of path rule 977: 19.328137
# Volume of path rule 978: 18.826967
# Volume of path rule 979: 17.955827
# Volume of path rule 980: 18.614585
# Volume of path rule 981: 18.378248
# Volume of path rule 982: 17.866527
# Volume of path rule 983: 17.807526
# Volume of path rule 984: 18.581037
# Volume of path rule 985: 19.924254
# Volume of path rule 986: 18.399449
# Volume of path rule 987: 17.860500
# Volume of path rule 988: 18.757832
# Volume of path rule 989: 18.926237
# Volume of path rule 990: 17.881421
# Volume of path rule 991: 18.677153
# Volume of path rule 992: 18.135878
# Volume of path rule 993: 18.625900
# Volume of path rule 994: 18.016303
# Volume of path rule 995: 18.776486
# Volume of path rule 996: 18.460705
# Volume of path rule 997: 18.480731
# Volume of path rule 998: 17.400902
# Volume of path rule 999: 18.457106
# Volume of MCR: 1.100785

# %%
y_pred = np.array(results)

# %%
y_pred.shape
# Out:
# (500, 24)

# %% [markdown]
# ###**COSINE DISTANCE**

# %%
X_test.shape
# Out:
# (500, 24)

# %%
yt = X_test.flatten()
yt.shape
# Out:
# (12000,)

# %%
yp = y_pred.flatten()
yp.shape
# Out:
# (12000,)

# %%
from scipy.spatial.distance import cosine

cos_distance = cosine(yt, yp)

# %%
cos_distance
# Out:
# 0.0003796785527175883
